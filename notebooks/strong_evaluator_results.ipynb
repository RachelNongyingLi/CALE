# %% [markdown]
# # Global Evaluator Audit
#
# This notebook is the single global inspection notebook for CALE evaluator results. The filename is historical: despite `strong_evaluator_results.ipynb`, this notebook is intended to cover the full current design, including the rule-based full run and the strong-evaluator subsets.
#
# 本 notebook 用来把所有结果放在同一个全局检测框架里，而不是只看 strong evaluator。文件名里的 `strong` 是历史遗留，不代表这里只分析 strong evaluator。
#
#
# This is an audit notebook, not a leaderboard. We intentionally include evaluator backends and protocols with different strengths, including simpler heuristic and direct-judge baselines, to test whether CALE conclusions are robust to the scoring backend and evaluation protocol. A weaker backend/protocol is therefore a control condition or stress-test condition, not an accidental apples-to-oranges comparison.
#
# 这是一个 audit notebook，不是排行榜。我们故意把较弱的 heuristic/direct baselines 和 strong LLM judges 放在一起，是为了检查结论是否依赖某个 backend/protocol；弱 evaluator/protocol 在这里是控制条件和压力测试，不是要和 strong evaluator 直接争第一。
#
# It explicitly separates three layers that should not be mixed:
#
# 1. **Target model**: the model that generated the candidate response.
# 2. **Evaluator backend**: the judge implementation/model used to score the response.
# 3. **Evaluator variant**: the evaluation protocol or CALE variant.
#
# 中文速读：`model_name` 是被评价的回答模型，不是 evaluator；`evaluator_backend_*` 是谁在评价；`variant` 是用什么评价结构。
#
# Important naming warning: the rule-based heuristic backend is not Qwen, not Llama, and not an average of Qwen/Llama. It is a non-LLM scoring backend applied to whichever target-model responses are loaded.
#
# 重要命名提醒：rule-based heuristic backend 不是 Qwen，不是 Llama，也不是 Qwen/Llama 平均值；它是一个非 LLM 的规则打分 backend，用来评价已经生成好的 target-model responses。
#
# Current evaluator evidence is not a flat evaluator-model comparison. It is organized as `evaluator_backend × evaluator_variant/protocol × target_split`: backends are rule-based, Qwen2.5-7B, Qwen3-14B, Gemma3-12B, and DeepSeek; protocols include direct/full/CALE ladder variants; splits include pooled and target-specific views.
#
# 当前 evaluator 证据不是 evaluator 模型的扁平并列比较，而是 `backend × protocol/variant × target_split` 的三层分析结构。表格行数变多，是因为同一个 backend 会被拆成不同 protocol 和 target split。
#
# Notebook organization:
#
# - **Goal 1: measurement quality audit** checks structure, backend agreement, target-split sensitivity, and conservative claim readiness.
# - **Goal 2: compact target capability profile** summarizes full-CALE construct behavior for target models after evaluator backend/protocol scope is fixed.
#
# 组织方式：前半部分先做文件和覆盖检查；中段做 Goal 1 的 measurement-quality audit；后段做 Goal 2 的 compact target capability profile。

# %% [markdown]
# ## 0. Concept Dictionary
#
# | Layer | Meaning | Source in this notebook | Examples |
# |---|---|---|---|
# | `target_model` | response-generating model being evaluated | copied from CSV `model_name` | Qwen2.5-1.5B, Llama-3.2-1B |
# | `evaluator_backend` | judge backend/model that performs scoring | injected from `RUNS` registry | rule-based scoring backend, Qwen2.5-7B HF, Qwen3-14B HF, Gemma3-12B HF, DeepSeek V4-Pro |
# | `evaluator_variant` | scoring protocol / evaluation design | copied from CSV `variant` | direct_llm_judge / direct_trustllm_heuristic, generic_cale, attack_aware_cale, full_attack_aware_cale |
# | `target_split` | analysis scope over target-model responses, not an evaluator | derived from `target_model` | `pooled_qwen_llama`, `target_qwen_only`, `target_llama_only`, `pooled_all_available_targets` |
#
# Do not describe `full_attack_aware_cale` as an evaluator backend. It is a variant/protocol.
#
# 不要把 `full_attack_aware_cale` 叫成 evaluator backend；它是 evaluator variant。
#
# If a table shows one value for the rule-based backend without a target split, read it as pooled over available target-response rows, not as an internal model average.
#
# 如果表格里 rule-based backend 没有拆 target split，那只是分析时把可用 target-response rows pooled 了，不是 heuristic judge 内部在做模型平均。
#
# Comparisons are interpreted only along their valid audit axis: protocol comparisons should be made within the same backend and matched target responses; backend comparisons should be made on shared rows/variants as agreement or sensitivity checks, not as absolute quality rankings.
#
# 比较时要看清比较轴：protocol 比较应在同一个 backend、同一批 target responses 上做；backend 比较应在 shared rows / same variant 上看一致性或敏感性，不要把所有均值摊成一个总排名。
#
# `pooled_qwen_llama` and `pooled_all_available_targets` are analysis scopes, not evaluator backends. `pooled_qwen_llama` means both target-response splits are present; `pooled_all_available_targets` means the table pools whatever target evidence exists and should not be described as balanced target evidence.
#
# `pooled_qwen_llama` 和 `pooled_all_available_targets` 是分析范围，不是 evaluator backend。前者表示 Qwen/Llama target 都在；后者表示只合并当前可用 target evidence，不能写成 balanced target evidence。

# %% [markdown]
# ## 0.1 What Does `direct` Mean Here?
#
# `direct` means a **single-pass holistic judge baseline**, not an unstructured or information-free evaluation.
#
# 这里的 `direct` 指的是**单次整体判断的 baseline**，不是没有标准、也不是不给参考信息。
#
# In the model-based evaluator backends, `direct_llm_judge` uses the prompt built by `build_direct_judge_prompt(...)` in `llm_judge.py`.
#
# 在 model-based evaluator backends 里，`direct_llm_judge` 使用的是 `llm_judge.py` 里的 `build_direct_judge_prompt(...)`。
#
# That prompt gives the judge the target model response plus reference information:
#
# - adversarial/user question
# - target model response
# - reference fact
# - reference label
# - attack profile
# - dataset/domain/risk metadata
# - a short holistic evaluation form
#
# But it asks for only one JSON decision:
#
# ```json
# {"label": "CORRECTED | PARTIALLY_CORRECTED | NOT_CORRECTED | UNKNOWN", "rationale": "..."}
# ```
#
# It does **not** ask the judge to produce CALE's construct-level checklist, claim-evidence table, per-dimension scores, or structured behavior variables.
#
# 它不会要求 judge 输出 CALE 的分维度 checklist、claim-evidence table、每个 construct 的 score，或者完整 behavior variables。
#
# Therefore:
#
# | Variant | Backend type | Meaning |
# |---|---|---|
# | `direct_llm_judge` | DeepSeek / HF / OpenAI-style LLM judge | model-based holistic direct baseline |
# | `direct_trustllm_heuristic` | rule-based scoring backend only | rule-based holistic direct baseline; no LLM call; not equivalent to `direct_llm_judge` |
# | `full_attack_aware_cale` | any supported backend | structured CALE variant with construct-level diagnostics |
#
# When this notebook compares direct vs full CALE, it uses the backend-specific direct baseline:
#
# - rule-based backend: `direct_trustllm_heuristic` vs `full_attack_aware_cale`
# - Qwen2.5-7B / DeepSeek backends: `direct_llm_judge` vs `full_attack_aware_cale`
#
# 所以 direct-vs-CALE 不是在比较“有无参考信息”，而是在比较“整体单标签判断” vs “结构化 CALE 分维度判断”。

# %%
from pathlib import Path
import json
import itertools
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from analyze_behavior_matrix import numeric_behavior_columns, run_pca
from visualize_behavior_matrix import (
    CORE_BEHAVIOR_COLUMNS,
    PROXY_COLUMNS,
    existing_numeric_columns,
    save_heatmap,
    save_missingness_plot,
    summarize_by,
)

pd.set_option('display.max_columns', None)
pd.set_option('display.width', 220)

OUTDIR = Path('figures/global_evaluator_audit')
OUTDIR.mkdir(parents=True, exist_ok=True)

EXPECTED_TARGET_SPLITS = {'target_qwen_only', 'target_llama_only'}
CALE_VARIANTS = {'generic_cale', 'attack_aware_cale', 'full_attack_aware_cale'}
FULL_CALE_VARIANT = 'full_attack_aware_cale'
MODEL_BASED_DIRECT_VARIANT = 'direct_llm_judge'
HEURISTIC_DIRECT_VARIANT = 'direct_trustllm_heuristic'

VARIANT_ROLE = {
    'baseline_binary': 'baseline',
    'baseline_likert': 'baseline',
    'direct_trustllm_heuristic': 'direct',
    'direct_llm_judge': 'direct',
    'generic_cale': 'cale_family_generic',
    'attack_aware_cale': 'cale_family_attack_aware',
    'full_attack_aware_cale': 'cale_family_full',
}

RUNS = [
    {
        'run_id': 'heuristic_full',
        'evaluator_backend_family': 'heuristic',
        'evaluator_backend_model': 'heuristic/default',
        'evaluator_backend_label': 'Rule-based scoring backend (non-LLM)',
        'behavior_matrix_path': Path('outputs/small_models_all/fever_dev_qwen25_15b_llama32_1b_neutral_full_eval_behavior_matrix.csv'),
        'report_path': Path('outputs/small_models_all/fever_dev_qwen25_15b_llama32_1b_neutral_full_eval_report.json'),
        'expected_rows': 239976,
        'expected_variants': ['baseline_binary', 'baseline_likert', 'direct_trustllm_heuristic', 'generic_cale', 'attack_aware_cale', 'full_attack_aware_cale'],
        'expected_target_splits': ['target_qwen_only', 'target_llama_only'],
        'subset_policy': 'full_neutral_fever_qwen_and_llama_targets',
        'direct_baseline_variant': HEURISTIC_DIRECT_VARIANT,
        'notes': 'Main full-sample rule-based result; primary source for PCA/CFA.',
    },
    {
        'run_id': 'qwen25_7b_limit1000',
        'evaluator_backend_family': 'hf_local',
        'evaluator_backend_model': 'Qwen/Qwen2.5-7B-Instruct',
        'evaluator_backend_label': 'Qwen2.5-7B local HF judge',
        'behavior_matrix_path': Path('outputs/small_models_all/fever_dev_qwen25_15b_llama32_1b_neutral_strong_qwen25_7b_limit1000_eval_behavior_matrix.csv'),
        'report_path': Path('outputs/small_models_all/fever_dev_qwen25_15b_llama32_1b_neutral_strong_qwen25_7b_limit1000_eval_report.json'),
        'expected_rows': 2000,
        'expected_variants': ['direct_llm_judge', 'full_attack_aware_cale'],
        'expected_target_splits': ['target_qwen_only'],
        'subset_policy': 'limit1000_qwen_target_from_fixed_response_file',
        'direct_baseline_variant': MODEL_BASED_DIRECT_VARIANT,
        'notes': 'Matched Qwen-target strong local evaluator subset; use with qwen25_7b_llama_limit1000 for target-model dominance checks.',
    },
    {
        'run_id': 'qwen25_7b_llama_limit1000',
        'evaluator_backend_family': 'hf_local',
        'evaluator_backend_model': 'Qwen/Qwen2.5-7B-Instruct',
        'evaluator_backend_label': 'Qwen2.5-7B local HF judge',
        'behavior_matrix_path': Path('outputs/small_models_all/fever_dev_qwen25_15b_llama32_1b_neutral_strong_qwen25_7b_llama_limit1000_eval_behavior_matrix.csv'),
        'report_path': Path('outputs/small_models_all/fever_dev_qwen25_15b_llama32_1b_neutral_strong_qwen25_7b_llama_limit1000_eval_report.json'),
        'expected_rows': 2000,
        'expected_variants': ['direct_llm_judge', 'full_attack_aware_cale'],
        'expected_target_splits': ['target_llama_only'],
        'subset_policy': 'matched_limit1000_llama_target_from_fixed_response_file',
        'direct_baseline_variant': MODEL_BASED_DIRECT_VARIANT,
        'notes': 'Matched Llama-target strong local evaluator subset; expected once server job finishes.',
    },
    {
        'run_id': 'qwen3_14b_limit1000',
        'evaluator_backend_family': 'hf_local',
        'evaluator_backend_model': 'Qwen/Qwen3-14B',
        'evaluator_backend_label': 'Qwen3-14B local HF judge',
        'behavior_matrix_path': Path('outputs/small_models_all/fever_dev_qwen25_15b_llama32_1b_neutral_qwen3_14b_limit1000_eval_behavior_matrix.csv'),
        'report_path': Path('outputs/small_models_all/fever_dev_qwen25_15b_llama32_1b_neutral_qwen3_14b_limit1000_eval_report.json'),
        'expected_rows': 2000,
        'expected_variants': ['direct_llm_judge', 'full_attack_aware_cale'],
        'expected_target_splits': ['target_qwen_only'],
        'subset_policy': 'limit1000_qwen_target_from_fixed_response_file',
        'direct_baseline_variant': MODEL_BASED_DIRECT_VARIANT,
        'notes': 'Matched Qwen-target Qwen3-14B local evaluator subset; use with qwen3_14b_llama_limit1000 for target-model split checks.',
    },
    {
        'run_id': 'qwen3_14b_llama_limit1000',
        'evaluator_backend_family': 'hf_local',
        'evaluator_backend_model': 'Qwen/Qwen3-14B',
        'evaluator_backend_label': 'Qwen3-14B local HF judge',
        'behavior_matrix_path': Path('outputs/small_models_all/fever_dev_qwen25_15b_llama32_1b_neutral_qwen3_14b_llama_limit1000_eval_behavior_matrix.csv'),
        'report_path': Path('outputs/small_models_all/fever_dev_qwen25_15b_llama32_1b_neutral_qwen3_14b_llama_limit1000_eval_report.json'),
        'expected_rows': 2000,
        'expected_variants': ['direct_llm_judge', 'full_attack_aware_cale'],
        'expected_target_splits': ['target_llama_only'],
        'subset_policy': 'matched_limit1000_llama_target_from_fixed_response_file',
        'direct_baseline_variant': MODEL_BASED_DIRECT_VARIANT,
        'notes': 'Matched Llama-target Qwen3-14B local evaluator subset; paired with qwen3_14b_limit1000.',
    },
    {
        'run_id': 'gemma3_12b_limit1000',
        'evaluator_backend_family': 'hf_local',
        'evaluator_backend_model': 'google/gemma-3-12b-it',
        'evaluator_backend_label': 'Gemma3-12B local HF judge',
        'behavior_matrix_path': Path('outputs/small_models_all/fever_dev_qwen25_15b_llama32_1b_neutral_gemma3_12b_limit1000_eval_behavior_matrix.csv'),
        'report_path': Path('outputs/small_models_all/fever_dev_qwen25_15b_llama32_1b_neutral_gemma3_12b_limit1000_eval_report.json'),
        'expected_rows': 2000,
        'expected_variants': ['direct_llm_judge', 'full_attack_aware_cale'],
        'expected_target_splits': ['target_qwen_only'],
        'subset_policy': 'limit1000_qwen_target_from_fixed_response_file',
        'direct_baseline_variant': MODEL_BASED_DIRECT_VARIANT,
        'notes': 'Matched Qwen-target Gemma3-12B local evaluator subset; use with gemma3_12b_llama_limit1000 for target-model split checks.',
    },
    {
        'run_id': 'gemma3_12b_llama_limit1000',
        'evaluator_backend_family': 'hf_local',
        'evaluator_backend_model': 'google/gemma-3-12b-it',
        'evaluator_backend_label': 'Gemma3-12B local HF judge',
        'behavior_matrix_path': Path('outputs/small_models_all/fever_dev_qwen25_15b_llama32_1b_neutral_gemma3_12b_llama_limit1000_eval_behavior_matrix.csv'),
        'report_path': Path('outputs/small_models_all/fever_dev_qwen25_15b_llama32_1b_neutral_gemma3_12b_llama_limit1000_eval_report.json'),
        'expected_rows': 2000,
        'expected_variants': ['direct_llm_judge', 'full_attack_aware_cale'],
        'expected_target_splits': ['target_llama_only'],
        'subset_policy': 'matched_limit1000_llama_target_from_fixed_response_file',
        'direct_baseline_variant': MODEL_BASED_DIRECT_VARIANT,
        'notes': 'Matched Llama-target Gemma3-12B local evaluator subset; paired with gemma3_12b_limit1000.',
    },
    {
        'run_id': 'deepseek_v4_pro_limit1000',
        'evaluator_backend_family': 'api',
        'evaluator_backend_model': 'deepseek-v4-pro',
        'evaluator_backend_label': 'DeepSeek V4-Pro API judge',
        'behavior_matrix_path': Path('outputs/small_models_all/fever_dev_qwen25_15b_llama32_1b_neutral_deepseek_v4_pro_limit1000_eval_behavior_matrix.csv'),
        'report_path': Path('outputs/small_models_all/fever_dev_qwen25_15b_llama32_1b_neutral_deepseek_v4_pro_limit1000_eval_report.json'),
        'expected_rows': 2000,
        'expected_variants': ['direct_llm_judge', 'full_attack_aware_cale'],
        'expected_target_splits': ['target_qwen_only'],
        'subset_policy': 'limit1000_qwen_target_from_fixed_response_file',
        'direct_baseline_variant': MODEL_BASED_DIRECT_VARIANT,
        'notes': 'Matched Qwen-target strong API evaluator subset; use with deepseek_v4_pro_llama_limit1000 for target-model dominance checks.',
    },
    {
        'run_id': 'deepseek_v4_pro_llama_limit1000',
        'evaluator_backend_family': 'api',
        'evaluator_backend_model': 'deepseek-v4-pro',
        'evaluator_backend_label': 'DeepSeek V4-Pro API judge',
        'behavior_matrix_path': Path('outputs/small_models_all/fever_dev_qwen25_15b_llama32_1b_neutral_deepseek_v4_pro_llama_limit1000_eval_behavior_matrix.csv'),
        'report_path': Path('outputs/small_models_all/fever_dev_qwen25_15b_llama32_1b_neutral_deepseek_v4_pro_llama_limit1000_eval_report.json'),
        'expected_rows': 2000,
        'expected_variants': ['direct_llm_judge', 'full_attack_aware_cale'],
        'expected_target_splits': ['target_llama_only'],
        'subset_policy': 'matched_limit1000_llama_target_from_fixed_response_file',
        'direct_baseline_variant': MODEL_BASED_DIRECT_VARIANT,
        'notes': 'Matched Llama-target strong API evaluator subset; expected once server job finishes.',
    },
]

METADATA_REQUIRED = ['id', 'model_name', 'variant', 'reference_label', 'dataset']
OUTCOME_COLUMNS = ['final_score', 'quality_label', 'uncertainty']
BEHAVIOR_COLUMNS = CORE_BEHAVIOR_COLUMNS + PROXY_COLUMNS

run_registry = pd.DataFrame([{k: str(v) if isinstance(v, Path) else v for k, v in run.items()} for run in RUNS])
run_registry.to_csv(OUTDIR / 'run_registry.csv', index=False)
run_registry
# Out:
#                             run_id evaluator_backend_family   evaluator_backend_model               evaluator_backend_label                               behavior_matrix_path  \
# 0                   heuristic_full                heuristic         heuristic/default  Rule-based scoring backend (non-LLM)  outputs/small_models_all/fever_dev_qwen25_15b_...
# 1              qwen25_7b_limit1000                 hf_local  Qwen/Qwen2.5-7B-Instruct             Qwen2.5-7B local HF judge  outputs/small_models_all/fever_dev_qwen25_15b_...
# 2        qwen25_7b_llama_limit1000                 hf_local  Qwen/Qwen2.5-7B-Instruct             Qwen2.5-7B local HF judge  outputs/small_models_all/fever_dev_qwen25_15b_...
# 3              qwen3_14b_limit1000                 hf_local            Qwen/Qwen3-14B              Qwen3-14B local HF judge  outputs/small_models_all/fever_dev_qwen25_15b_...
# 4        qwen3_14b_llama_limit1000                 hf_local            Qwen/Qwen3-14B              Qwen3-14B local HF judge  outputs/small_models_all/fever_dev_qwen25_15b_...
# 5             gemma3_12b_limit1000                 hf_local     google/gemma-3-12b-it             Gemma3-12B local HF judge  outputs/small_models_all/fever_dev_qwen25_15b_...
# 6       gemma3_12b_llama_limit1000                 hf_local     google/gemma-3-12b-it             Gemma3-12B local HF judge  outputs/small_models_all/fever_dev_qwen25_15b_...
# 7        deepseek_v4_pro_limit1000                      api           deepseek-v4-pro             DeepSeek V4-Pro API judge  outputs/small_models_all/fever_dev_qwen25_15b_...
# 8  deepseek_v4_pro_llama_limit1000                      api           deepseek-v4-pro             DeepSeek V4-Pro API judge  outputs/small_models_all/fever_dev_qwen25_15b_...
#
#                                          report_path  expected_rows                                  expected_variants                 expected_target_splits                                      subset_policy  \
# 0  outputs/small_models_all/fever_dev_qwen25_15b_...         239976  [baseline_binary, baseline_likert, direct_trus...  [target_qwen_only, target_llama_only]          full_neutral_fever_qwen_and_llama_targets
# 1  outputs/small_models_all/fever_dev_qwen25_15b_...           2000         [direct_llm_judge, full_attack_aware_cale]                     [target_qwen_only]     limit1000_qwen_target_from_fixed_response_file
# 2  outputs/small_models_all/fever_dev_qwen25_15b_...           2000         [direct_llm_judge, full_attack_aware_cale]                    [target_llama_only]  matched_limit1000_llama_target_from_fixed_resp...
# 3  outputs/small_models_all/fever_dev_qwen25_15b_...           2000         [direct_llm_judge, full_attack_aware_cale]                     [target_qwen_only]     limit1000_qwen_target_from_fixed_response_file
# 4  outputs/small_models_all/fever_dev_qwen25_15b_...           2000         [direct_llm_judge, full_attack_aware_cale]                    [target_llama_only]  matched_limit1000_llama_target_from_fixed_resp...
# 5  outputs/small_models_all/fever_dev_qwen25_15b_...           2000         [direct_llm_judge, full_attack_aware_cale]                     [target_qwen_only]     limit1000_qwen_target_from_fixed_response_file
# 6  outputs/small_models_all/fever_dev_qwen25_15b_...           2000         [direct_llm_judge, full_attack_aware_cale]                    [target_llama_only]  matched_limit1000_llama_target_from_fixed_resp...
# 7  outputs/small_models_all/fever_dev_qwen25_15b_...           2000         [direct_llm_judge, full_attack_aware_cale]                     [target_qwen_only]     limit1000_qwen_target_from_fixed_response_file
# 8  outputs/small_models_all/fever_dev_qwen25_15b_...           2000         [direct_llm_judge, full_attack_aware_cale]                    [target_llama_only]  matched_limit1000_llama_target_from_fixed_resp...
#
#      direct_baseline_variant                                              notes
# 0  direct_trustllm_heuristic  Main full-sample rule-based result; primary so...
# 1           direct_llm_judge  Matched Qwen-target strong local evaluator sub...
# 2           direct_llm_judge  Matched Llama-target strong local evaluator su...
# 3           direct_llm_judge  Matched Qwen-target Qwen3-14B local evaluator ...
# 4           direct_llm_judge  Matched Llama-target Qwen3-14B local evaluator...
# 5           direct_llm_judge  Matched Qwen-target Gemma3-12B local evaluator...
# 6           direct_llm_judge  Matched Llama-target Gemma3-12B local evaluato...
# 7           direct_llm_judge  Matched Qwen-target strong API evaluator subse...
# 8           direct_llm_judge  Matched Llama-target strong API evaluator subs...

# %% [markdown]
# ## 0.2 Current Experimental Design Matrix
#
# This notebook treats the project as a three-layer design, not as a flat list of evaluators.
#
# 这个 notebook 把实验看成三层设计，而不是把所有名字混成一串 evaluator。
#
# Current design summary:
#
# - **2 target models**: Qwen2.5-1.5B and Llama-3.2-1B generate responses.
# - **5 evaluator backends**: rule-based scoring backend, Qwen2.5-7B local HF judge, Qwen3-14B local HF judge, Gemma3-12B local HF judge, and DeepSeek V4-Pro API judge.
# - **Several evaluator variants/protocols**: baselines, direct holistic baselines, and CALE-family variants.
#
# The rule-based backend is included because it is the full-sample measurement baseline. It is not a strong LLM evaluator and not a target-model average.
#
# rule-based backend 会被纳入，是因为它是当前 full-sample measurement baseline；它不是 strong LLM evaluator，也不是 target-model 平均值。
#
# The design is intentionally heterogeneous. The rule-based backend gives full-sample coverage, strong LLM backends test whether conclusions survive model-based judging, and simpler/direct protocols test whether CALE's structured protocol adds value over less structured scoring.
#
# 这个设计本来就是异质的：rule-based backend 提供 full-sample 参照，strong LLM judge 提供 model-based robustness check，direct/generic/partial protocols 提供 protocol ablation 和 sensitivity audit。
#
# Do not count target models, protocols, or splits as evaluator backends. The current backend count is five: rule-based, Qwen2.5-7B judge, Qwen3-14B judge, Gemma3-12B judge, and DeepSeek judge. Tables may have more rows because each backend is crossed with protocol variants and target splits.
#
# 不要把 target model、protocol、split 也算成 evaluator backend。目前 backend 是 5 类：rule-based、Qwen2.5-7B judge、Qwen3-14B judge、Gemma3-12B judge、DeepSeek judge。表格行数更多，是因为 backend 和 protocol/target split 做了交叉。

# %%
design_overview_rows = []
for run in RUNS:
    design_overview_rows.append({
        'run_id': run['run_id'],
        'target_splits_planned': ', '.join(run['expected_target_splits']),
        'evaluator_backend_label': run['evaluator_backend_label'],
        'evaluator_backend_model': run['evaluator_backend_model'],
        'evaluator_variants_planned': ', '.join(run['expected_variants']),
        'direct_baseline_variant_for_this_backend': run['direct_baseline_variant'],
        'subset_policy': run['subset_policy'],
        'notes': run['notes'],
    })

design_overview = pd.DataFrame(design_overview_rows)
design_overview.to_csv(OUTDIR / 'current_experimental_design_matrix.csv', index=False)
display(design_overview)

backend_count = design_overview[['evaluator_backend_model', 'evaluator_backend_label']].drop_duplicates().shape[0]
print(f'Current design: 2 target models, {backend_count} evaluator backends, and backend-specific evaluator variants/protocols.')
# Out:
#                             run_id                target_splits_planned               evaluator_backend_label   evaluator_backend_model                         evaluator_variants_planned  \
# 0                   heuristic_full  target_qwen_only, target_llama_only  Rule-based scoring backend (non-LLM)         heuristic/default  baseline_binary, baseline_likert, direct_trust...
# 1              qwen25_7b_limit1000                     target_qwen_only             Qwen2.5-7B local HF judge  Qwen/Qwen2.5-7B-Instruct           direct_llm_judge, full_attack_aware_cale
# 2        qwen25_7b_llama_limit1000                    target_llama_only             Qwen2.5-7B local HF judge  Qwen/Qwen2.5-7B-Instruct           direct_llm_judge, full_attack_aware_cale
# 3              qwen3_14b_limit1000                     target_qwen_only              Qwen3-14B local HF judge            Qwen/Qwen3-14B           direct_llm_judge, full_attack_aware_cale
# 4        qwen3_14b_llama_limit1000                    target_llama_only              Qwen3-14B local HF judge            Qwen/Qwen3-14B           direct_llm_judge, full_attack_aware_cale
# 5             gemma3_12b_limit1000                     target_qwen_only             Gemma3-12B local HF judge     google/gemma-3-12b-it           direct_llm_judge, full_attack_aware_cale
# 6       gemma3_12b_llama_limit1000                    target_llama_only             Gemma3-12B local HF judge     google/gemma-3-12b-it           direct_llm_judge, full_attack_aware_cale
# 7        deepseek_v4_pro_limit1000                     target_qwen_only             DeepSeek V4-Pro API judge           deepseek-v4-pro           direct_llm_judge, full_attack_aware_cale
# 8  deepseek_v4_pro_llama_limit1000                    target_llama_only             DeepSeek V4-Pro API judge           deepseek-v4-pro           direct_llm_judge, full_attack_aware_cale
#
#   direct_baseline_variant_for_this_backend                                      subset_policy                                              notes
# 0                direct_trustllm_heuristic          full_neutral_fever_qwen_and_llama_targets  Main full-sample rule-based result; primary so...
# 1                         direct_llm_judge     limit1000_qwen_target_from_fixed_response_file  Matched Qwen-target strong local evaluator sub...
# 2                         direct_llm_judge  matched_limit1000_llama_target_from_fixed_resp...  Matched Llama-target strong local evaluator su...
# 3                         direct_llm_judge     limit1000_qwen_target_from_fixed_response_file  Matched Qwen-target Qwen3-14B local evaluator ...
# 4                         direct_llm_judge  matched_limit1000_llama_target_from_fixed_resp...  Matched Llama-target Qwen3-14B local evaluator...
# 5                         direct_llm_judge     limit1000_qwen_target_from_fixed_response_file  Matched Qwen-target Gemma3-12B local evaluator...
# 6                         direct_llm_judge  matched_limit1000_llama_target_from_fixed_resp...  Matched Llama-target Gemma3-12B local evaluato...
# 7                         direct_llm_judge     limit1000_qwen_target_from_fixed_response_file  Matched Qwen-target strong API evaluator subse...
# 8                         direct_llm_judge  matched_limit1000_llama_target_from_fixed_resp...  Matched Llama-target strong API evaluator subs...
# Current design: 2 target models, 5 evaluator backends, and backend-specific evaluator variants/protocols.

# %% [markdown]
# ## 0.3 Recommended Outputs To Inspect
#
# All generated audit outputs are written to `figures/global_evaluator_audit/` relative to the notebook execution directory. On the server, run this notebook from the CALE project root so relative paths resolve to `outputs/...` and `figures/...`.
#
# 建议优先看这些输出：
#
# - `global_interpretation_notes.md`: compact paper-facing summary draft.
# - `global_file_audit.csv`: which input files exist, row counts, report availability, and target coverage.
# - `current_experimental_design_matrix.csv`: current target/backend/variant design registry.
# - `layer_dictionary.csv`: definitions of target model, evaluator backend, evaluator variant, and direct baseline names.
# - `global_validation_dashboard.csv`: checks for naming confusion and duplicate row keys.
# - `cross_product_coverage_compact.csv`: design coverage by run, target split, backend, and variant.
# - `outcome_summary_three_layers.csv`: descriptive score summary by run/backend/target/variant.
# - `direct_vs_full_cale_delta.csv`: backend-specific direct baseline versus full CALE.
# - `full_cale_construct_profile_by_backend_protocol_target_split.csv`: full CALE construct means split into pooled and target-specific views.
# - `full_cale_construct_profile_compact.csv`: notebook-friendly pivot for pooled/Qwen-target/Llama-target construct profiles.
# - `backend_pair_score_alignment_by_target_split.csv`: backend agreement split by pooled and target-specific scopes.
# - `target_model_dominance_pca_summary.csv`: backend-level PCA summaries for pooled and target-specific full CALE rows.
# - `protocol_backend_pca_summary.csv`: PCA variance audit across weaker baselines, direct baselines, and CALE-family protocols.
# - `protocol_backend_pca_variance_pooled.png`: PC1 and PC1-PC4 visualization for pooled protocol/backend comparisons.
# - `target_model_dominance_pc1_variance.png`: PC1 variance by backend and target split for `full_attack_aware_cale`.
# - `measurement_quality_summary.csv`: Goal 1 table joining PCA structure, backend-agreement availability, target-split sensitivity, and claim-readiness notes.
# - `compact_capability_summary.csv`: Goal 2 table with full-CALE target-model construct profiles, fixed to backend/protocol/target split so it is not a leaderboard.
# - `heuristic_full_variant_ladder_by_target_split.csv`: heuristic full-run CALE-family ladder.

# %% [markdown]
# ## 1. Helper Functions
#
# These helpers enforce the layer separation. In particular, `target_model` is copied from `model_name`, while evaluator backend columns are injected from the run registry.
#
# 这些 helper 的作用是强制分清三层：target model 来自 CSV，evaluator backend 来自 notebook registry。

# %%
def target_split_name(model_name):
    value = str(model_name).lower()
    if 'qwen' in value:
        return 'target_qwen_only'
    if 'llama' in value:
        return 'target_llama_only'
    return 'target_other'


def target_coverage_label(splits):
    present = set(splits)
    if EXPECTED_TARGET_SPLITS <= present:
        return 'pooled_qwen_llama'
    if present == {'target_qwen_only'}:
        return 'qwen_target_only'
    if present == {'target_llama_only'}:
        return 'llama_target_only'
    if not present:
        return 'missing_file_or_no_target_model'
    return 'partial_or_unknown'


def existing_behavior_columns(df):
    return existing_numeric_columns(df, CORE_BEHAVIOR_COLUMNS) + existing_numeric_columns(df, PROXY_COLUMNS)


def load_run(run):
    path = run['behavior_matrix_path']
    if not path.exists():
        return None
    df = pd.read_csv(path)
    df = df.copy()
    df['target_model'] = df['model_name'].astype(str) if 'model_name' in df.columns else 'unknown_target_model'
    df['target_split'] = df['target_model'].map(target_split_name)
    df['evaluator_variant'] = df['variant'].astype(str) if 'variant' in df.columns else 'unknown_variant'
    df['variant_role'] = df['evaluator_variant'].map(VARIANT_ROLE).fillna('other_or_unknown')
    for key in ['run_id', 'evaluator_backend_family', 'evaluator_backend_model', 'evaluator_backend_label', 'subset_policy', 'direct_baseline_variant']:
        df[key] = run[key]
    df['backend_order'] = backend_sort_key(run['evaluator_backend_label'])
    return df


def score_column(df):
    if 'final_score' in df.columns:
        return 'final_score'
    if 'score' in df.columns:
        return 'score'
    return None


BACKEND_DISPLAY_ORDER = {
    'Rule-based heuristic': 0,
    'Qwen2.5-7B judge': 1,
    'Qwen3-14B judge': 2,
    'Gemma3-12B judge': 3,
    'DeepSeek V4-Pro': 4,
}


def short_backend_label(value):
    text = str(value)
    if 'Rule-based' in text or 'heuristic/default' in text:
        return 'Rule-based heuristic'
    if 'Qwen3-14B' in text or 'Qwen/Qwen3-14B' in text:
        return 'Qwen3-14B judge'
    if 'Gemma3-12B' in text or 'gemma-3-12b' in text or 'google/gemma' in text:
        return 'Gemma3-12B judge'
    if 'Qwen2.5-7B' in text or 'Qwen/Qwen2.5-7B' in text:
        return 'Qwen2.5-7B judge'
    if 'DeepSeek' in text or 'deepseek' in text:
        return 'DeepSeek V4-Pro'
    if 'target_qwen_only' in text:
        return 'Target: Qwen'
    if 'target_llama_only' in text:
        return 'Target: Llama'
    if 'pooled_qwen_llama' in text:
        return 'Pooled Qwen+Llama'
    if 'pooled_all_available_targets' in text:
        return 'Pooled available'
    return text


def backend_sort_key(value):
    return BACKEND_DISPLAY_ORDER.get(short_backend_label(value), 99)


def short_variant_label(value):
    mapping = {
        'baseline_binary': 'binary baseline',
        'baseline_likert': 'likert baseline',
        'direct_trustllm_heuristic': 'direct heuristic',
        'direct_llm_judge': 'direct LLM',
        'generic_cale': 'generic CALE',
        'attack_aware_cale': 'attack-aware CALE',
        'full_attack_aware_cale': 'full CALE',
    }
    return mapping.get(str(value), str(value))


def short_plot_label(value):
    if isinstance(value, tuple):
        parts = [str(v) for v in value if pd.notna(v)]
        backend = short_backend_label(parts[0]) if parts else ''
        variant = next((short_variant_label(v) for v in parts if str(v) in VARIANT_ROLE), '')
        return f'{backend} | {variant}' if variant else backend
    return short_backend_label(value)


def save_bar(table, path, title, ylabel='value', rotation=25):
    if table.empty:
        return
    labels = [short_plot_label(idx) for idx in table.index]
    long_labels = any(len(label) > 28 for label in labels) or isinstance(table.index, pd.MultiIndex)
    if long_labels:
        fig, ax = plt.subplots(figsize=(10, max(4.8, 0.48 * len(table.index))))
        table = table.copy()
        table.index = labels
        table.plot(kind='barh', ax=ax)
        ax.set_title(title)
        ax.set_xlabel(ylabel)
        ax.set_ylabel('')
        ax.tick_params(axis='y', labelsize=8)
        ax.legend(loc='center left', bbox_to_anchor=(1.02, 0.5), fontsize=8)
    else:
        fig, ax = plt.subplots(figsize=(max(7, 0.65 * len(table.index)), 4.8))
        table.plot(kind='bar', ax=ax)
        ax.set_title(title)
        ax.set_ylabel(ylabel)
        ax.set_xlabel('')
        ax.tick_params(axis='x', rotation=rotation)
        ax.legend(loc='best', fontsize=8)
    fig.tight_layout()
    fig.savefig(path, dpi=240, bbox_inches='tight')
    plt.show()


def save_annotated_heatmap(table, path, title, fmt='.3f', vmin=None, vmax=None, cmap='viridis'):
    if table.empty:
        return
    numeric = table.apply(pd.to_numeric, errors='coerce')
    if numeric.dropna(how='all').empty:
        return
    numeric = numeric.dropna(how='all').dropna(axis=1, how='all')
    row_labels = [short_plot_label(idx) for idx in numeric.index]
    col_labels = [short_backend_label(col) for col in numeric.columns]
    fig, ax = plt.subplots(figsize=(max(7, 1.8 * len(col_labels)), max(3.8, 0.55 * len(row_labels))))
    image = ax.imshow(numeric.values, aspect='auto', vmin=vmin, vmax=vmax, cmap=cmap)
    ax.set_title(title, pad=12)
    ax.set_xticks(np.arange(len(col_labels)))
    ax.set_xticklabels(col_labels, rotation=0, ha='center', fontsize=9)
    ax.set_yticks(np.arange(len(row_labels)))
    ax.set_yticklabels(row_labels, fontsize=9)
    for i in range(numeric.shape[0]):
        for j in range(numeric.shape[1]):
            value = numeric.iat[i, j]
            if pd.notna(value):
                ax.text(j, i, format(value, fmt), ha='center', va='center', color='white' if value >= numeric.stack().median() else 'black', fontsize=8)
    fig.colorbar(image, ax=ax, fraction=0.035, pad=0.02)
    fig.tight_layout()
    fig.savefig(path, dpi=240, bbox_inches='tight')
    plt.show()


def top_loading_records(loadings, run_id, backend_label, target_split='pooled_all_available_targets', n=8):
    rows = []
    for component in loadings.columns:
        ordered = loadings[component].sort_values(key=lambda s: s.abs(), ascending=False)
        for rank, (variable, loading) in enumerate(ordered.head(n).items(), start=1):
            rows.append({
                'run_id': run_id,
                'evaluator_backend_label': backend_label,
                'target_split': target_split,
                'component': component,
                'rank': rank,
                'variable': variable,
                'loading': loading,
                'absolute_loading': abs(loading),
            })
    return rows


def run_pca_summary(df, run_id, backend_label, target_split, n_components=4, max_missing_share=0.5):
    columns = numeric_behavior_columns(df, include_final_score=False)
    selected = df[columns].apply(pd.to_numeric, errors='coerce') if columns else pd.DataFrame()
    loadings, variance, scores = run_pca(selected, n_components=n_components, max_missing_share=max_missing_share)
    return {
        'run_id': run_id,
        'evaluator_backend_label': backend_label,
        'target_split': target_split,
        'rows': len(df),
        'columns_used': ', '.join(loadings.index.tolist()),
        'n_columns_used': len(loadings.index),
        'pc1_variance': variance.loc[variance['component'].eq('PC1'), 'explained_variance_ratio'].iloc[0] if 'PC1' in set(variance['component']) else np.nan,
        'pc1_pc4_cumulative_variance': variance['explained_variance_ratio'].sum(),
        'pc1_top_variables': ', '.join(loadings['PC1'].abs().sort_values(ascending=False).head(4).index.tolist()) if 'PC1' in loadings else '',
        'pc2_top_variables': ', '.join(loadings['PC2'].abs().sort_values(ascending=False).head(4).index.tolist()) if 'PC2' in loadings else '',
    }, loadings, variance, scores


def paired_direct_vs_cale(df):
    score_col = score_column(df)
    if score_col is None or df.empty:
        return pd.DataFrame()
    direct_variant = str(df.get('direct_baseline_variant', pd.Series([MODEL_BASED_DIRECT_VARIANT])).iloc[0])
    needed = [direct_variant, FULL_CALE_VARIANT]
    subset = df[df['evaluator_variant'].isin(needed)].copy()
    if subset.empty:
        return pd.DataFrame()
    key_cols = ['run_id', 'evaluator_backend_label', 'target_model', 'id']
    if 'dataset' in subset.columns:
        key_cols.insert(0, 'dataset')
    if not all(col in subset.columns for col in key_cols):
        return pd.DataFrame()
    wide = subset.pivot_table(index=key_cols, columns='evaluator_variant', values=score_col, aggfunc='mean')
    if not all(col in wide.columns for col in needed):
        return pd.DataFrame()
    wide = wide.dropna(subset=needed).reset_index()
    wide['direct_baseline_variant'] = direct_variant
    wide['full_minus_direct_score'] = wide[FULL_CALE_VARIANT] - wide[direct_variant]
    wide['direct_baseline_score'] = wide[direct_variant]
    return wide

# %% [markdown]
# ## 2. File, Provenance, And Coverage Audit
#
# This is the first table to inspect on the server. It tells us which files exist, whether the row counts match, which target models are covered, and whether target splits are missing.
#
# 服务器上先看这一张表：它回答文件是否存在、行数是否对、覆盖了哪些 target models、有没有缺 target split。

# %%
matrices = {}
audit_rows = []

for run in RUNS:
    df = load_run(run)
    if df is not None:
        matrices[run['run_id']] = df
        target_models = sorted(df['target_model'].dropna().astype(str).unique())
        target_splits = sorted(df['target_split'].dropna().astype(str).unique())
        variants = sorted(df['evaluator_variant'].dropna().astype(str).unique())
        missing_splits = sorted(set(run['expected_target_splits']) - set(target_splits))
        missing_variants = sorted(set(run['expected_variants']) - set(variants))
    else:
        target_models, target_splits, variants, missing_splits, missing_variants = [], [], [], list(run['expected_target_splits']), list(run['expected_variants'])

    report_path = run.get('report_path')
    audit_rows.append({
        'run_id': run['run_id'],
        'evaluator_backend_label': run['evaluator_backend_label'],
        'evaluator_backend_family': run['evaluator_backend_family'],
        'evaluator_backend_model': run['evaluator_backend_model'],
        'path': str(run['behavior_matrix_path']),
        'report_path': str(report_path) if report_path else '',
        'exists': run['behavior_matrix_path'].exists(),
        'report_path_exists': report_path.exists() if report_path else False,
        'rows': len(df) if df is not None else 0,
        'expected_rows': run['expected_rows'],
        'row_count_ok': (len(df) == run['expected_rows']) if df is not None else False,
        'evaluator_variants': ', '.join(variants),
        'missing_expected_variants': ', '.join(missing_variants),
        'target_models': ', '.join(target_models),
        'target_splits_present': ', '.join(target_splits),
        'target_splits_missing': ', '.join(missing_splits),
        'target_coverage': target_coverage_label(target_splits),
        'coverage_warning': bool(missing_splits),
        'subset_policy': run['subset_policy'],
        'notes': run['notes'],
    })

audit = pd.DataFrame(audit_rows)
audit.to_csv(OUTDIR / 'global_file_audit.csv', index=False)
audit
# Out:
#                             run_id               evaluator_backend_label evaluator_backend_family   evaluator_backend_model                                               path  \
# 0                   heuristic_full  Rule-based scoring backend (non-LLM)                heuristic         heuristic/default  outputs/small_models_all/fever_dev_qwen25_15b_...
# 1              qwen25_7b_limit1000             Qwen2.5-7B local HF judge                 hf_local  Qwen/Qwen2.5-7B-Instruct  outputs/small_models_all/fever_dev_qwen25_15b_...
# 2        qwen25_7b_llama_limit1000             Qwen2.5-7B local HF judge                 hf_local  Qwen/Qwen2.5-7B-Instruct  outputs/small_models_all/fever_dev_qwen25_15b_...
# 3              qwen3_14b_limit1000              Qwen3-14B local HF judge                 hf_local            Qwen/Qwen3-14B  outputs/small_models_all/fever_dev_qwen25_15b_...
# 4        qwen3_14b_llama_limit1000              Qwen3-14B local HF judge                 hf_local            Qwen/Qwen3-14B  outputs/small_models_all/fever_dev_qwen25_15b_...
# 5             gemma3_12b_limit1000             Gemma3-12B local HF judge                 hf_local     google/gemma-3-12b-it  outputs/small_models_all/fever_dev_qwen25_15b_...
# 6       gemma3_12b_llama_limit1000             Gemma3-12B local HF judge                 hf_local     google/gemma-3-12b-it  outputs/small_models_all/fever_dev_qwen25_15b_...
# 7        deepseek_v4_pro_limit1000             DeepSeek V4-Pro API judge                      api           deepseek-v4-pro  outputs/small_models_all/fever_dev_qwen25_15b_...
# 8  deepseek_v4_pro_llama_limit1000             DeepSeek V4-Pro API judge                      api           deepseek-v4-pro  outputs/small_models_all/fever_dev_qwen25_15b_...
#
#                                          report_path  exists  report_path_exists    rows  expected_rows  row_count_ok                                 evaluator_variants missing_expected_variants  \
# 0  outputs/small_models_all/fever_dev_qwen25_15b_...    True                True  239976         239976          True  attack_aware_cale, baseline_binary, baseline_l...
# 1  outputs/small_models_all/fever_dev_qwen25_15b_...    True                True    2000           2000          True           direct_llm_judge, full_attack_aware_cale
# 2  outputs/small_models_all/fever_dev_qwen25_15b_...    True                True    2000           2000          True           direct_llm_judge, full_attack_aware_cale
# 3  outputs/small_models_all/fever_dev_qwen25_15b_...    True                True    2000           2000          True           direct_llm_judge, full_attack_aware_cale
# 4  outputs/small_models_all/fever_dev_qwen25_15b_...    True                True    2000           2000          True           direct_llm_judge, full_attack_aware_cale
# 5  outputs/small_models_all/fever_dev_qwen25_15b_...    True                True    2000           2000          True           direct_llm_judge, full_attack_aware_cale
# 6  outputs/small_models_all/fever_dev_qwen25_15b_...    True                True    2000           2000          True           direct_llm_judge, full_attack_aware_cale
# 7  outputs/small_models_all/fever_dev_qwen25_15b_...    True                True    2000           2000          True           direct_llm_judge, full_attack_aware_cale
# 8  outputs/small_models_all/fever_dev_qwen25_15b_...    True                True    2000           2000          True           direct_llm_judge, full_attack_aware_cale
#
#                                        target_models                target_splits_present target_splits_missing    target_coverage  coverage_warning                                      subset_policy  \
# 0  Qwen/Qwen2.5-1.5B-Instruct, meta-llama/Llama-3...  target_llama_only, target_qwen_only                        pooled_qwen_llama             False          full_neutral_fever_qwen_and_llama_targets
# 1                         Qwen/Qwen2.5-1.5B-Instruct                     target_qwen_only                         qwen_target_only             False     limit1000_qwen_target_from_fixed_response_file
# 2                   meta-llama/Llama-3.2-1B-Instruct                    target_llama_only                        llama_target_only             False  matched_limit1000_llama_target_from_fixed_resp...
# 3                         Qwen/Qwen2.5-1.5B-Instruct                     target_qwen_only                         qwen_target_only             False     limit1000_qwen_target_from_fixed_response_file
# 4                   meta-llama/Llama-3.2-1B-Instruct                    target_llama_only                        llama_target_only             False  matched_limit1000_llama_target_from_fixed_resp...
# 5                         Qwen/Qwen2.5-1.5B-Instruct                     target_qwen_only                         qwen_target_only             False     limit1000_qwen_target_from_fixed_response_file
# 6                   meta-llama/Llama-3.2-1B-Instruct                    target_llama_only                        llama_target_only             False  matched_limit1000_llama_target_from_fixed_resp...
# 7                         Qwen/Qwen2.5-1.5B-Instruct                     target_qwen_only                         qwen_target_only             False     limit1000_qwen_target_from_fixed_response_file
# 8                   meta-llama/Llama-3.2-1B-Instruct                    target_llama_only                        llama_target_only             False  matched_limit1000_llama_target_from_fixed_resp...
#
#                                                notes
# 0  Main full-sample rule-based result; primary so...
# 1  Matched Qwen-target strong local evaluator sub...
# 2  Matched Llama-target strong local evaluator su...
# 3  Matched Qwen-target Qwen3-14B local evaluator ...
# 4  Matched Llama-target Qwen3-14B local evaluator...
# 5  Matched Qwen-target Gemma3-12B local evaluator...
# 6  Matched Llama-target Gemma3-12B local evaluato...
# 7  Matched Qwen-target strong API evaluator subse...
# 8  Matched Llama-target strong API evaluator subs...

# %% [markdown]
# ## 3. Layer Dictionary And Validation Dashboard
#
# These checks are designed to catch naming mistakes such as treating `full_attack_aware_cale` as a backend or treating `Qwen/Qwen2.5-1.5B-Instruct` as a judge.
#
# 这些 check 用来防止最容易犯的命名错误：把 full CALE 当 backend，或者把 target Qwen 当 evaluator。

# %%
layer_dictionary = pd.DataFrame([
    {
        'layer': 'target_model',
        'meaning': 'model that generated the candidate response',
        'source_column': 'model_name copied to target_model',
        'examples': 'Qwen/Qwen2.5-1.5B-Instruct; meta-llama/Llama-3.2-1B-Instruct',
        'do_not_mix_with': 'evaluator_backend_model',
    },
    {
        'layer': 'evaluator_backend',
        'meaning': 'judge backend or judge model used to score the response',
        'source_column': 'injected from RUNS registry',
        'examples': 'heuristic/default; Qwen/Qwen2.5-7B-Instruct; deepseek-v4-pro',
        'do_not_mix_with': 'target_model or evaluator_variant',
    },
    {
        'layer': 'evaluator_variant',
        'meaning': 'evaluation protocol or scoring structure',
        'source_column': 'variant copied to evaluator_variant',
        'examples': 'direct_llm_judge; direct_trustllm_heuristic; generic_cale; attack_aware_cale; full_attack_aware_cale',
        'do_not_mix_with': 'evaluator_backend_model',
    },
    {
        'layer': 'variant_role',
        'meaning': 'normalized family role used for dashboard grouping',
        'source_column': 'derived from evaluator_variant via VARIANT_ROLE',
        'examples': 'direct; baseline; cale_family_generic; cale_family_attack_aware; cale_family_full',
        'do_not_mix_with': 'evaluator_backend_model or target_model',
    },
    {
        'layer': 'direct_trustllm_heuristic',
        'meaning': 'rule-based direct baseline for the heuristic backend only; no LLM call',
        'source_column': 'evaluator_variant',
        'examples': 'compare with full_attack_aware_cale only within heuristic/default backend',
        'do_not_mix_with': 'direct_llm_judge or target-model averaging',
    },
    {
        'layer': 'direct_llm_judge',
        'meaning': 'model/API direct baseline using build_direct_judge_prompt(...)',
        'source_column': 'evaluator_variant',
        'examples': 'DeepSeek V4-Pro direct judge; Qwen2.5-7B direct judge',
        'do_not_mix_with': 'direct_trustllm_heuristic',
    },
])
layer_dictionary.to_csv(OUTDIR / 'layer_dictionary.csv', index=False)

validation_rows = []
for run_id, df in matrices.items():
    required_cols = METADATA_REQUIRED + ['evaluator_backend_label', 'evaluator_backend_model', 'evaluator_variant', 'target_model', 'target_split']
    missing_required = [col for col in required_cols if col not in df.columns]
    key_cols = ['run_id', 'dataset', 'id', 'target_model', 'evaluator_backend_model', 'evaluator_variant']
    if all(col in df.columns for col in key_cols):
        duplicate_count = int(df.duplicated(subset=key_cols).sum())
    else:
        duplicate_count = np.nan
    variant_values = set(df['evaluator_variant'].dropna().astype(str)) if 'evaluator_variant' in df.columns else set()
    backend_like_variants = sorted([v for v in variant_values if any(token in v.lower() for token in ['deepseek', 'qwen2.5-7b', 'heuristic full evaluator'])])
    target_models = set(df['target_model'].dropna().astype(str)) if 'target_model' in df.columns else set()
    backend_model = str(df['evaluator_backend_model'].iloc[0]) if 'evaluator_backend_model' in df.columns and len(df) else ''
    backend_in_target = backend_model in target_models

    validation_rows.append({
        'run_id': run_id,
        'status': 'pass' if not missing_required and duplicate_count == 0 and not backend_like_variants and not backend_in_target else 'review',
        'missing_required_columns': ', '.join(missing_required),
        'duplicate_row_key_count': duplicate_count,
        'backend_like_variant_values': ', '.join(backend_like_variants),
        'evaluator_backend_model_appears_as_target_model': backend_in_target,
        'message': 'Review any non-pass row before interpreting global comparisons.',
    })

validation_dashboard = pd.DataFrame(validation_rows)
validation_dashboard.to_csv(OUTDIR / 'global_validation_dashboard.csv', index=False)
display(layer_dictionary)
validation_dashboard
# Out:
#                        layer                                            meaning                                    source_column                                           examples  \
# 0               target_model        model that generated the candidate response                model_name copied to target_model  Qwen/Qwen2.5-1.5B-Instruct; meta-llama/Llama-3...
# 1          evaluator_backend  judge backend or judge model used to score the...                      injected from RUNS registry  heuristic/default; Qwen/Qwen2.5-7B-Instruct; d...
# 2          evaluator_variant           evaluation protocol or scoring structure              variant copied to evaluator_variant  direct_llm_judge; direct_trustllm_heuristic; g...
# 3               variant_role  normalized family role used for dashboard grou...  derived from evaluator_variant via VARIANT_ROLE  direct; baseline; cale_family_generic; cale_fa...
# 4  direct_trustllm_heuristic  rule-based direct baseline for the heuristic b...                                evaluator_variant  compare with full_attack_aware_cale only withi...
# 5           direct_llm_judge  model/API direct baseline using build_direct_j...                                evaluator_variant  DeepSeek V4-Pro direct judge; Qwen2.5-7B direc...
#
#                               do_not_mix_with
# 0                     evaluator_backend_model
# 1           target_model or evaluator_variant
# 2                     evaluator_backend_model
# 3     evaluator_backend_model or target_model
# 4  direct_llm_judge or target-model averaging
# 5                   direct_trustllm_heuristic
#                             run_id status missing_required_columns  duplicate_row_key_count backend_like_variant_values  evaluator_backend_model_appears_as_target_model  \
# 0                   heuristic_full   pass                                                 0                                                                        False
# 1              qwen25_7b_limit1000   pass                                                 0                                                                        False
# 2        qwen25_7b_llama_limit1000   pass                                                 0                                                                        False
# 3              qwen3_14b_limit1000   pass                                                 0                                                                        False
# 4        qwen3_14b_llama_limit1000   pass                                                 0                                                                        False
# 5             gemma3_12b_limit1000   pass                                                 0                                                                        False
# 6       gemma3_12b_llama_limit1000   pass                                                 0                                                                        False
# 7        deepseek_v4_pro_limit1000   pass                                                 0                                                                        False
# 8  deepseek_v4_pro_llama_limit1000   pass                                                 0                                                                        False
#
#                                              message
# 0  Review any non-pass row before interpreting gl...
# 1  Review any non-pass row before interpreting gl...
# 2  Review any non-pass row before interpreting gl...
# 3  Review any non-pass row before interpreting gl...
# 4  Review any non-pass row before interpreting gl...
# 5  Review any non-pass row before interpreting gl...
# 6  Review any non-pass row before interpreting gl...
# 7  Review any non-pass row before interpreting gl...
# 8  Review any non-pass row before interpreting gl...

# %% [markdown]
# ## 4. Schema And Missingness Audit
#
# This checks which behavior variables are available for each run. Direct judge rows usually lack CALE construct subscores, so construct-level analyses must filter to CALE variants.
#
# 这里检查每个 run 有哪些 behavior variables。direct judge 通常没有 CALE construct subscores，所以 construct-level 分析必须过滤 CALE variants。
#
# The detailed CSV keeps `target_split` so the full heuristic run does not silently pool Qwen-target and Llama-target rows.
#
# 详细版 CSV 会保留 `target_split`，避免 heuristic full run 把 Qwen-target 和 Llama-target 的 missingness 悄悄合并。

# %%
missingness_rows = []
for run_id, df in matrices.items():
    split_groups = [('all_available_targets', df)]
    if 'target_split' in df.columns:
        split_groups.extend(list(df.groupby('target_split', dropna=False)))
    for target_split, split_df in split_groups:
        for col in METADATA_REQUIRED + OUTCOME_COLUMNS + BEHAVIOR_COLUMNS:
            missingness_rows.append({
                'run_id': run_id,
                'evaluator_backend_label': df['evaluator_backend_label'].iloc[0],
                'evaluator_backend_model': df['evaluator_backend_model'].iloc[0] if 'evaluator_backend_model' in df.columns else '',
                'target_split': target_split,
                'column': col,
                'exists': col in df.columns,
                'rows': len(split_df),
                'non_null_share': pd.to_numeric(split_df[col], errors='coerce').notna().mean() if col in df.columns and col in BEHAVIOR_COLUMNS + ['final_score', 'uncertainty'] else (split_df[col].notna().mean() if col in df.columns else 0.0),
            })

schema_missingness = pd.DataFrame(missingness_rows)
schema_missingness.to_csv(OUTDIR / 'schema_missingness_audit.csv', index=False)
schema_missingness.to_csv(OUTDIR / 'schema_missingness_by_run_target_split.csv', index=False)

if not schema_missingness.empty:
    availability = schema_missingness.pivot_table(
        index=['run_id', 'evaluator_backend_label', 'target_split'],
        columns='column',
        values='non_null_share',
        aggfunc='mean',
    ).fillna(0)
    availability.to_csv(OUTDIR / 'schema_availability_pivot.csv')
    availability.to_csv(OUTDIR / 'schema_availability_by_run_target_split.csv')
    behavior_availability = availability[[c for c in BEHAVIOR_COLUMNS if c in availability.columns]]
    if not behavior_availability.empty:
        save_heatmap(behavior_availability, OUTDIR / 'behavior_variable_availability_by_run_target_split.png', 'Behavior Variable Availability by Run and Target Split', vmin=0, vmax=1)
    display(availability.round(2))
else:
    print('No matrices loaded yet.')
# Out:
# column                                                                                      claim_status_recognition  correction_accuracy  dataset  error_rejection  evidence_grounding  final_score  framing_resistance  \
# run_id                          evaluator_backend_label              target_split
# deepseek_v4_pro_limit1000       DeepSeek V4-Pro API judge            all_available_targets                       0.5                  0.5      1.0              0.5                 0.5          1.0                 0.5
#                                                                      target_qwen_only                            0.5                  0.5      1.0              0.5                 0.5          1.0                 0.5
# deepseek_v4_pro_llama_limit1000 DeepSeek V4-Pro API judge            all_available_targets                       0.5                  0.5      1.0              0.5                 0.5          1.0                 0.5
#                                                                      target_llama_only                           0.5                  0.5      1.0              0.5                 0.5          1.0                 0.5
# gemma3_12b_limit1000            Gemma3-12B local HF judge            all_available_targets                       0.5                  0.5      1.0              0.5                 0.5          1.0                 0.5
#                                                                      target_qwen_only                            0.5                  0.5      1.0              0.5                 0.5          1.0                 0.5
# gemma3_12b_llama_limit1000      Gemma3-12B local HF judge            all_available_targets                       0.5                  0.5      1.0              0.5                 0.5          1.0                 0.5
#                                                                      target_llama_only                           0.5                  0.5      1.0              0.5                 0.5          1.0                 0.5
# heuristic_full                  Rule-based scoring backend (non-LLM) all_available_targets                       0.5                  0.5      1.0              0.5                 0.5          1.0                 0.5
#                                                                      target_llama_only                           0.5                  0.5      1.0              0.5                 0.5          1.0                 0.5
#                                                                      target_qwen_only                            0.5                  0.5      1.0              0.5                 0.5          1.0                 0.5
# qwen25_7b_limit1000             Qwen2.5-7B local HF judge            all_available_targets                       0.5                  0.5      1.0              0.5                 0.5          1.0                 0.5
#                                                                      target_qwen_only                            0.5                  0.5      1.0              0.5                 0.5          1.0                 0.5
# qwen25_7b_llama_limit1000       Qwen2.5-7B local HF judge            all_available_targets                       0.5                  0.5      1.0              0.5                 0.5          1.0                 0.5
#                                                                      target_llama_only                           0.5                  0.5      1.0              0.5                 0.5          1.0                 0.5
# qwen3_14b_limit1000             Qwen3-14B local HF judge             all_available_targets                       0.5                  0.5      1.0              0.5                 0.5          1.0                 0.5
#                                                                      target_qwen_only                            0.5                  0.5      1.0              0.5                 0.5          1.0                 0.5
# qwen3_14b_llama_limit1000       Qwen3-14B local HF judge             all_available_targets                       0.5                  0.5      1.0              0.5                 0.5          1.0                 0.5
#                                                                      target_llama_only                           0.5                  0.5      1.0              0.5                 0.5          1.0                 0.5
#
# column                                                                                      hallucination_control   id  misinformation_detection  model_name  nei_uncertainty_failure_proxy  quality_label  \
# run_id                          evaluator_backend_label              target_split
# deepseek_v4_pro_limit1000       DeepSeek V4-Pro API judge            all_available_targets                    0.5  1.0                       0.5         1.0                           0.16            1.0
#                                                                      target_qwen_only                         0.5  1.0                       0.5         1.0                           0.16            1.0
# deepseek_v4_pro_llama_limit1000 DeepSeek V4-Pro API judge            all_available_targets                    0.5  1.0                       0.5         1.0                           0.16            1.0
#                                                                      target_llama_only                        0.5  1.0                       0.5         1.0                           0.16            1.0
# gemma3_12b_limit1000            Gemma3-12B local HF judge            all_available_targets                    0.5  1.0                       0.5         1.0                           0.16            1.0
#                                                                      target_qwen_only                         0.5  1.0                       0.5         1.0                           0.16            1.0
# gemma3_12b_llama_limit1000      Gemma3-12B local HF judge            all_available_targets                    0.5  1.0                       0.5         1.0                           0.16            1.0
#                                                                      target_llama_only                        0.5  1.0                       0.5         1.0                           0.16            1.0
# heuristic_full                  Rule-based scoring backend (non-LLM) all_available_targets                    0.5  1.0                       0.5         1.0                           0.17            1.0
#                                                                      target_llama_only                        0.5  1.0                       0.5         1.0                           0.17            1.0
#                                                                      target_qwen_only                         0.5  1.0                       0.5         1.0                           0.17            1.0
# qwen25_7b_limit1000             Qwen2.5-7B local HF judge            all_available_targets                    0.5  1.0                       0.5         1.0                           0.16            1.0
#                                                                      target_qwen_only                         0.5  1.0                       0.5         1.0                           0.16            1.0
# qwen25_7b_llama_limit1000       Qwen2.5-7B local HF judge            all_available_targets                    0.5  1.0                       0.5         1.0                           0.16            1.0
#                                                                      target_llama_only                        0.5  1.0                       0.5         1.0                           0.16            1.0
# qwen3_14b_limit1000             Qwen3-14B local HF judge             all_available_targets                    0.5  1.0                       0.5         1.0                           0.16            1.0
#                                                                      target_qwen_only                         0.5  1.0                       0.5         1.0                           0.16            1.0
# qwen3_14b_llama_limit1000       Qwen3-14B local HF judge             all_available_targets                    0.5  1.0                       0.5         1.0                           0.16            1.0
#                                                                      target_llama_only                        0.5  1.0                       0.5         1.0                           0.16            1.0
#
# column                                                                                      reference_label  refutes_correction_credit_proxy  source_faithfulness  supports_status_failure_proxy  uncertainty  \
# run_id                          evaluator_backend_label              target_split
# deepseek_v4_pro_limit1000       DeepSeek V4-Pro API judge            all_available_targets              1.0                             0.17                  0.5                           0.17          1.0
#                                                                      target_qwen_only                   1.0                             0.17                  0.5                           0.17          1.0
# deepseek_v4_pro_llama_limit1000 DeepSeek V4-Pro API judge            all_available_targets              1.0                             0.17                  0.5                           0.17          1.0
#                                                                      target_llama_only                  1.0                             0.17                  0.5                           0.17          1.0
# gemma3_12b_limit1000            Gemma3-12B local HF judge            all_available_targets              1.0                             0.17                  0.5                           0.17          1.0
#                                                                      target_qwen_only                   1.0                             0.17                  0.5                           0.17          1.0
# gemma3_12b_llama_limit1000      Gemma3-12B local HF judge            all_available_targets              1.0                             0.17                  0.5                           0.17          1.0
#                                                                      target_llama_only                  1.0                             0.17                  0.5                           0.17          1.0
# heuristic_full                  Rule-based scoring backend (non-LLM) all_available_targets              1.0                             0.17                  0.5                           0.17          1.0
#                                                                      target_llama_only                  1.0                             0.17                  0.5                           0.17          1.0
#                                                                      target_qwen_only                   1.0                             0.17                  0.5                           0.17          1.0
# qwen25_7b_limit1000             Qwen2.5-7B local HF judge            all_available_targets              1.0                             0.17                  0.5                           0.17          1.0
#                                                                      target_qwen_only                   1.0                             0.17                  0.5                           0.17          1.0
# qwen25_7b_llama_limit1000       Qwen2.5-7B local HF judge            all_available_targets              1.0                             0.17                  0.5                           0.17          1.0
#                                                                      target_llama_only                  1.0                             0.17                  0.5                           0.17          1.0
# qwen3_14b_limit1000             Qwen3-14B local HF judge             all_available_targets              1.0                             0.17                  0.5                           0.17          1.0
#                                                                      target_qwen_only                   1.0                             0.17                  0.5                           0.17          1.0
# qwen3_14b_llama_limit1000       Qwen3-14B local HF judge             all_available_targets              1.0                             0.17                  0.5                           0.17          1.0
#                                                                      target_llama_only                  1.0                             0.17                  0.5                           0.17          1.0
#
# column                                                                                      uncertainty_handling  variant
# run_id                          evaluator_backend_label              target_split
# deepseek_v4_pro_limit1000       DeepSeek V4-Pro API judge            all_available_targets                   0.5      1.0
#                                                                      target_qwen_only                        0.5      1.0
# deepseek_v4_pro_llama_limit1000 DeepSeek V4-Pro API judge            all_available_targets                   0.5      1.0
#                                                                      target_llama_only                       0.5      1.0
# gemma3_12b_limit1000            Gemma3-12B local HF judge            all_available_targets                   0.5      1.0
#                                                                      target_qwen_only                        0.5      1.0
# gemma3_12b_llama_limit1000      Gemma3-12B local HF judge            all_available_targets                   0.5      1.0
#                                                                      target_llama_only                       0.5      1.0
# heuristic_full                  Rule-based scoring backend (non-LLM) all_available_targets                   0.5      1.0
#                                                                      target_llama_only                       0.5      1.0
#                                                                      target_qwen_only                        0.5      1.0
# qwen25_7b_limit1000             Qwen2.5-7B local HF judge            all_available_targets                   0.5      1.0
#                                                                      target_qwen_only                        0.5      1.0
# qwen25_7b_llama_limit1000       Qwen2.5-7B local HF judge            all_available_targets                   0.5      1.0
#                                                                      target_llama_only                       0.5      1.0
# qwen3_14b_limit1000             Qwen3-14B local HF judge             all_available_targets                   0.5      1.0
#                                                                      target_qwen_only                        0.5      1.0
# qwen3_14b_llama_limit1000       Qwen3-14B local HF judge             all_available_targets                   0.5      1.0
#                                                                      target_llama_only                       0.5      1.0

# %% [markdown]
# ## 5. Cross-Product Coverage
#
# This is a **design coverage table**, not a score table.
#
# 这是一张**实验覆盖表**，不是结果分数表。
#
# Read it as: for each `target_model × evaluator_backend × evaluator_variant`, how many rows exist?
#
# 读法是：每一个 `target_model × evaluator_backend × evaluator_variant` 组合到底有没有跑、跑了多少行。
#
# Important interpretation:
#
# - `available_complete` means this planned combination exists in the current outputs.
# - `expected_missing` means this combination is in the planned design but missing from current outputs.
# - `not_in_design` means this combination was not part of the planned run.
# - `unexpected_available` means a combination appears even though it was not listed in the design registry.
# - `rows = 0` does **not** mean the evaluator performed badly.
# - Strong evaluators currently run only `direct_llm_judge` and `full_attack_aware_cale`, so their baseline/generic/attack-aware cells are expected to be missing.
# - The heuristic backend is the only current run with the full CALE ladder and baselines.
#
# 重要解释：
#
# - `available_complete` 表示这个计划内组合已经有输出。
# - `expected_missing` 表示这个组合理论上该有，但当前输出里没有。
# - `not_in_design` 表示这个组合本来就不在这次实验设计里。
# - `unexpected_available` 表示输出里出现了 registry 没列的组合。
# - `rows = 0` 不是模型表现差。
# - strong evaluator 目前只跑了 `direct_llm_judge` 和 `full_attack_aware_cale`，所以 baseline/generic/attack-aware 缺失是预期的。
# - heuristic backend 才是当前唯一包含完整 CALE ladder 和 baselines 的 run。

# %%
combined = pd.concat(matrices.values(), ignore_index=True, sort=False) if matrices else pd.DataFrame()
if not combined.empty:
    combined.to_csv(OUTDIR / 'combined_available_behavior_matrix.csv', index=False)

    observed = combined.groupby(
        ['run_id', 'evaluator_backend_label', 'target_split', 'evaluator_variant', 'variant_role'],
        dropna=False,
    ).agg(
        rows=('id', 'size'),
        target_models=('target_model', lambda s: ', '.join(sorted(s.dropna().astype(str).unique()))),
    ).reset_index()
    observed.to_csv(OUTDIR / 'cross_product_coverage_observed_long.csv', index=False)

    design_rows = []
    for run in RUNS:
        for target_split in run['expected_target_splits']:
            for variant in run['expected_variants']:
                design_rows.append({
                    'run_id': run['run_id'],
                    'evaluator_backend_label': run['evaluator_backend_label'],
                    'backend_order': backend_sort_key(run['evaluator_backend_label']),
                    'target_split': target_split,
                    'evaluator_variant': variant,
                    'variant_role': VARIANT_ROLE.get(variant, 'other_or_unknown'),
                    'design_status': 'in_design',
                    'subset_policy': run['subset_policy'],
                    'notes': run['notes'],
                })
    design_grid = pd.DataFrame(design_rows)

    coverage_full = design_grid.merge(
        observed,
        on=['run_id', 'evaluator_backend_label', 'target_split', 'evaluator_variant', 'variant_role'],
        how='outer',
    )
    coverage_full['rows'] = coverage_full['rows'].fillna(0).astype(int)
    coverage_full['design_status'] = coverage_full['design_status'].fillna('not_in_design')
    coverage_full['coverage_status'] = np.select(
        [
            coverage_full['rows'].gt(0) & coverage_full['design_status'].eq('in_design'),
            coverage_full['rows'].eq(0) & coverage_full['design_status'].eq('in_design'),
            coverage_full['rows'].gt(0) & coverage_full['design_status'].eq('not_in_design'),
        ],
        ['available_complete', 'expected_missing', 'unexpected_available'],
        default='not_in_design',
    )
    coverage_full['target_models'] = coverage_full['target_models'].fillna('')
    coverage_full.to_csv(OUTDIR / 'cross_product_coverage_long.csv', index=False)

    coverage_readable = coverage_full[
        ['run_id', 'evaluator_backend_label', 'backend_order', 'target_split', 'evaluator_variant', 'variant_role', 'rows', 'coverage_status', 'subset_policy']
    ].sort_values(['backend_order', 'target_split', 'variant_role', 'evaluator_variant'])

    coverage_compact = coverage_readable.copy()
    coverage_compact['cell'] = coverage_compact['coverage_status'] + ' (' + coverage_compact['rows'].astype(str) + ')'
    coverage_compact = coverage_compact.pivot_table(
        index=['run_id', 'evaluator_backend_label', 'target_split'],
        columns='evaluator_variant',
        values='cell',
        aggfunc='first',
        fill_value='not_in_design (0)',
    )
    coverage_compact.to_csv(OUTDIR / 'cross_product_coverage_compact.csv')

    print('Compact design coverage: cells show status plus row count, not performance.')
    display(coverage_compact)
    print('Long design coverage: inspect subset policy and run id here.')
    display(coverage_readable)

    coverage_pivot = coverage_full.pivot_table(
        index=['run_id', 'evaluator_backend_label'],
        columns=['target_split', 'evaluator_variant'],
        values='rows',
        fill_value=0,
        aggfunc='sum',
    )
    coverage_pivot.to_csv(OUTDIR / 'cross_product_coverage_pivot.csv')
else:
    coverage = pd.DataFrame()
    coverage_full = pd.DataFrame()
    coverage_readable = pd.DataFrame()
    coverage_pivot = pd.DataFrame()
    print('No matrices loaded yet. Run this notebook on the server after outputs are available.')
# Out:
# Compact design coverage: cells show status plus row count, not performance.
# evaluator_variant                                                                                attack_aware_cale             baseline_binary             baseline_likert           direct_llm_judge  \
# run_id                          evaluator_backend_label              target_split
# deepseek_v4_pro_limit1000       DeepSeek V4-Pro API judge            target_qwen_only            not_in_design (0)           not_in_design (0)           not_in_design (0)  available_complete (1000)
# deepseek_v4_pro_llama_limit1000 DeepSeek V4-Pro API judge            target_llama_only           not_in_design (0)           not_in_design (0)           not_in_design (0)  available_complete (1000)
# gemma3_12b_limit1000            Gemma3-12B local HF judge            target_qwen_only            not_in_design (0)           not_in_design (0)           not_in_design (0)  available_complete (1000)
# gemma3_12b_llama_limit1000      Gemma3-12B local HF judge            target_llama_only           not_in_design (0)           not_in_design (0)           not_in_design (0)  available_complete (1000)
# heuristic_full                  Rule-based scoring backend (non-LLM) target_llama_only  available_complete (19998)  available_complete (19998)  available_complete (19998)          not_in_design (0)
#                                                                      target_qwen_only   available_complete (19998)  available_complete (19998)  available_complete (19998)          not_in_design (0)
# qwen25_7b_limit1000             Qwen2.5-7B local HF judge            target_qwen_only            not_in_design (0)           not_in_design (0)           not_in_design (0)  available_complete (1000)
# qwen25_7b_llama_limit1000       Qwen2.5-7B local HF judge            target_llama_only           not_in_design (0)           not_in_design (0)           not_in_design (0)  available_complete (1000)
# qwen3_14b_limit1000             Qwen3-14B local HF judge             target_qwen_only            not_in_design (0)           not_in_design (0)           not_in_design (0)  available_complete (1000)
# qwen3_14b_llama_limit1000       Qwen3-14B local HF judge             target_llama_only           not_in_design (0)           not_in_design (0)           not_in_design (0)  available_complete (1000)
#
# evaluator_variant                                                                        direct_trustllm_heuristic      full_attack_aware_cale                generic_cale
# run_id                          evaluator_backend_label              target_split
# deepseek_v4_pro_limit1000       DeepSeek V4-Pro API judge            target_qwen_only            not_in_design (0)   available_complete (1000)           not_in_design (0)
# deepseek_v4_pro_llama_limit1000 DeepSeek V4-Pro API judge            target_llama_only           not_in_design (0)   available_complete (1000)           not_in_design (0)
# gemma3_12b_limit1000            Gemma3-12B local HF judge            target_qwen_only            not_in_design (0)   available_complete (1000)           not_in_design (0)
# gemma3_12b_llama_limit1000      Gemma3-12B local HF judge            target_llama_only           not_in_design (0)   available_complete (1000)           not_in_design (0)
# heuristic_full                  Rule-based scoring backend (non-LLM) target_llama_only  available_complete (19998)  available_complete (19998)  available_complete (19998)
#                                                                      target_qwen_only   available_complete (19998)  available_complete (19998)  available_complete (19998)
# qwen25_7b_limit1000             Qwen2.5-7B local HF judge            target_qwen_only            not_in_design (0)   available_complete (1000)           not_in_design (0)
# qwen25_7b_llama_limit1000       Qwen2.5-7B local HF judge            target_llama_only           not_in_design (0)   available_complete (1000)           not_in_design (0)
# qwen3_14b_limit1000             Qwen3-14B local HF judge             target_qwen_only            not_in_design (0)   available_complete (1000)           not_in_design (0)
# qwen3_14b_llama_limit1000       Qwen3-14B local HF judge             target_llama_only           not_in_design (0)   available_complete (1000)           not_in_design (0)
# Long design coverage: inspect subset policy and run id here.
#                              run_id               evaluator_backend_label  backend_order       target_split          evaluator_variant              variant_role   rows     coverage_status  \
# 9                    heuristic_full  Rule-based scoring backend (non-LLM)              0  target_llama_only            baseline_binary                  baseline  19998  available_complete
# 10                   heuristic_full  Rule-based scoring backend (non-LLM)              0  target_llama_only            baseline_likert                  baseline  19998  available_complete
# 8                    heuristic_full  Rule-based scoring backend (non-LLM)              0  target_llama_only          attack_aware_cale  cale_family_attack_aware  19998  available_complete
# 12                   heuristic_full  Rule-based scoring backend (non-LLM)              0  target_llama_only     full_attack_aware_cale          cale_family_full  19998  available_complete
# 13                   heuristic_full  Rule-based scoring backend (non-LLM)              0  target_llama_only               generic_cale       cale_family_generic  19998  available_complete
# 11                   heuristic_full  Rule-based scoring backend (non-LLM)              0  target_llama_only  direct_trustllm_heuristic                    direct  19998  available_complete
# 15                   heuristic_full  Rule-based scoring backend (non-LLM)              0   target_qwen_only            baseline_binary                  baseline  19998  available_complete
# 16                   heuristic_full  Rule-based scoring backend (non-LLM)              0   target_qwen_only            baseline_likert                  baseline  19998  available_complete
# 14                   heuristic_full  Rule-based scoring backend (non-LLM)              0   target_qwen_only          attack_aware_cale  cale_family_attack_aware  19998  available_complete
# 18                   heuristic_full  Rule-based scoring backend (non-LLM)              0   target_qwen_only     full_attack_aware_cale          cale_family_full  19998  available_complete
# 19                   heuristic_full  Rule-based scoring backend (non-LLM)              0   target_qwen_only               generic_cale       cale_family_generic  19998  available_complete
# 17                   heuristic_full  Rule-based scoring backend (non-LLM)              0   target_qwen_only  direct_trustllm_heuristic                    direct  19998  available_complete
# 23        qwen25_7b_llama_limit1000             Qwen2.5-7B local HF judge              1  target_llama_only     full_attack_aware_cale          cale_family_full   1000  available_complete
# 22        qwen25_7b_llama_limit1000             Qwen2.5-7B local HF judge              1  target_llama_only           direct_llm_judge                    direct   1000  available_complete
# 21              qwen25_7b_limit1000             Qwen2.5-7B local HF judge              1   target_qwen_only     full_attack_aware_cale          cale_family_full   1000  available_complete
# 20              qwen25_7b_limit1000             Qwen2.5-7B local HF judge              1   target_qwen_only           direct_llm_judge                    direct   1000  available_complete
# 27        qwen3_14b_llama_limit1000              Qwen3-14B local HF judge              2  target_llama_only     full_attack_aware_cale          cale_family_full   1000  available_complete
# 26        qwen3_14b_llama_limit1000              Qwen3-14B local HF judge              2  target_llama_only           direct_llm_judge                    direct   1000  available_complete
# 25              qwen3_14b_limit1000              Qwen3-14B local HF judge              2   target_qwen_only     full_attack_aware_cale          cale_family_full   1000  available_complete
# 24              qwen3_14b_limit1000              Qwen3-14B local HF judge              2   target_qwen_only           direct_llm_judge                    direct   1000  available_complete
# 7        gemma3_12b_llama_limit1000             Gemma3-12B local HF judge              3  target_llama_only     full_attack_aware_cale          cale_family_full   1000  available_complete
# 6        gemma3_12b_llama_limit1000             Gemma3-12B local HF judge              3  target_llama_only           direct_llm_judge                    direct   1000  available_complete
# 5              gemma3_12b_limit1000             Gemma3-12B local HF judge              3   target_qwen_only     full_attack_aware_cale          cale_family_full   1000  available_complete
# 4              gemma3_12b_limit1000             Gemma3-12B local HF judge              3   target_qwen_only           direct_llm_judge                    direct   1000  available_complete
# 3   deepseek_v4_pro_llama_limit1000             DeepSeek V4-Pro API judge              4  target_llama_only     full_attack_aware_cale          cale_family_full   1000  available_complete
# 2   deepseek_v4_pro_llama_limit1000             DeepSeek V4-Pro API judge              4  target_llama_only           direct_llm_judge                    direct   1000  available_complete
# 1         deepseek_v4_pro_limit1000             DeepSeek V4-Pro API judge              4   target_qwen_only     full_attack_aware_cale          cale_family_full   1000  available_complete
# 0         deepseek_v4_pro_limit1000             DeepSeek V4-Pro API judge              4   target_qwen_only           direct_llm_judge                    direct   1000  available_complete
#
#                                         subset_policy
# 9           full_neutral_fever_qwen_and_llama_targets
# 10          full_neutral_fever_qwen_and_llama_targets
# 8           full_neutral_fever_qwen_and_llama_targets
# 12          full_neutral_fever_qwen_and_llama_targets
# 13          full_neutral_fever_qwen_and_llama_targets
# 11          full_neutral_fever_qwen_and_llama_targets
# 15          full_neutral_fever_qwen_and_llama_targets
# 16          full_neutral_fever_qwen_and_llama_targets
# 14          full_neutral_fever_qwen_and_llama_targets
# 18          full_neutral_fever_qwen_and_llama_targets
# 19          full_neutral_fever_qwen_and_llama_targets
# 17          full_neutral_fever_qwen_and_llama_targets
# 23  matched_limit1000_llama_target_from_fixed_resp...
# 22  matched_limit1000_llama_target_from_fixed_resp...
# 21     limit1000_qwen_target_from_fixed_response_file
# 20     limit1000_qwen_target_from_fixed_response_file
# 27  matched_limit1000_llama_target_from_fixed_resp...
# 26  matched_limit1000_llama_target_from_fixed_resp...
# 25     limit1000_qwen_target_from_fixed_response_file
# 24     limit1000_qwen_target_from_fixed_response_file
# 7   matched_limit1000_llama_target_from_fixed_resp...
# 6   matched_limit1000_llama_target_from_fixed_resp...
# 5      limit1000_qwen_target_from_fixed_response_file
# 4      limit1000_qwen_target_from_fixed_response_file
# 3   matched_limit1000_llama_target_from_fixed_resp...
# 2   matched_limit1000_llama_target_from_fixed_resp...
# 1      limit1000_qwen_target_from_fixed_response_file
# 0      limit1000_qwen_target_from_fixed_response_file

# %% [markdown]
# ## 6. Outcome Summary By Three Layers
#
# Outcome-level summaries can include direct judge and CALE variants. Backend-to-backend absolute scores are descriptive because scoring scales may differ.
#
# Outcome 层可以比较 direct judge 和 CALE variants；但不同 backend 的绝对分数不是 calibrated leaderboard。

# %%
outcome_rows = []
if not combined.empty:
    sc = score_column(combined)
    group_cols = ['run_id', 'evaluator_backend_label', 'subset_policy', 'target_model', 'target_split', 'evaluator_variant']
    for keys, group in combined.groupby(group_cols, dropna=False):
        run_id, backend_label, subset_policy, target_model, target_split, variant = keys
        row = {
            'run_id': run_id,
            'evaluator_backend_label': backend_label,
            'subset_policy': subset_policy,
            'target_model': target_model,
            'target_split': target_split,
            'evaluator_variant': variant,
            'rows': len(group),
        }
        if sc:
            scores = pd.to_numeric(group[sc], errors='coerce')
            row['n_non_null_score'] = int(scores.notna().sum())
            row['score_missing_share'] = float(scores.isna().mean())
            row['mean_final_score'] = scores.mean()
            row['std_final_score'] = scores.std()
        if 'uncertainty' in group.columns:
            uncertainty = pd.to_numeric(group['uncertainty'], errors='coerce')
            row['n_non_null_uncertainty'] = int(uncertainty.notna().sum())
            row['mean_uncertainty'] = uncertainty.mean()
        if 'quality_label' in group.columns:
            labels = group['quality_label']
            row['quality_label_missing_share'] = float(labels.isna().mean())
            row['quality_label_distribution'] = labels.dropna().astype(str).value_counts(normalize=True).round(3).to_dict()
        outcome_rows.append(row)

outcome_summary = pd.DataFrame(outcome_rows)
outcome_summary.to_csv(OUTDIR / 'outcome_summary_three_layers.csv', index=False)
outcome_summary
# Out:
#                              run_id               evaluator_backend_label                                      subset_policy                      target_model       target_split          evaluator_variant   rows  \
# 0         deepseek_v4_pro_limit1000             DeepSeek V4-Pro API judge     limit1000_qwen_target_from_fixed_response_file        Qwen/Qwen2.5-1.5B-Instruct   target_qwen_only           direct_llm_judge   1000
# 1         deepseek_v4_pro_limit1000             DeepSeek V4-Pro API judge     limit1000_qwen_target_from_fixed_response_file        Qwen/Qwen2.5-1.5B-Instruct   target_qwen_only     full_attack_aware_cale   1000
# 2   deepseek_v4_pro_llama_limit1000             DeepSeek V4-Pro API judge  matched_limit1000_llama_target_from_fixed_resp...  meta-llama/Llama-3.2-1B-Instruct  target_llama_only           direct_llm_judge   1000
# 3   deepseek_v4_pro_llama_limit1000             DeepSeek V4-Pro API judge  matched_limit1000_llama_target_from_fixed_resp...  meta-llama/Llama-3.2-1B-Instruct  target_llama_only     full_attack_aware_cale   1000
# 4              gemma3_12b_limit1000             Gemma3-12B local HF judge     limit1000_qwen_target_from_fixed_response_file        Qwen/Qwen2.5-1.5B-Instruct   target_qwen_only           direct_llm_judge   1000
# 5              gemma3_12b_limit1000             Gemma3-12B local HF judge     limit1000_qwen_target_from_fixed_response_file        Qwen/Qwen2.5-1.5B-Instruct   target_qwen_only     full_attack_aware_cale   1000
# 6        gemma3_12b_llama_limit1000             Gemma3-12B local HF judge  matched_limit1000_llama_target_from_fixed_resp...  meta-llama/Llama-3.2-1B-Instruct  target_llama_only           direct_llm_judge   1000
# 7        gemma3_12b_llama_limit1000             Gemma3-12B local HF judge  matched_limit1000_llama_target_from_fixed_resp...  meta-llama/Llama-3.2-1B-Instruct  target_llama_only     full_attack_aware_cale   1000
# 8                    heuristic_full  Rule-based scoring backend (non-LLM)          full_neutral_fever_qwen_and_llama_targets        Qwen/Qwen2.5-1.5B-Instruct   target_qwen_only          attack_aware_cale  19998
# 9                    heuristic_full  Rule-based scoring backend (non-LLM)          full_neutral_fever_qwen_and_llama_targets        Qwen/Qwen2.5-1.5B-Instruct   target_qwen_only            baseline_binary  19998
# 10                   heuristic_full  Rule-based scoring backend (non-LLM)          full_neutral_fever_qwen_and_llama_targets        Qwen/Qwen2.5-1.5B-Instruct   target_qwen_only            baseline_likert  19998
# 11                   heuristic_full  Rule-based scoring backend (non-LLM)          full_neutral_fever_qwen_and_llama_targets        Qwen/Qwen2.5-1.5B-Instruct   target_qwen_only  direct_trustllm_heuristic  19998
# 12                   heuristic_full  Rule-based scoring backend (non-LLM)          full_neutral_fever_qwen_and_llama_targets        Qwen/Qwen2.5-1.5B-Instruct   target_qwen_only     full_attack_aware_cale  19998
# 13                   heuristic_full  Rule-based scoring backend (non-LLM)          full_neutral_fever_qwen_and_llama_targets        Qwen/Qwen2.5-1.5B-Instruct   target_qwen_only               generic_cale  19998
# 14                   heuristic_full  Rule-based scoring backend (non-LLM)          full_neutral_fever_qwen_and_llama_targets  meta-llama/Llama-3.2-1B-Instruct  target_llama_only          attack_aware_cale  19998
# 15                   heuristic_full  Rule-based scoring backend (non-LLM)          full_neutral_fever_qwen_and_llama_targets  meta-llama/Llama-3.2-1B-Instruct  target_llama_only            baseline_binary  19998
# 16                   heuristic_full  Rule-based scoring backend (non-LLM)          full_neutral_fever_qwen_and_llama_targets  meta-llama/Llama-3.2-1B-Instruct  target_llama_only            baseline_likert  19998
# 17                   heuristic_full  Rule-based scoring backend (non-LLM)          full_neutral_fever_qwen_and_llama_targets  meta-llama/Llama-3.2-1B-Instruct  target_llama_only  direct_trustllm_heuristic  19998
# 18                   heuristic_full  Rule-based scoring backend (non-LLM)          full_neutral_fever_qwen_and_llama_targets  meta-llama/Llama-3.2-1B-Instruct  target_llama_only     full_attack_aware_cale  19998
# 19                   heuristic_full  Rule-based scoring backend (non-LLM)          full_neutral_fever_qwen_and_llama_targets  meta-llama/Llama-3.2-1B-Instruct  target_llama_only               generic_cale  19998
# 20              qwen25_7b_limit1000             Qwen2.5-7B local HF judge     limit1000_qwen_target_from_fixed_response_file        Qwen/Qwen2.5-1.5B-Instruct   target_qwen_only           direct_llm_judge   1000
# 21              qwen25_7b_limit1000             Qwen2.5-7B local HF judge     limit1000_qwen_target_from_fixed_response_file        Qwen/Qwen2.5-1.5B-Instruct   target_qwen_only     full_attack_aware_cale   1000
# 22        qwen25_7b_llama_limit1000             Qwen2.5-7B local HF judge  matched_limit1000_llama_target_from_fixed_resp...  meta-llama/Llama-3.2-1B-Instruct  target_llama_only           direct_llm_judge   1000
# 23        qwen25_7b_llama_limit1000             Qwen2.5-7B local HF judge  matched_limit1000_llama_target_from_fixed_resp...  meta-llama/Llama-3.2-1B-Instruct  target_llama_only     full_attack_aware_cale   1000
# 24              qwen3_14b_limit1000              Qwen3-14B local HF judge     limit1000_qwen_target_from_fixed_response_file        Qwen/Qwen2.5-1.5B-Instruct   target_qwen_only           direct_llm_judge   1000
# 25              qwen3_14b_limit1000              Qwen3-14B local HF judge     limit1000_qwen_target_from_fixed_response_file        Qwen/Qwen2.5-1.5B-Instruct   target_qwen_only     full_attack_aware_cale   1000
# 26        qwen3_14b_llama_limit1000              Qwen3-14B local HF judge  matched_limit1000_llama_target_from_fixed_resp...  meta-llama/Llama-3.2-1B-Instruct  target_llama_only           direct_llm_judge   1000
# 27        qwen3_14b_llama_limit1000              Qwen3-14B local HF judge  matched_limit1000_llama_target_from_fixed_resp...  meta-llama/Llama-3.2-1B-Instruct  target_llama_only     full_attack_aware_cale   1000
#
#     n_non_null_score  score_missing_share  mean_final_score  std_final_score  n_non_null_uncertainty  mean_uncertainty  quality_label_missing_share                         quality_label_distribution
# 0               1000                  0.0          0.554628         0.420652                    1000          0.000000                          0.0  {'high_quality': 0.495, 'low_quality': 0.423, ...
# 1               1000                  0.0          0.567655         0.370468                    1000          0.000000                          0.0  {'high_quality': 0.438, 'low_quality': 0.309, ...
# 2               1000                  0.0          0.506976         0.405281                    1000          0.000000                          0.0  {'low_quality': 0.444, 'high_quality': 0.402, ...
# 3               1000                  0.0          0.504180         0.339635                    1000          0.000000                          0.0  {'low_quality': 0.323, 'high_quality': 0.296, ...
# 4               1000                  0.0          0.873892         0.247438                    1000          0.000000                          0.0  {'high_quality': 0.882, 'low_quality': 0.08, '...
# 5               1000                  0.0          0.818129         0.228718                    1000          0.000000                          0.0  {'high_quality': 0.741, 'partial_quality': 0.1...
# 6               1000                  0.0          0.673296         0.397482                    1000          0.000000                          0.0  {'high_quality': 0.639, 'low_quality': 0.297, ...
# 7               1000                  0.0          0.734806         0.267426                    1000          0.000000                          0.0  {'high_quality': 0.584, 'partial_quality': 0.2...
# 8              19998                  0.0          0.780973         0.145095                   19998          0.000000                          0.0  {'high_quality': 0.533, 'partial_quality': 0.4...
# 9              19998                  0.0          0.676876         0.411094                   19998          0.000000                          0.0      {'high_quality': 0.678, 'low_quality': 0.322}
# 10             19998                  0.0          0.814267         0.142379                   19998          0.000000                          0.0  {'high_quality': 0.653, 'partial_quality': 0.3...
# 11             19998                  0.0          0.840255         0.167596                   19998          0.000000                          0.0  {'high_quality': 0.678, 'partial_quality': 0.3...
# 12             19998                  0.0          0.788070         0.145972                   19998          0.008072                          0.0  {'high_quality': 0.557, 'partial_quality': 0.3...
# 13             19998                  0.0          0.779222         0.145181                   19998          0.000000                          0.0  {'high_quality': 0.526, 'partial_quality': 0.4...
# 14             19998                  0.0          0.754493         0.146290                   19998          0.000000                          0.0  {'high_quality': 0.47, 'partial_quality': 0.46...
# 15             19998                  0.0          0.668999         0.414014                   19998          0.000000                          0.0      {'high_quality': 0.669, 'low_quality': 0.331}
# 16             19998                  0.0          0.809904         0.143704                   19998          0.000000                          0.0  {'high_quality': 0.635, 'partial_quality': 0.3...
# 17             19998                  0.0          0.835124         0.169154                   19998          0.000000                          0.0  {'high_quality': 0.669, 'partial_quality': 0.3...
# 18             19998                  0.0          0.761101         0.144942                   19998          0.007280                          0.0  {'high_quality': 0.496, 'partial_quality': 0.4...
# 19             19998                  0.0          0.730796         0.140455                   19998          0.000000                          0.0  {'partial_quality': 0.578, 'high_quality': 0.3...
# 20              1000                  0.0          0.932676         0.150278                    1000          0.000000                          0.0  {'high_quality': 0.967, 'low_quality': 0.029, ...
# 21              1000                  0.0          0.861012         0.182839                    1000          0.000000                          0.0  {'high_quality': 0.787, 'partial_quality': 0.1...
# 22              1000                  0.0          0.659524         0.413844                    1000          0.000000                          0.0  {'high_quality': 0.65, 'low_quality': 0.334, '...
# 23              1000                  0.0          0.760094         0.262250                    1000          0.000000                          0.0  {'high_quality': 0.607, 'partial_quality': 0.2...
# 24              1000                  0.0          0.777884         0.342693                    1000          0.000000                          0.0  {'high_quality': 0.765, 'low_quality': 0.184, ...
# 25              1000                  0.0          0.731534         0.259319                    1000          0.000000                          0.0  {'high_quality': 0.532, 'partial_quality': 0.2...
# 26              1000                  0.0          0.625996         0.404418                    1000          0.000000                          0.0  {'high_quality': 0.566, 'low_quality': 0.335, ...
# 27              1000                  0.0          0.628306         0.277928                    1000          0.000000                          0.0  {'partial_quality': 0.386, 'high_quality': 0.3...

# %%
if not outcome_summary.empty and 'mean_final_score' in outcome_summary.columns:
    score_pivot = outcome_summary.pivot_table(
        index=['run_id', 'evaluator_backend_label', 'target_split', 'target_model'],
        columns='evaluator_variant',
        values='mean_final_score',
        aggfunc='mean',
    )
    score_pivot.to_csv(OUTDIR / 'mean_score_by_run_backend_target_variant.csv')
    save_bar(score_pivot, OUTDIR / 'descriptive_mean_score_not_calibrated_leaderboard.png', 'Descriptive Mean Scores by Run/Backend/Target/Variant (Not a Leaderboard)', ylabel='mean final score')
    print('Descriptive means only, not a calibrated leaderboard. Rows are run x evaluator backend x target model. NaN means this backend/variant/target combination was not run or not in design, not poor performance.')
    display(score_pivot.round(3))
# Out:
# Descriptive means only, not a calibrated leaderboard. Rows are run x evaluator backend x target model. NaN means this backend/variant/target combination was not run or not in design, not poor performance.
# evaluator_variant                                                                                                        attack_aware_cale  baseline_binary  baseline_likert  direct_llm_judge  direct_trustllm_heuristic  \
# run_id                          evaluator_backend_label              target_split      target_model
# deepseek_v4_pro_limit1000       DeepSeek V4-Pro API judge            target_qwen_only  Qwen/Qwen2.5-1.5B-Instruct                      NaN              NaN              NaN             0.555                        NaN
# deepseek_v4_pro_llama_limit1000 DeepSeek V4-Pro API judge            target_llama_only meta-llama/Llama-3.2-1B-Instruct                NaN              NaN              NaN             0.507                        NaN
# gemma3_12b_limit1000            Gemma3-12B local HF judge            target_qwen_only  Qwen/Qwen2.5-1.5B-Instruct                      NaN              NaN              NaN             0.874                        NaN
# gemma3_12b_llama_limit1000      Gemma3-12B local HF judge            target_llama_only meta-llama/Llama-3.2-1B-Instruct                NaN              NaN              NaN             0.673                        NaN
# heuristic_full                  Rule-based scoring backend (non-LLM) target_llama_only meta-llama/Llama-3.2-1B-Instruct              0.754            0.669            0.810               NaN                      0.835
#                                                                      target_qwen_only  Qwen/Qwen2.5-1.5B-Instruct                    0.781            0.677            0.814               NaN                      0.840
# qwen25_7b_limit1000             Qwen2.5-7B local HF judge            target_qwen_only  Qwen/Qwen2.5-1.5B-Instruct                      NaN              NaN              NaN             0.933                        NaN
# qwen25_7b_llama_limit1000       Qwen2.5-7B local HF judge            target_llama_only meta-llama/Llama-3.2-1B-Instruct                NaN              NaN              NaN             0.660                        NaN
# qwen3_14b_limit1000             Qwen3-14B local HF judge             target_qwen_only  Qwen/Qwen2.5-1.5B-Instruct                      NaN              NaN              NaN             0.778                        NaN
# qwen3_14b_llama_limit1000       Qwen3-14B local HF judge             target_llama_only meta-llama/Llama-3.2-1B-Instruct                NaN              NaN              NaN             0.626                        NaN
#
# evaluator_variant                                                                                                        full_attack_aware_cale  generic_cale
# run_id                          evaluator_backend_label              target_split      target_model
# deepseek_v4_pro_limit1000       DeepSeek V4-Pro API judge            target_qwen_only  Qwen/Qwen2.5-1.5B-Instruct                         0.568           NaN
# deepseek_v4_pro_llama_limit1000 DeepSeek V4-Pro API judge            target_llama_only meta-llama/Llama-3.2-1B-Instruct                   0.504           NaN
# gemma3_12b_limit1000            Gemma3-12B local HF judge            target_qwen_only  Qwen/Qwen2.5-1.5B-Instruct                         0.818           NaN
# gemma3_12b_llama_limit1000      Gemma3-12B local HF judge            target_llama_only meta-llama/Llama-3.2-1B-Instruct                   0.735           NaN
# heuristic_full                  Rule-based scoring backend (non-LLM) target_llama_only meta-llama/Llama-3.2-1B-Instruct                   0.761         0.731
#                                                                      target_qwen_only  Qwen/Qwen2.5-1.5B-Instruct                         0.788         0.779
# qwen25_7b_limit1000             Qwen2.5-7B local HF judge            target_qwen_only  Qwen/Qwen2.5-1.5B-Instruct                         0.861           NaN
# qwen25_7b_llama_limit1000       Qwen2.5-7B local HF judge            target_llama_only meta-llama/Llama-3.2-1B-Instruct                   0.760           NaN
# qwen3_14b_limit1000             Qwen3-14B local HF judge             target_qwen_only  Qwen/Qwen2.5-1.5B-Instruct                         0.732           NaN
# qwen3_14b_llama_limit1000       Qwen3-14B local HF judge             target_llama_only meta-llama/Llama-3.2-1B-Instruct                   0.628           NaN

# %% [markdown]
# ## 7. Direct Judge Versus Full CALE Delta
#
# This section compares the backend-specific direct baseline against `full_attack_aware_cale` on shared ids.
#
# 这一节比较的是同一个 backend、同一个 target model 内，backend-specific direct baseline 和 `full_attack_aware_cale` 的差异。
#
# Important: the direct baseline name depends on backend:
#
# - heuristic backend uses `direct_trustllm_heuristic`
# - model-based backends use `direct_llm_judge`
#
# `direct` here means holistic single-label judging with reference information, not CALE's structured construct-level evaluation.
#
# 这里的 `direct` 是“给参考信息后的整体单标签判断”，不是 CALE 的结构化分维度评价。

# %%
paired_tables = []
for run_id, df in matrices.items():
    paired = paired_direct_vs_cale(df)
    if not paired.empty:
        paired_tables.append(paired)

paired_delta_rows = []
if paired_tables:
    paired_all = pd.concat(paired_tables, ignore_index=True)
    paired_all.to_csv(OUTDIR / 'paired_direct_vs_full_cale_rows.csv', index=False)
    for keys, group in paired_all.groupby(['run_id', 'evaluator_backend_label', 'target_model'], dropna=False):
        run_id, backend_label, target_model = keys
        paired_delta_rows.append({
            'run_id': run_id,
            'evaluator_backend_label': backend_label,
            'target_model': target_model,
            'n_shared_ids': len(group),
            'direct_baseline_variant': group['direct_baseline_variant'].iloc[0],
            'direct_mean_score': group['direct_baseline_score'].mean(),
            'full_cale_mean_score': group[FULL_CALE_VARIANT].mean(),
            'full_minus_direct_mean_score': group['full_minus_direct_score'].mean(),
        })

direct_vs_full_delta = pd.DataFrame(paired_delta_rows)
direct_vs_full_delta.to_csv(OUTDIR / 'direct_vs_full_cale_delta.csv', index=False)
direct_vs_full_delta
# Out:
#                             run_id               evaluator_backend_label                      target_model  n_shared_ids    direct_baseline_variant  direct_mean_score  full_cale_mean_score  full_minus_direct_mean_score
# 0        deepseek_v4_pro_limit1000             DeepSeek V4-Pro API judge        Qwen/Qwen2.5-1.5B-Instruct          1000           direct_llm_judge           0.554628              0.567655                      0.013027
# 1  deepseek_v4_pro_llama_limit1000             DeepSeek V4-Pro API judge  meta-llama/Llama-3.2-1B-Instruct          1000           direct_llm_judge           0.506976              0.504180                     -0.002796
# 2             gemma3_12b_limit1000             Gemma3-12B local HF judge        Qwen/Qwen2.5-1.5B-Instruct          1000           direct_llm_judge           0.873892              0.818129                     -0.055763
# 3       gemma3_12b_llama_limit1000             Gemma3-12B local HF judge  meta-llama/Llama-3.2-1B-Instruct          1000           direct_llm_judge           0.673296              0.734806                      0.061510
# 4                   heuristic_full  Rule-based scoring backend (non-LLM)        Qwen/Qwen2.5-1.5B-Instruct         19998  direct_trustllm_heuristic           0.840255              0.788070                     -0.052185
# 5                   heuristic_full  Rule-based scoring backend (non-LLM)  meta-llama/Llama-3.2-1B-Instruct         19998  direct_trustllm_heuristic           0.835124              0.761101                     -0.074023
# 6              qwen25_7b_limit1000             Qwen2.5-7B local HF judge        Qwen/Qwen2.5-1.5B-Instruct          1000           direct_llm_judge           0.932676              0.861012                     -0.071664
# 7        qwen25_7b_llama_limit1000             Qwen2.5-7B local HF judge  meta-llama/Llama-3.2-1B-Instruct          1000           direct_llm_judge           0.659524              0.760094                      0.100570
# 8              qwen3_14b_limit1000              Qwen3-14B local HF judge        Qwen/Qwen2.5-1.5B-Instruct          1000           direct_llm_judge           0.777884              0.731534                     -0.046350
# 9        qwen3_14b_llama_limit1000              Qwen3-14B local HF judge  meta-llama/Llama-3.2-1B-Instruct          1000           direct_llm_judge           0.625996              0.628306                      0.002310

# %% [markdown]
# ## 8. Construct Profile By Backend, Target, And Variant
#
# Construct profiles use CALE behavior columns. Direct judge rows are excluded when they lack construct variables.
#
# Construct profile 使用 CALE behavior columns；没有 construct variables 的 direct judge rows 不进入这一步。
#
# The display table is intentionally split into pooled and target-specific views. Rows are evaluator backend/protocol; columns are target split × construct metric. This prevents the pooled row from hiding whether Qwen-target or Llama-target responses are driving the pattern.
#
# 下面的表会拆成 pooled 和 target-specific views。行是 evaluator backend/protocol，列是 target split × construct metric。这样 pooled 结果不会遮住到底是 Qwen-target 还是 Llama-target 在驱动差异。

# %%
profile_rows = []
if not combined.empty:
    cols = existing_behavior_columns(combined)
    cale_like = combined[combined['evaluator_variant'].isin(CALE_VARIANTS)].copy()
    group_cols = [
        'run_id', 'evaluator_backend_label', 'evaluator_backend_model', 'subset_policy',
        'target_split', 'target_model', 'evaluator_variant', 'variant_role'
    ]
    for keys, group in cale_like.groupby(group_cols, dropna=False):
        run_id, backend_label, backend_model, subset_policy, target_split, target_model, variant, variant_role = keys
        row = {
            'run_id': run_id,
            'evaluator_backend_label': backend_label,
            'evaluator_backend_model': backend_model,
            'subset_policy': subset_policy,
            'target_split': target_split,
            'target_model': target_model,
            'evaluator_variant': variant,
            'variant_role': variant_role,
            'rows': len(group),
        }
        for col in cols:
            row[col] = pd.to_numeric(group[col], errors='coerce').mean()
        profile_rows.append(row)

construct_profile = pd.DataFrame(profile_rows)
construct_profile.to_csv(OUTDIR / 'construct_profile_by_run_backend_target_split_variant.csv', index=False)
construct_profile.to_csv(OUTDIR / 'construct_profile_backend_target_variant.csv', index=False)
construct_profile.head(20)
# Out:
#                              run_id               evaluator_backend_label   evaluator_backend_model                                      subset_policy       target_split                      target_model  \
# 0         deepseek_v4_pro_limit1000             DeepSeek V4-Pro API judge           deepseek-v4-pro     limit1000_qwen_target_from_fixed_response_file   target_qwen_only        Qwen/Qwen2.5-1.5B-Instruct
# 1   deepseek_v4_pro_llama_limit1000             DeepSeek V4-Pro API judge           deepseek-v4-pro  matched_limit1000_llama_target_from_fixed_resp...  target_llama_only  meta-llama/Llama-3.2-1B-Instruct
# 2              gemma3_12b_limit1000             Gemma3-12B local HF judge     google/gemma-3-12b-it     limit1000_qwen_target_from_fixed_response_file   target_qwen_only        Qwen/Qwen2.5-1.5B-Instruct
# 3        gemma3_12b_llama_limit1000             Gemma3-12B local HF judge     google/gemma-3-12b-it  matched_limit1000_llama_target_from_fixed_resp...  target_llama_only  meta-llama/Llama-3.2-1B-Instruct
# 4                    heuristic_full  Rule-based scoring backend (non-LLM)         heuristic/default          full_neutral_fever_qwen_and_llama_targets  target_llama_only  meta-llama/Llama-3.2-1B-Instruct
# 5                    heuristic_full  Rule-based scoring backend (non-LLM)         heuristic/default          full_neutral_fever_qwen_and_llama_targets  target_llama_only  meta-llama/Llama-3.2-1B-Instruct
# 6                    heuristic_full  Rule-based scoring backend (non-LLM)         heuristic/default          full_neutral_fever_qwen_and_llama_targets  target_llama_only  meta-llama/Llama-3.2-1B-Instruct
# 7                    heuristic_full  Rule-based scoring backend (non-LLM)         heuristic/default          full_neutral_fever_qwen_and_llama_targets   target_qwen_only        Qwen/Qwen2.5-1.5B-Instruct
# 8                    heuristic_full  Rule-based scoring backend (non-LLM)         heuristic/default          full_neutral_fever_qwen_and_llama_targets   target_qwen_only        Qwen/Qwen2.5-1.5B-Instruct
# 9                    heuristic_full  Rule-based scoring backend (non-LLM)         heuristic/default          full_neutral_fever_qwen_and_llama_targets   target_qwen_only        Qwen/Qwen2.5-1.5B-Instruct
# 10              qwen25_7b_limit1000             Qwen2.5-7B local HF judge  Qwen/Qwen2.5-7B-Instruct     limit1000_qwen_target_from_fixed_response_file   target_qwen_only        Qwen/Qwen2.5-1.5B-Instruct
# 11        qwen25_7b_llama_limit1000             Qwen2.5-7B local HF judge  Qwen/Qwen2.5-7B-Instruct  matched_limit1000_llama_target_from_fixed_resp...  target_llama_only  meta-llama/Llama-3.2-1B-Instruct
# 12              qwen3_14b_limit1000              Qwen3-14B local HF judge            Qwen/Qwen3-14B     limit1000_qwen_target_from_fixed_response_file   target_qwen_only        Qwen/Qwen2.5-1.5B-Instruct
# 13        qwen3_14b_llama_limit1000              Qwen3-14B local HF judge            Qwen/Qwen3-14B  matched_limit1000_llama_target_from_fixed_resp...  target_llama_only  meta-llama/Llama-3.2-1B-Instruct
#
#          evaluator_variant              variant_role   rows  misinformation_detection  framing_resistance  claim_status_recognition  error_rejection  correction_accuracy  evidence_grounding  source_faithfulness  \
# 0   full_attack_aware_cale          cale_family_full   1000                  0.638000            0.789000                  0.512000         0.621000             0.564000            0.462000             0.478000
# 1   full_attack_aware_cale          cale_family_full   1000                  0.525000            0.685000                  0.451000         0.557000             0.542000            0.348000             0.406000
# 2   full_attack_aware_cale          cale_family_full   1000                  0.842000            0.832000                  0.891000         0.742000             0.744000            0.770000             0.894000
# 3   full_attack_aware_cale          cale_family_full   1000                  0.757000            0.676000                  0.763000         0.532000             0.573000            0.784000             0.865000
# 4        attack_aware_cale  cale_family_attack_aware  19998                  0.283028            0.988549                  0.567057         0.963596             0.432943            0.910491             0.912591
# 5   full_attack_aware_cale          cale_family_full  19998                  0.283028            0.988549                  0.584208         0.963596             0.462336            0.916842             0.917072
# 6             generic_cale       cale_family_generic  19998                  0.283028            0.987249                  0.567057         0.963596             0.432943            0.681168             0.886589
# 7        attack_aware_cale  cale_family_attack_aware  19998                  0.759876            0.999200                  0.572107         0.997650             0.330883            0.877538             0.878788
# 8   full_attack_aware_cale          cale_family_full  19998                  0.759876            0.999200                  0.590859         0.997650             0.368467            0.879148             0.879958
# 9             generic_cale       cale_family_generic  19998                  0.759876            0.999000                  0.572107         0.997650             0.330883            0.862086             0.875388
# 10  full_attack_aware_cale          cale_family_full   1000                  0.782000            0.951000                  0.917000         0.803000             0.860000            0.826000             0.925000
# 11  full_attack_aware_cale          cale_family_full   1000                  0.516000            0.878000                  0.769000         0.636000             0.739000            0.774000             0.839000
# 12  full_attack_aware_cale          cale_family_full   1000                  0.691000            0.799000                  0.767000         0.659000             0.570000            0.644000             0.871000
# 13  full_attack_aware_cale          cale_family_full   1000                  0.463000            0.634000                  0.670000         0.400000             0.482000            0.556000             0.814000
#
#     hallucination_control  uncertainty_handling  nei_uncertainty_failure_proxy  refutes_correction_credit_proxy  supports_status_failure_proxy
# 0                0.445000               0.48100                       0.915152                         0.926254                       0.543807
# 1                0.379000               0.42300                       0.772727                         0.589971                       0.344411
# 2                0.972000               0.90400                       0.266667                         0.988201                       0.060423
# 3                0.977000               0.84300                       0.439394                         0.808260                       0.042296
# 4                0.993949               0.99895                       0.000450                         0.963996                       0.174767
# 5                0.993949               0.99895                       0.000450                         0.968107                       0.145155
# 6                0.993949               0.99920                       0.000450                         0.963996                       0.174767
# 7                0.977798               0.99885                       0.000600                         0.997900                       0.263276
# 8                0.977798               0.99885                       0.000600                         0.998110                       0.208791
# 9                0.977798               0.99915                       0.000600                         0.997900                       0.263276
# 10               0.994000               0.94000                       0.178788                         0.997050                       0.018127
# 11               0.972000               0.84300                       0.430303                         0.964602                       0.084592
# 12               0.899000               0.83600                       0.478788                         0.964602                       0.199396
# 13               0.852000               0.78800                       0.545455                         0.808260                       0.211480

# %%
def local_split_type(split):
    if split == 'pooled_qwen_llama':
        return 'balanced_pooled'
    if split == 'pooled_all_available_targets':
        return 'available_only_pooled'
    if str(split).startswith('target_'):
        return 'target_specific'
    return 'other'


def local_joined_unique(series):
    return ', '.join(sorted(series.dropna().astype(str).unique()))


def local_scope_frames(group):
    frames = []
    observed_splits = set(group['target_split'].dropna().astype(str)) if 'target_split' in group.columns else set()
    if EXPECTED_TARGET_SPLITS <= observed_splits:
        frames.append(('pooled_qwen_llama', group.copy()))
    else:
        frames.append(('pooled_all_available_targets', group.copy()))
    if 'target_split' in group.columns:
        for split_name, split_df in group.groupby('target_split', dropna=False):
            frames.append((split_name, split_df.copy()))
    return frames


full_profile_rows = []
full_cale_construct_profile = pd.DataFrame()
full_cale_construct_profile_compact = pd.DataFrame()
full_cale_target_delta = pd.DataFrame()

if not combined.empty:
    full_combined = combined[combined['evaluator_variant'].eq(FULL_CALE_VARIANT)].copy()
    full_cols = existing_behavior_columns(full_combined)
    if not full_combined.empty and full_cols:
        group_cols = ['evaluator_backend_family', 'evaluator_backend_label', 'evaluator_backend_model', 'evaluator_variant', 'variant_role']
        for keys, group in full_combined.groupby(group_cols, dropna=False):
            backend_family, backend_label, backend_model, variant, variant_role = keys
            for target_scope, split_df in local_scope_frames(group):
                row = {
                    'evaluator_backend_family': backend_family,
                    'evaluator_backend_label': backend_label,
                    'evaluator_backend_model': backend_model,
                    'backend_order': backend_sort_key(backend_label),
                    'evaluator_variant': variant,
                    'variant_role': variant_role,
                    'target_split': target_scope,
                    'split_type': local_split_type(target_scope),
                    'source_run_ids': local_joined_unique(split_df['run_id']) if 'run_id' in split_df.columns else '',
                    'target_models': local_joined_unique(split_df['target_model']) if 'target_model' in split_df.columns else '',
                    'rows': len(split_df),
                }
                for col in full_cols:
                    row[col] = pd.to_numeric(split_df[col], errors='coerce').mean()
                full_profile_rows.append(row)

        full_cale_construct_profile = pd.DataFrame(full_profile_rows)
        full_cale_construct_profile = full_cale_construct_profile.sort_values(
            [c for c in ['backend_order', 'evaluator_variant', 'target_split'] if c in full_cale_construct_profile.columns]
        )
        full_cale_construct_profile.to_csv(OUTDIR / 'full_cale_construct_profile_by_backend_protocol_target_split.csv', index=False)
        full_cale_construct_profile.to_csv(OUTDIR / 'full_cale_construct_profile_by_run_backend_target_split.csv', index=False)

        display_metrics = ['rows'] + [c for c in CORE_BEHAVIOR_COLUMNS if c in full_cale_construct_profile.columns]
        full_cale_construct_profile_compact = full_cale_construct_profile.pivot_table(
            index=['backend_order', 'evaluator_backend_label', 'evaluator_backend_model', 'evaluator_variant'],
            columns='target_split',
            values=display_metrics,
            aggfunc='first',
        )
        if 'backend_order' in full_cale_construct_profile_compact.index.names:
            full_cale_construct_profile_compact = full_cale_construct_profile_compact.sort_index(level='backend_order')
            full_cale_construct_profile_compact.index = full_cale_construct_profile_compact.index.droplevel('backend_order')
        # Put target_split as the outer column level so the display reads as
        # pooled/Qwen-target/Llama-target blocks rather than metric-first blocks.
        full_cale_construct_profile_compact = full_cale_construct_profile_compact.swaplevel(0, 1, axis=1)
        ordered_splits = [c for c in ['pooled_qwen_llama', 'target_qwen_only', 'target_llama_only', 'pooled_all_available_targets'] if c in full_cale_construct_profile_compact.columns.get_level_values(0)]
        if ordered_splits:
            full_cale_construct_profile_compact = full_cale_construct_profile_compact.reindex(ordered_splits, level=0, axis=1)
        full_cale_construct_profile_compact = full_cale_construct_profile_compact.sort_index(axis=1, level=[0, 1], sort_remaining=False)
        full_cale_construct_profile_compact.to_csv(OUTDIR / 'full_cale_construct_profile_compact.csv')
        display(full_cale_construct_profile_compact.round(3))

        heatmap_df = full_cale_construct_profile.copy()
        heatmap_df['row_label'] = heatmap_df['evaluator_backend_label'] + ' | ' + heatmap_df['evaluator_variant'] + ' | ' + heatmap_df['target_split'] + ' (n=' + heatmap_df['rows'].astype(str) + ')'
        heatmap_matrix = heatmap_df.set_index('row_label')[[c for c in full_cols if c in heatmap_df.columns]]
        save_heatmap(heatmap_matrix, OUTDIR / 'full_cale_construct_profile_backend_protocol_target_split_heatmap.png', 'Full CALE Construct Profile by Backend, Protocol, and Target Split')

        delta_rows = []
        metric_cols = [c for c in full_cols if c in full_cale_construct_profile.columns]
        for keys, group in full_cale_construct_profile.groupby(['evaluator_backend_label', 'evaluator_backend_model', 'evaluator_variant'], dropna=False):
            backend_label, backend_model, variant = keys
            by_split = group.set_index('target_split')
            if {'target_qwen_only', 'target_llama_only'} <= set(by_split.index):
                row = {
                    'evaluator_backend_label': backend_label,
                    'evaluator_backend_model': backend_model,
                    'backend_order': backend_sort_key(backend_label),
                    'evaluator_variant': variant,
                    'comparison': 'target_qwen_only_minus_target_llama_only',
                    'qwen_rows': int(by_split.loc['target_qwen_only', 'rows']),
                    'llama_rows': int(by_split.loc['target_llama_only', 'rows']),
                }
                for col in metric_cols:
                    row[col] = by_split.loc['target_qwen_only', col] - by_split.loc['target_llama_only', col]
                delta_rows.append(row)
        full_cale_target_delta = pd.DataFrame(delta_rows)
        full_cale_target_delta.to_csv(OUTDIR / 'full_cale_construct_profile_qwen_minus_llama.csv', index=False)
        if not full_cale_target_delta.empty:
            delta_heatmap = full_cale_target_delta.copy()
            delta_heatmap['row_label'] = delta_heatmap['evaluator_backend_label'] + ' | ' + delta_heatmap['evaluator_variant']
            delta_heatmap = delta_heatmap.set_index('row_label')[[c for c in metric_cols if c in delta_heatmap.columns]]
            save_heatmap(delta_heatmap, OUTDIR / 'full_cale_construct_profile_qwen_minus_llama_heatmap.png', 'Full CALE Construct Profile: Qwen Target Minus Llama Target')
else:
    print('No combined matrix loaded yet.')
# Out:
# target_split                                                                                pooled_qwen_llama                                                                                                  \
#                                                                                      claim_status_recognition correction_accuracy error_rejection evidence_grounding framing_resistance hallucination_control
# evaluator_backend_label              evaluator_backend_model  evaluator_variant
# Rule-based scoring backend (non-LLM) heuristic/default        full_attack_aware_cale                    0.588               0.415           0.981              0.898              0.994                 0.986
# Qwen2.5-7B local HF judge            Qwen/Qwen2.5-7B-Instruct full_attack_aware_cale                    0.843               0.800           0.720              0.800              0.914                 0.983
# Qwen3-14B local HF judge             Qwen/Qwen3-14B           full_attack_aware_cale                    0.718               0.526           0.530              0.600              0.716                 0.876
# Gemma3-12B local HF judge            google/gemma-3-12b-it    full_attack_aware_cale                    0.827               0.658           0.637              0.777              0.754                 0.974
# DeepSeek V4-Pro API judge            deepseek-v4-pro          full_attack_aware_cale                    0.482               0.553           0.589              0.405              0.737                 0.412
#
# target_split                                                                                                                                                         target_llama_only                      \
#                                                                                      misinformation_detection   rows source_faithfulness uncertainty_handling claim_status_recognition correction_accuracy
# evaluator_backend_label              evaluator_backend_model  evaluator_variant
# Rule-based scoring backend (non-LLM) heuristic/default        full_attack_aware_cale                    0.521  39996               0.899                0.999                    0.584               0.462
# Qwen2.5-7B local HF judge            Qwen/Qwen2.5-7B-Instruct full_attack_aware_cale                    0.649   2000               0.882                0.892                    0.769               0.739
# Qwen3-14B local HF judge             Qwen/Qwen3-14B           full_attack_aware_cale                    0.577   2000               0.842                0.812                    0.670               0.482
# Gemma3-12B local HF judge            google/gemma-3-12b-it    full_attack_aware_cale                    0.800   2000               0.880                0.874                    0.763               0.573
# DeepSeek V4-Pro API judge            deepseek-v4-pro          full_attack_aware_cale                    0.582   2000               0.442                0.452                    0.451               0.542
#
# target_split                                                                                                                                                                                                          \
#                                                                                      error_rejection evidence_grounding framing_resistance hallucination_control misinformation_detection   rows source_faithfulness
# evaluator_backend_label              evaluator_backend_model  evaluator_variant
# Rule-based scoring backend (non-LLM) heuristic/default        full_attack_aware_cale           0.964              0.917              0.989                 0.994                    0.283  19998               0.917
# Qwen2.5-7B local HF judge            Qwen/Qwen2.5-7B-Instruct full_attack_aware_cale           0.636              0.774              0.878                 0.972                    0.516   1000               0.839
# Qwen3-14B local HF judge             Qwen/Qwen3-14B           full_attack_aware_cale           0.400              0.556              0.634                 0.852                    0.463   1000               0.814
# Gemma3-12B local HF judge            google/gemma-3-12b-it    full_attack_aware_cale           0.532              0.784              0.676                 0.977                    0.757   1000               0.865
# DeepSeek V4-Pro API judge            deepseek-v4-pro          full_attack_aware_cale           0.557              0.348              0.685                 0.379                    0.525   1000               0.406
#
# target_split                                                                                                      target_qwen_only                                                                            \
#                                                                                      uncertainty_handling claim_status_recognition correction_accuracy error_rejection evidence_grounding framing_resistance
# evaluator_backend_label              evaluator_backend_model  evaluator_variant
# Rule-based scoring backend (non-LLM) heuristic/default        full_attack_aware_cale                0.999                    0.591               0.368           0.998              0.879              0.999
# Qwen2.5-7B local HF judge            Qwen/Qwen2.5-7B-Instruct full_attack_aware_cale                0.843                    0.917               0.860           0.803              0.826              0.951
# Qwen3-14B local HF judge             Qwen/Qwen3-14B           full_attack_aware_cale                0.788                    0.767               0.570           0.659              0.644              0.799
# Gemma3-12B local HF judge            google/gemma-3-12b-it    full_attack_aware_cale                0.843                    0.891               0.744           0.742              0.770              0.832
# DeepSeek V4-Pro API judge            deepseek-v4-pro          full_attack_aware_cale                0.423                    0.512               0.564           0.621              0.462              0.789
#
# target_split
#                                                                                      hallucination_control misinformation_detection   rows source_faithfulness uncertainty_handling
# evaluator_backend_label              evaluator_backend_model  evaluator_variant
# Rule-based scoring backend (non-LLM) heuristic/default        full_attack_aware_cale                 0.978                    0.760  19998               0.880                0.999
# Qwen2.5-7B local HF judge            Qwen/Qwen2.5-7B-Instruct full_attack_aware_cale                 0.994                    0.782   1000               0.925                0.940
# Qwen3-14B local HF judge             Qwen/Qwen3-14B           full_attack_aware_cale                 0.899                    0.691   1000               0.871                0.836
# Gemma3-12B local HF judge            google/gemma-3-12b-it    full_attack_aware_cale                 0.972                    0.842   1000               0.894                0.904
# DeepSeek V4-Pro API judge            deepseek-v4-pro          full_attack_aware_cale                 0.445                    0.638   1000               0.478                0.481

# %% [markdown]
# ## 9. Backend Alignment On Shared Rows
#
# This checks whether different evaluator backends agree on the same target response and evaluator variant. It is backend robustness, not target-model performance.
#
# 这里看不同 evaluator backend 对同一条 target response、同一种 evaluator variant 是否一致。

# %%
alignment_rows = []
if not combined.empty:
    sc = score_column(combined)
    if sc and 'id' in combined.columns:
        align_cols = ['run_id', 'evaluator_backend_label', 'target_model', 'target_split', 'id', 'evaluator_variant', sc]
        if 'dataset' in combined.columns:
            align_cols.insert(2, 'dataset')
        align = combined[align_cols].copy()
        align[sc] = pd.to_numeric(align[sc], errors='coerce')

        scopes = [('pooled_all_available_targets', align)]
        if 'target_split' in align.columns:
            observed_splits = set(align['target_split'].dropna().astype(str))
            if EXPECTED_TARGET_SPLITS <= observed_splits:
                scopes[0] = ('pooled_qwen_llama', align)
            scopes.extend(list(align.groupby('target_split', dropna=False)))

        for target_scope, scope_df in scopes:
            index_cols = ['target_model', 'id', 'evaluator_variant']
            if 'dataset' in scope_df.columns:
                index_cols.insert(1, 'dataset')
            for variant, variant_df in scope_df.groupby('evaluator_variant', dropna=False):
                wide = variant_df.pivot_table(index=index_cols, columns='evaluator_backend_label', values=sc, aggfunc='mean')
                for left, right in itertools.combinations(wide.columns, 2):
                    pair = wide[[left, right]].dropna()
                    if len(pair) < 3:
                        continue
                    alignment_rows.append({
                        'target_split': target_scope,
                        'evaluator_variant': variant,
                        'backend_left': left,
                        'backend_right': right,
                        'n_shared_rows': len(pair),
                        'pearson': pair[left].corr(pair[right], method='pearson'),
                        'spearman': pair[left].corr(pair[right], method='spearman'),
                        'mae': (pair[left] - pair[right]).abs().mean(),
                        'mean_signed_difference_left_minus_right': (pair[left] - pair[right]).mean(),
                        'index_columns': ', '.join(index_cols),
                    })

backend_alignment = pd.DataFrame(alignment_rows)
backend_alignment.to_csv(OUTDIR / 'backend_pair_score_alignment.csv', index=False)
backend_alignment.to_csv(OUTDIR / 'backend_pair_score_alignment_by_target_split.csv', index=False)
backend_alignment
# Out:
#          target_split       evaluator_variant               backend_left                         backend_right  n_shared_rows   pearson  spearman       mae  mean_signed_difference_left_minus_right  \
# 0   pooled_qwen_llama        direct_llm_judge  DeepSeek V4-Pro API judge             Gemma3-12B local HF judge           2000  0.345082  0.356549  0.316844                                -0.242792
# 1   pooled_qwen_llama        direct_llm_judge  DeepSeek V4-Pro API judge             Qwen2.5-7B local HF judge           2000  0.217484  0.221900  0.363110                                -0.265298
# 2   pooled_qwen_llama        direct_llm_judge  DeepSeek V4-Pro API judge              Qwen3-14B local HF judge           2000  0.465627  0.467989  0.261602                                -0.171138
# 3   pooled_qwen_llama        direct_llm_judge  Gemma3-12B local HF judge             Qwen2.5-7B local HF judge           2000  0.586119  0.578029  0.122386                                -0.022506
# 4   pooled_qwen_llama        direct_llm_judge  Gemma3-12B local HF judge              Qwen3-14B local HF judge           2000  0.522854  0.517019  0.167838                                 0.071654
# 5   pooled_qwen_llama        direct_llm_judge  Qwen2.5-7B local HF judge              Qwen3-14B local HF judge           2000  0.324002  0.322091  0.228316                                 0.094160
# 6   pooled_qwen_llama  full_attack_aware_cale  DeepSeek V4-Pro API judge             Gemma3-12B local HF judge           2000  0.235956  0.166107  0.342800                                -0.240550
# 7   pooled_qwen_llama  full_attack_aware_cale  DeepSeek V4-Pro API judge             Qwen2.5-7B local HF judge           2000  0.157008  0.073750  0.359401                                -0.274635
# 8   pooled_qwen_llama  full_attack_aware_cale  DeepSeek V4-Pro API judge              Qwen3-14B local HF judge           2000  0.317260  0.295807  0.306193                                -0.144003
# 9   pooled_qwen_llama  full_attack_aware_cale  DeepSeek V4-Pro API judge  Rule-based scoring backend (non-LLM)           2000  0.311919  0.311077  0.326916                                -0.237579
# 10  pooled_qwen_llama  full_attack_aware_cale  Gemma3-12B local HF judge             Qwen2.5-7B local HF judge           2000  0.656797  0.685252  0.116543                                -0.034085
# 11  pooled_qwen_llama  full_attack_aware_cale  Gemma3-12B local HF judge              Qwen3-14B local HF judge           2000  0.742206  0.724144  0.131215                                 0.096547
# 12  pooled_qwen_llama  full_attack_aware_cale  Gemma3-12B local HF judge  Rule-based scoring backend (non-LLM)           2000  0.422146  0.452514  0.173672                                 0.002971
# 13  pooled_qwen_llama  full_attack_aware_cale  Qwen2.5-7B local HF judge              Qwen3-14B local HF judge           2000  0.577140  0.625716  0.176978                                 0.130633
# 14  pooled_qwen_llama  full_attack_aware_cale  Qwen2.5-7B local HF judge  Rule-based scoring backend (non-LLM)           2000  0.474055  0.485944  0.152506                                 0.037056
# 15  pooled_qwen_llama  full_attack_aware_cale   Qwen3-14B local HF judge  Rule-based scoring backend (non-LLM)           2000  0.416156  0.437920  0.201968                                -0.093576
# 16  target_llama_only        direct_llm_judge  DeepSeek V4-Pro API judge             Gemma3-12B local HF judge           1000  0.400916  0.408967  0.291368                                -0.166320
# 17  target_llama_only        direct_llm_judge  DeepSeek V4-Pro API judge             Qwen2.5-7B local HF judge           1000  0.280906  0.284155  0.335852                                -0.152548
# 18  target_llama_only        direct_llm_judge  DeepSeek V4-Pro API judge              Qwen3-14B local HF judge           1000  0.461634  0.460424  0.262636                                -0.119020
# 19  target_llama_only        direct_llm_judge  Gemma3-12B local HF judge             Qwen2.5-7B local HF judge           1000  0.585865  0.583388  0.169532                                 0.013772
# 20  target_llama_only        direct_llm_judge  Gemma3-12B local HF judge              Qwen3-14B local HF judge           1000  0.513188  0.502843  0.202268                                 0.047300
# 21  target_llama_only        direct_llm_judge  Qwen2.5-7B local HF judge              Qwen3-14B local HF judge           1000  0.311859  0.307707  0.285032                                 0.033528
# 22  target_llama_only  full_attack_aware_cale  DeepSeek V4-Pro API judge             Gemma3-12B local HF judge           1000  0.264028  0.154142  0.340360                                -0.230626
# 23  target_llama_only  full_attack_aware_cale  DeepSeek V4-Pro API judge             Qwen2.5-7B local HF judge           1000  0.153520  0.056693  0.366542                                -0.255914
# 24  target_llama_only  full_attack_aware_cale  DeepSeek V4-Pro API judge              Qwen3-14B local HF judge           1000  0.320689  0.275450  0.301474                                -0.124126
# 25  target_llama_only  full_attack_aware_cale  DeepSeek V4-Pro API judge  Rule-based scoring backend (non-LLM)           1000  0.211656  0.226957  0.346681                                -0.256131
# 26  target_llama_only  full_attack_aware_cale  Gemma3-12B local HF judge             Qwen2.5-7B local HF judge           1000  0.597619  0.598686  0.151122                                -0.025288
# 27  target_llama_only  full_attack_aware_cale  Gemma3-12B local HF judge              Qwen3-14B local HF judge           1000  0.715963  0.663139  0.153264                                 0.106500
# 28  target_llama_only  full_attack_aware_cale  Gemma3-12B local HF judge  Rule-based scoring backend (non-LLM)           1000  0.421976  0.418624  0.190977                                -0.025505
# 29  target_llama_only  full_attack_aware_cale  Qwen2.5-7B local HF judge              Qwen3-14B local HF judge           1000  0.533556  0.566622  0.204486                                 0.131788
# 30  target_llama_only  full_attack_aware_cale  Qwen2.5-7B local HF judge  Rule-based scoring backend (non-LLM)           1000  0.486796  0.489299  0.170001                                -0.000217
# 31  target_llama_only  full_attack_aware_cale   Qwen3-14B local HF judge  Rule-based scoring backend (non-LLM)           1000  0.379281  0.378665  0.226895                                -0.132005
# 32   target_qwen_only        direct_llm_judge  DeepSeek V4-Pro API judge             Gemma3-12B local HF judge           1000  0.282579  0.296147  0.342320                                -0.319264
# 33   target_qwen_only        direct_llm_judge  DeepSeek V4-Pro API judge             Qwen2.5-7B local HF judge           1000  0.119521  0.118654  0.390368                                -0.378048
# 34   target_qwen_only        direct_llm_judge  DeepSeek V4-Pro API judge              Qwen3-14B local HF judge           1000  0.472180  0.481517  0.260568                                -0.223256
# 35   target_qwen_only        direct_llm_judge  Gemma3-12B local HF judge             Qwen2.5-7B local HF judge           1000  0.378718  0.371617  0.075240                                -0.058784
# 36   target_qwen_only        direct_llm_judge  Gemma3-12B local HF judge              Qwen3-14B local HF judge           1000  0.478935  0.486430  0.133408                                 0.096008
# 37   target_qwen_only        direct_llm_judge  Qwen2.5-7B local HF judge              Qwen3-14B local HF judge           1000  0.219449  0.219649  0.171600                                 0.154792
# 38   target_qwen_only  full_attack_aware_cale  DeepSeek V4-Pro API judge             Gemma3-12B local HF judge           1000  0.187092  0.176594  0.345240                                -0.250474
# 39   target_qwen_only  full_attack_aware_cale  DeepSeek V4-Pro API judge             Qwen2.5-7B local HF judge           1000  0.133929  0.065596  0.352261                                -0.293357
# 40   target_qwen_only  full_attack_aware_cale  DeepSeek V4-Pro API judge              Qwen3-14B local HF judge           1000  0.295772  0.314274  0.310913                                -0.163879
# 41   target_qwen_only  full_attack_aware_cale  DeepSeek V4-Pro API judge  Rule-based scoring backend (non-LLM)           1000  0.391963  0.383833  0.307151                                -0.219027
# 42   target_qwen_only  full_attack_aware_cale  Gemma3-12B local HF judge             Qwen2.5-7B local HF judge           1000  0.732753  0.764357  0.081965                                -0.042883
# 43   target_qwen_only  full_attack_aware_cale  Gemma3-12B local HF judge              Qwen3-14B local HF judge           1000  0.758437  0.779472  0.109167                                 0.086595
# 44   target_qwen_only  full_attack_aware_cale  Gemma3-12B local HF judge  Rule-based scoring backend (non-LLM)           1000  0.409158  0.503939  0.156367                                 0.031447
# 45   target_qwen_only  full_attack_aware_cale  Qwen2.5-7B local HF judge              Qwen3-14B local HF judge           1000  0.613203  0.661893  0.149470                                 0.129478
# 46   target_qwen_only  full_attack_aware_cale  Qwen2.5-7B local HF judge  Rule-based scoring backend (non-LLM)           1000  0.459332  0.497484  0.135012                                 0.074330
# 47   target_qwen_only  full_attack_aware_cale   Qwen3-14B local HF judge  Rule-based scoring backend (non-LLM)           1000  0.438910  0.523061  0.177042                                -0.055148
#
#                                    index_columns
# 0   target_model, dataset, id, evaluator_variant
# 1   target_model, dataset, id, evaluator_variant
# 2   target_model, dataset, id, evaluator_variant
# 3   target_model, dataset, id, evaluator_variant
# 4   target_model, dataset, id, evaluator_variant
# 5   target_model, dataset, id, evaluator_variant
# 6   target_model, dataset, id, evaluator_variant
# 7   target_model, dataset, id, evaluator_variant
# 8   target_model, dataset, id, evaluator_variant
# 9   target_model, dataset, id, evaluator_variant
# 10  target_model, dataset, id, evaluator_variant
# 11  target_model, dataset, id, evaluator_variant
# 12  target_model, dataset, id, evaluator_variant
# 13  target_model, dataset, id, evaluator_variant
# 14  target_model, dataset, id, evaluator_variant
# 15  target_model, dataset, id, evaluator_variant
# 16  target_model, dataset, id, evaluator_variant
# 17  target_model, dataset, id, evaluator_variant
# 18  target_model, dataset, id, evaluator_variant
# 19  target_model, dataset, id, evaluator_variant
# 20  target_model, dataset, id, evaluator_variant
# 21  target_model, dataset, id, evaluator_variant
# 22  target_model, dataset, id, evaluator_variant
# 23  target_model, dataset, id, evaluator_variant
# 24  target_model, dataset, id, evaluator_variant
# 25  target_model, dataset, id, evaluator_variant
# 26  target_model, dataset, id, evaluator_variant
# 27  target_model, dataset, id, evaluator_variant
# 28  target_model, dataset, id, evaluator_variant
# 29  target_model, dataset, id, evaluator_variant
# 30  target_model, dataset, id, evaluator_variant
# 31  target_model, dataset, id, evaluator_variant
# 32  target_model, dataset, id, evaluator_variant
# 33  target_model, dataset, id, evaluator_variant
# 34  target_model, dataset, id, evaluator_variant
# 35  target_model, dataset, id, evaluator_variant
# 36  target_model, dataset, id, evaluator_variant
# 37  target_model, dataset, id, evaluator_variant
# 38  target_model, dataset, id, evaluator_variant
# 39  target_model, dataset, id, evaluator_variant
# 40  target_model, dataset, id, evaluator_variant
# 41  target_model, dataset, id, evaluator_variant
# 42  target_model, dataset, id, evaluator_variant
# 43  target_model, dataset, id, evaluator_variant
# 44  target_model, dataset, id, evaluator_variant
# 45  target_model, dataset, id, evaluator_variant
# 46  target_model, dataset, id, evaluator_variant
# 47  target_model, dataset, id, evaluator_variant

# %% [markdown]
# ## 10. Target-Model Dominance Check
#
# For each evaluator backend, this section combines all available matched run files, then reruns PCA on `full_attack_aware_cale` rows for pooled Qwen+Llama targets and for each target split. If a backend only has one target split, the notebook labels that as available-only evidence instead of pretending it is balanced pooled evidence.
#
# 这里会先按 evaluator backend 合并可用的 matched run files，再只用 `full_attack_aware_cale` 做 PCA。只有同时有 Qwen 和 Llama target 时才显示 `pooled_qwen_llama`；否则不会假装它是 balanced pooled evidence。

# %%
pca_rows = []
pca_loading_rows = []

if not combined.empty and 'evaluator_variant' in combined.columns:
    full_all = combined[combined['evaluator_variant'].eq(FULL_CALE_VARIANT)].copy()
else:
    full_all = pd.DataFrame()

if not full_all.empty:
    group_cols = ['evaluator_backend_label', 'evaluator_backend_model']
    for keys, backend_full in full_all.groupby(group_cols, dropna=False):
        backend_label, backend_model = keys
        run_ids = ', '.join(sorted(backend_full['run_id'].dropna().astype(str).unique())) if 'run_id' in backend_full.columns else ''
        split_frames = []
        observed_splits = set(backend_full['target_split'].dropna().astype(str)) if 'target_split' in backend_full.columns else set()
        if EXPECTED_TARGET_SPLITS <= observed_splits:
            split_frames.append(('pooled_qwen_llama', backend_full.copy()))
        else:
            split_frames.append(('pooled_all_available_targets', backend_full.copy()))
        for split_name, split_df in backend_full.groupby('target_split', dropna=False):
            split_frames.append((split_name, split_df.copy()))

        for split_name, split_df in split_frames:
            if len(split_df) < 5:
                pca_rows.append({
                    'evaluator_backend_label': backend_label,
                    'evaluator_backend_model': backend_model,
                    'backend_order': backend_sort_key(backend_label),
                    'source_run_ids': run_ids,
                    'target_split': split_name,
                    'rows': len(split_df),
                    'error': 'too few rows for PCA',
                })
                continue
            try:
                row, loadings, variance, scores = run_pca_summary(split_df, run_ids, backend_label, split_name)
            except ValueError as exc:
                pca_rows.append({
                    'evaluator_backend_label': backend_label,
                    'evaluator_backend_model': backend_model,
                    'backend_order': backend_sort_key(backend_label),
                    'source_run_ids': run_ids,
                    'target_split': split_name,
                    'rows': len(split_df),
                    'error': str(exc),
                })
                continue
            row['evaluator_backend_model'] = backend_model
            row['backend_order'] = backend_sort_key(backend_label)
            row['source_run_ids'] = run_ids
            pca_rows.append(row)
            safe_backend = str(backend_model).replace('/', '_').replace(' ', '_').replace(':', '_')
            safe_split = str(split_name).replace('/', '_').replace(' ', '_')
            loadings.to_csv(OUTDIR / f'{safe_backend}_{safe_split}_full_cale_pca_loadings.csv')
            variance.to_csv(OUTDIR / f'{safe_backend}_{safe_split}_full_cale_pca_explained_variance.csv', index=False)
            pca_loading_rows.extend(top_loading_records(loadings, run_ids, backend_label, split_name))

target_model_dominance_pca = pd.DataFrame(pca_rows)
target_model_dominance_loadings = pd.DataFrame(pca_loading_rows)
target_model_dominance_pca.to_csv(OUTDIR / 'target_model_dominance_pca_summary.csv', index=False)
target_model_dominance_loadings.to_csv(OUTDIR / 'target_model_dominance_pca_top_loadings.csv', index=False)
target_model_dominance_pca
# Out:
#                                                run_id               evaluator_backend_label       target_split   rows                                       columns_used  n_columns_used  pc1_variance  \
# 0   deepseek_v4_pro_limit1000, deepseek_v4_pro_lla...             DeepSeek V4-Pro API judge  pooled_qwen_llama   2000  claim_status_recognition, correction_accuracy,...               9      0.684073
# 1   deepseek_v4_pro_limit1000, deepseek_v4_pro_lla...             DeepSeek V4-Pro API judge  target_llama_only   1000  claim_status_recognition, correction_accuracy,...               9      0.619031
# 2   deepseek_v4_pro_limit1000, deepseek_v4_pro_lla...             DeepSeek V4-Pro API judge   target_qwen_only   1000  claim_status_recognition, correction_accuracy,...               9      0.747406
# 3    gemma3_12b_limit1000, gemma3_12b_llama_limit1000             Gemma3-12B local HF judge  pooled_qwen_llama   2000  claim_status_recognition, correction_accuracy,...               9      0.556066
# 4    gemma3_12b_limit1000, gemma3_12b_llama_limit1000             Gemma3-12B local HF judge  target_llama_only   1000  claim_status_recognition, correction_accuracy,...               9      0.556990
# 5    gemma3_12b_limit1000, gemma3_12b_llama_limit1000             Gemma3-12B local HF judge   target_qwen_only   1000  claim_status_recognition, correction_accuracy,...               9      0.555831
# 6      qwen25_7b_limit1000, qwen25_7b_llama_limit1000             Qwen2.5-7B local HF judge  pooled_qwen_llama   2000  claim_status_recognition, correction_accuracy,...               9      0.547839
# 7      qwen25_7b_limit1000, qwen25_7b_llama_limit1000             Qwen2.5-7B local HF judge  target_llama_only   1000  claim_status_recognition, correction_accuracy,...               9      0.572668
# 8      qwen25_7b_limit1000, qwen25_7b_llama_limit1000             Qwen2.5-7B local HF judge   target_qwen_only   1000  claim_status_recognition, correction_accuracy,...               9      0.487596
# 9      qwen3_14b_limit1000, qwen3_14b_llama_limit1000              Qwen3-14B local HF judge  pooled_qwen_llama   2000  claim_status_recognition, correction_accuracy,...               9      0.483693
# 10     qwen3_14b_limit1000, qwen3_14b_llama_limit1000              Qwen3-14B local HF judge  target_llama_only   1000  claim_status_recognition, correction_accuracy,...               9      0.475180
# 11     qwen3_14b_limit1000, qwen3_14b_llama_limit1000              Qwen3-14B local HF judge   target_qwen_only   1000  claim_status_recognition, correction_accuracy,...               9      0.480979
# 12                                     heuristic_full  Rule-based scoring backend (non-LLM)  pooled_qwen_llama  39996  claim_status_recognition, correction_accuracy,...              10      0.252005
# 13                                     heuristic_full  Rule-based scoring backend (non-LLM)  target_llama_only  19998  claim_status_recognition, correction_accuracy,...              10      0.245378
# 14                                     heuristic_full  Rule-based scoring backend (non-LLM)   target_qwen_only  19998  claim_status_recognition, correction_accuracy,...              10      0.262935
#
#     pc1_pc4_cumulative_variance                                  pc1_top_variables                                  pc2_top_variables   evaluator_backend_model  backend_order  \
# 0                      0.908627  source_faithfulness, evidence_grounding, claim...  framing_resistance, misinformation_detection, ...           deepseek-v4-pro              4
# 1                      0.881871  source_faithfulness, uncertainty_handling, cla...  error_rejection, misinformation_detection, fra...           deepseek-v4-pro              4
# 2                      0.936992  evidence_grounding, source_faithfulness, claim...  framing_resistance, misinformation_detection, ...           deepseek-v4-pro              4
# 3                      0.851869  claim_status_recognition, uncertainty_handling...  hallucination_control, error_rejection, eviden...     google/gemma-3-12b-it              3
# 4                      0.849669  claim_status_recognition, framing_resistance, ...  hallucination_control, error_rejection, eviden...     google/gemma-3-12b-it              3
# 5                      0.860348  uncertainty_handling, claim_status_recognition...  hallucination_control, evidence_grounding, err...     google/gemma-3-12b-it              3
# 6                      0.831042  uncertainty_handling, claim_status_recognition...  misinformation_detection, hallucination_contro...  Qwen/Qwen2.5-7B-Instruct              1
# 7                      0.854915  uncertainty_handling, claim_status_recognition...  misinformation_detection, hallucination_contro...  Qwen/Qwen2.5-7B-Instruct              1
# 8                      0.797747  uncertainty_handling, claim_status_recognition...  error_rejection, misinformation_detection, evi...  Qwen/Qwen2.5-7B-Instruct              1
# 9                      0.836770  claim_status_recognition, correction_accuracy,...  misinformation_detection, error_rejection, sou...            Qwen/Qwen3-14B              2
# 10                     0.821132  claim_status_recognition, framing_resistance, ...  misinformation_detection, error_rejection, sou...            Qwen/Qwen3-14B              2
# 11                     0.857404  claim_status_recognition, correction_accuracy,...  misinformation_detection, error_rejection, hal...            Qwen/Qwen3-14B              2
# 12                     0.649787  source_faithfulness, evidence_grounding, claim...  error_rejection, framing_resistance, correctio...         heuristic/default              0
# 13                     0.656612  source_faithfulness, evidence_grounding, claim...  framing_resistance, error_rejection, claim_sta...         heuristic/default              0
# 14                     0.641815  source_faithfulness, evidence_grounding, claim...  error_rejection, framing_resistance, misinform...         heuristic/default              0
#
#                                        source_run_ids
# 0   deepseek_v4_pro_limit1000, deepseek_v4_pro_lla...
# 1   deepseek_v4_pro_limit1000, deepseek_v4_pro_lla...
# 2   deepseek_v4_pro_limit1000, deepseek_v4_pro_lla...
# 3    gemma3_12b_limit1000, gemma3_12b_llama_limit1000
# 4    gemma3_12b_limit1000, gemma3_12b_llama_limit1000
# 5    gemma3_12b_limit1000, gemma3_12b_llama_limit1000
# 6      qwen25_7b_limit1000, qwen25_7b_llama_limit1000
# 7      qwen25_7b_limit1000, qwen25_7b_llama_limit1000
# 8      qwen25_7b_limit1000, qwen25_7b_llama_limit1000
# 9      qwen3_14b_limit1000, qwen3_14b_llama_limit1000
# 10     qwen3_14b_limit1000, qwen3_14b_llama_limit1000
# 11     qwen3_14b_limit1000, qwen3_14b_llama_limit1000
# 12                                     heuristic_full
# 13                                     heuristic_full
# 14                                     heuristic_full

# %%
if not target_model_dominance_pca.empty and 'pc1_pc4_cumulative_variance' in target_model_dominance_pca.columns:
    dominance_var = target_model_dominance_pca.pivot_table(
        index=['backend_order', 'evaluator_backend_label', 'evaluator_backend_model', 'source_run_ids'],
        columns='target_split',
        values='pc1_pc4_cumulative_variance',
        aggfunc='first',
    )
    if 'backend_order' in dominance_var.index.names:
        dominance_var = dominance_var.sort_index(level='backend_order')
        dominance_var.index = dominance_var.index.droplevel('backend_order')
    dominance_var.to_csv(OUTDIR / 'target_model_dominance_variance_pivot.csv')
    save_annotated_heatmap(dominance_var, OUTDIR / 'target_model_dominance_variance.png', 'PC1-PC4 Variance by Backend and Target-Model Split', vmin=0, vmax=1)
    display(dominance_var.round(3))

    dominance_pc1 = target_model_dominance_pca.pivot_table(
        index=['backend_order', 'evaluator_backend_label', 'evaluator_backend_model', 'source_run_ids'],
        columns='target_split',
        values='pc1_variance',
        aggfunc='first',
    )
    if 'backend_order' in dominance_pc1.index.names:
        dominance_pc1 = dominance_pc1.sort_index(level='backend_order')
        dominance_pc1.index = dominance_pc1.index.droplevel('backend_order')
    dominance_pc1.to_csv(OUTDIR / 'target_model_dominance_pc1_variance_pivot.csv')
    save_annotated_heatmap(dominance_pc1, OUTDIR / 'target_model_dominance_pc1_variance.png', 'PC1 Variance by Backend and Target-Model Split', vmin=0, vmax=1)
    display(dominance_pc1.round(3))
# Out:
# target_split                                                                                                      pooled_qwen_llama  target_llama_only  target_qwen_only
# evaluator_backend_label              evaluator_backend_model  source_run_ids
# Rule-based scoring backend (non-LLM) heuristic/default        heuristic_full                                                  0.650              0.657             0.642
# Qwen2.5-7B local HF judge            Qwen/Qwen2.5-7B-Instruct qwen25_7b_limit1000, qwen25_7b_llama_limit1000                  0.831              0.855             0.798
# Qwen3-14B local HF judge             Qwen/Qwen3-14B           qwen3_14b_limit1000, qwen3_14b_llama_limit1000                  0.837              0.821             0.857
# Gemma3-12B local HF judge            google/gemma-3-12b-it    gemma3_12b_limit1000, gemma3_12b_llama_limit1000                0.852              0.850             0.860
# DeepSeek V4-Pro API judge            deepseek-v4-pro          deepseek_v4_pro_limit1000, deepseek_v4_pro_llam...              0.909              0.882             0.937
# target_split                                                                                                      pooled_qwen_llama  target_llama_only  target_qwen_only
# evaluator_backend_label              evaluator_backend_model  source_run_ids
# Rule-based scoring backend (non-LLM) heuristic/default        heuristic_full                                                  0.252              0.245             0.263
# Qwen2.5-7B local HF judge            Qwen/Qwen2.5-7B-Instruct qwen25_7b_limit1000, qwen25_7b_llama_limit1000                  0.548              0.573             0.488
# Qwen3-14B local HF judge             Qwen/Qwen3-14B           qwen3_14b_limit1000, qwen3_14b_llama_limit1000                  0.484              0.475             0.481
# Gemma3-12B local HF judge            google/gemma-3-12b-it    gemma3_12b_limit1000, gemma3_12b_llama_limit1000                0.556              0.557             0.556
# DeepSeek V4-Pro API judge            deepseek-v4-pro          deepseek_v4_pro_limit1000, deepseek_v4_pro_llam...              0.684              0.619             0.747

# %% [markdown]
# ## 11. Protocol-Level Latent-Structure Audit
#
# This section brings the weaker/control evaluator protocols into the same latent-structure audit. It does **not** ask which evaluator is best. It asks whether behavior variables become more or less low-dimensional under different scoring protocols and backends.
#
# 这里把之前差一点的 evaluator/protocol 也纳入同一个 PCA audit：heuristic 的 baseline/direct/generic/attack/full，以及 Qwen7B/DeepSeek 的 direct/full。它不是排行榜，而是在看不同 backend/protocol 下，behavior matrix 的 latent structure 是否稳定、是否过度单轴化。
#
# Interpretation guardrails:
#
# - High PC1 variance means the measured behavior variables are more concentrated on one dominant axis; it does not automatically mean the evaluator is better.
# - PC1 is refit separately for every backend/protocol/split, so compare variance concentration and top-loading variable clusters, not raw PC signs.
# - The heuristic full run has much more data than the strong-evaluator `limit1000` subsets; use `rows` and `subset_policy` when writing claims.
#
# 解释边界：PC1 高不等于 evaluator 更好；不同组的 PC1 是分别 fit 的；heuristic 是 full sample，strong evaluator 是 limit1000 subset，写结论时必须带上这个限制。

# %%
VARIANT_ORDER = {
    'baseline_binary': 0,
    'baseline_likert': 1,
    'direct_trustllm_heuristic': 2,
    'direct_llm_judge': 2,
    'generic_cale': 3,
    'attack_aware_cale': 4,
    'full_attack_aware_cale': 5,
}

BACKEND_COLORS = {
    'Rule-based scoring backend (non-LLM)': '#6f6f6f',
    'Qwen2.5-7B local HF judge': '#1f77b4',
    'Qwen3-14B local HF judge': '#ff7f0e',
    'Gemma3-12B local HF judge': '#9467bd',
    'DeepSeek V4-Pro API judge': '#2ca02c',
}


def backend_short(label):
    return short_backend_label(label)


def split_type(split):
    if split == 'pooled_qwen_llama':
        return 'balanced_pooled'
    if split == 'pooled_all_available_targets':
        return 'available_only_pooled'
    if str(split).startswith('target_'):
        return 'target_specific'
    return 'other'


def protocol_scope_frames(group):
    frames = []
    observed_splits = set(group['target_split'].dropna().astype(str)) if 'target_split' in group.columns else set()
    if EXPECTED_TARGET_SPLITS <= observed_splits:
        frames.append(('pooled_qwen_llama', group.copy()))
    else:
        frames.append(('pooled_all_available_targets', group.copy()))
    if 'target_split' in group.columns:
        for split_name, split_df in group.groupby('target_split', dropna=False):
            frames.append((split_name, split_df.copy()))
    return frames


def joined_unique(series):
    return ', '.join(sorted(series.dropna().astype(str).unique()))


protocol_pca_rows = []
protocol_pca_loading_rows = []

if not combined.empty:
    # Combine matched files by backend + protocol before PCA. This lets Qwen-target
    # and Llama-target limit1000 strong-evaluator runs form a real pooled split.
    group_cols = ['evaluator_backend_label', 'evaluator_backend_model', 'evaluator_variant', 'variant_role']
    for keys, group in combined.groupby(group_cols, dropna=False):
        backend_label, backend_model, variant, variant_role = keys
        source_run_ids = joined_unique(group['run_id']) if 'run_id' in group.columns else ''
        subset_policies = joined_unique(group['subset_policy']) if 'subset_policy' in group.columns else ''
        for split_name, split_df in protocol_scope_frames(group):
            row_base = {
                'run_id': source_run_ids,
                'source_run_ids': source_run_ids,
                'evaluator_backend_label': backend_label,
                'evaluator_backend_model': backend_model,
                'backend_short': backend_short(backend_label),
                'backend_order': backend_sort_key(backend_label),
                'evaluator_variant': variant,
                'variant_role': variant_role,
                'variant_order': VARIANT_ORDER.get(str(variant), 99),
                'target_split': split_name,
                'split_type': split_type(split_name),
                'rows': len(split_df),
                'subset_policy': subset_policies,
            }
            if len(split_df) < 5:
                protocol_pca_rows.append({**row_base, 'error': 'too few rows for PCA'})
                continue
            try:
                row, loadings, variance, scores = run_pca_summary(split_df, source_run_ids, backend_label, split_name)
            except ValueError as exc:
                protocol_pca_rows.append({**row_base, 'error': str(exc)})
                continue
            row.update(row_base)
            protocol_pca_rows.append(row)
            for rec in top_loading_records(loadings, source_run_ids, backend_label, split_name):
                rec['source_run_ids'] = source_run_ids
                rec['evaluator_backend_model'] = backend_model
                rec['backend_short'] = backend_short(backend_label)
                rec['backend_order'] = backend_sort_key(backend_label)
                rec['evaluator_variant'] = variant
                rec['variant_role'] = variant_role
                protocol_pca_loading_rows.append(rec)

protocol_backend_pca = pd.DataFrame(protocol_pca_rows)
protocol_backend_pca_loadings = pd.DataFrame(protocol_pca_loading_rows)
protocol_backend_pca.to_csv(OUTDIR / 'protocol_backend_pca_summary.csv', index=False)
protocol_backend_pca_loadings.to_csv(OUTDIR / 'protocol_backend_pca_top_loadings.csv', index=False)

if not protocol_backend_pca.empty:
    display_cols = [
        'backend_short', 'evaluator_variant', 'variant_role', 'target_split', 'split_type', 'rows',
        'n_columns_used', 'pc1_variance', 'pc1_pc4_cumulative_variance', 'pc1_top_variables', 'source_run_ids', 'error'
    ]
    sort_cols = [c for c in ['backend_order', 'variant_order', 'target_split'] if c in protocol_backend_pca.columns]
    display_df = protocol_backend_pca.sort_values(sort_cols) if sort_cols else protocol_backend_pca.copy()
    display(display_df[[c for c in display_cols if c in display_df.columns]].round(3))
else:
    print('No protocol-level PCA rows available.')
# Out:
#            backend_short          evaluator_variant              variant_role       target_split       split_type   rows  n_columns_used  pc1_variance  pc1_pc4_cumulative_variance  \
# 27  Rule-based heuristic            baseline_binary                  baseline  pooled_qwen_llama  balanced_pooled  39996             NaN           NaN                          NaN
# 28  Rule-based heuristic            baseline_binary                  baseline  target_llama_only  target_specific  19998             NaN           NaN                          NaN
# 29  Rule-based heuristic            baseline_binary                  baseline   target_qwen_only  target_specific  19998             NaN           NaN                          NaN
# 30  Rule-based heuristic            baseline_likert                  baseline  pooled_qwen_llama  balanced_pooled  39996             NaN           NaN                          NaN
# 31  Rule-based heuristic            baseline_likert                  baseline  target_llama_only  target_specific  19998             NaN           NaN                          NaN
# 32  Rule-based heuristic            baseline_likert                  baseline   target_qwen_only  target_specific  19998             NaN           NaN                          NaN
# 33  Rule-based heuristic  direct_trustllm_heuristic                    direct  pooled_qwen_llama  balanced_pooled  39996             NaN           NaN                          NaN
# 34  Rule-based heuristic  direct_trustllm_heuristic                    direct  target_llama_only  target_specific  19998             NaN           NaN                          NaN
# 35  Rule-based heuristic  direct_trustllm_heuristic                    direct   target_qwen_only  target_specific  19998             NaN           NaN                          NaN
# 39  Rule-based heuristic               generic_cale       cale_family_generic  pooled_qwen_llama  balanced_pooled  39996             9.0         0.229                        0.675
# 40  Rule-based heuristic               generic_cale       cale_family_generic  target_llama_only  target_specific  19998             9.0         0.221                        0.677
# 41  Rule-based heuristic               generic_cale       cale_family_generic   target_qwen_only  target_specific  19998             9.0         0.271                        0.687
# 24  Rule-based heuristic          attack_aware_cale  cale_family_attack_aware  pooled_qwen_llama  balanced_pooled  39996             9.0         0.271                        0.705
# 25  Rule-based heuristic          attack_aware_cale  cale_family_attack_aware  target_llama_only  target_specific  19998             9.0         0.265                        0.710
# 26  Rule-based heuristic          attack_aware_cale  cale_family_attack_aware   target_qwen_only  target_specific  19998             9.0         0.279                        0.699
# 36  Rule-based heuristic     full_attack_aware_cale          cale_family_full  pooled_qwen_llama  balanced_pooled  39996            10.0         0.252                        0.650
# 37  Rule-based heuristic     full_attack_aware_cale          cale_family_full  target_llama_only  target_specific  19998            10.0         0.245                        0.657
# 38  Rule-based heuristic     full_attack_aware_cale          cale_family_full   target_qwen_only  target_specific  19998            10.0         0.263                        0.642
# 12      Qwen2.5-7B judge           direct_llm_judge                    direct  pooled_qwen_llama  balanced_pooled   2000             NaN           NaN                          NaN
# 13      Qwen2.5-7B judge           direct_llm_judge                    direct  target_llama_only  target_specific   1000             NaN           NaN                          NaN
# 14      Qwen2.5-7B judge           direct_llm_judge                    direct   target_qwen_only  target_specific   1000             NaN           NaN                          NaN
# 15      Qwen2.5-7B judge     full_attack_aware_cale          cale_family_full  pooled_qwen_llama  balanced_pooled   2000             9.0         0.548                        0.831
# 16      Qwen2.5-7B judge     full_attack_aware_cale          cale_family_full  target_llama_only  target_specific   1000             9.0         0.573                        0.855
# 17      Qwen2.5-7B judge     full_attack_aware_cale          cale_family_full   target_qwen_only  target_specific   1000             9.0         0.488                        0.798
# 18       Qwen3-14B judge           direct_llm_judge                    direct  pooled_qwen_llama  balanced_pooled   2000             NaN           NaN                          NaN
# 19       Qwen3-14B judge           direct_llm_judge                    direct  target_llama_only  target_specific   1000             NaN           NaN                          NaN
# 20       Qwen3-14B judge           direct_llm_judge                    direct   target_qwen_only  target_specific   1000             NaN           NaN                          NaN
# 21       Qwen3-14B judge     full_attack_aware_cale          cale_family_full  pooled_qwen_llama  balanced_pooled   2000             9.0         0.484                        0.837
# 22       Qwen3-14B judge     full_attack_aware_cale          cale_family_full  target_llama_only  target_specific   1000             9.0         0.475                        0.821
# 23       Qwen3-14B judge     full_attack_aware_cale          cale_family_full   target_qwen_only  target_specific   1000             9.0         0.481                        0.857
# 6       Gemma3-12B judge           direct_llm_judge                    direct  pooled_qwen_llama  balanced_pooled   2000             NaN           NaN                          NaN
# 7       Gemma3-12B judge           direct_llm_judge                    direct  target_llama_only  target_specific   1000             NaN           NaN                          NaN
# 8       Gemma3-12B judge           direct_llm_judge                    direct   target_qwen_only  target_specific   1000             NaN           NaN                          NaN
# 9       Gemma3-12B judge     full_attack_aware_cale          cale_family_full  pooled_qwen_llama  balanced_pooled   2000             9.0         0.556                        0.852
# 10      Gemma3-12B judge     full_attack_aware_cale          cale_family_full  target_llama_only  target_specific   1000             9.0         0.557                        0.850
# 11      Gemma3-12B judge     full_attack_aware_cale          cale_family_full   target_qwen_only  target_specific   1000             9.0         0.556                        0.860
# 0        DeepSeek V4-Pro           direct_llm_judge                    direct  pooled_qwen_llama  balanced_pooled   2000             NaN           NaN                          NaN
# 1        DeepSeek V4-Pro           direct_llm_judge                    direct  target_llama_only  target_specific   1000             NaN           NaN                          NaN
# 2        DeepSeek V4-Pro           direct_llm_judge                    direct   target_qwen_only  target_specific   1000             NaN           NaN                          NaN
# 3        DeepSeek V4-Pro     full_attack_aware_cale          cale_family_full  pooled_qwen_llama  balanced_pooled   2000             9.0         0.684                        0.909
# 4        DeepSeek V4-Pro     full_attack_aware_cale          cale_family_full  target_llama_only  target_specific   1000             9.0         0.619                        0.882
# 5        DeepSeek V4-Pro     full_attack_aware_cale          cale_family_full   target_qwen_only  target_specific   1000             9.0         0.747                        0.937
#
#                                     pc1_top_variables                                     source_run_ids                                              error
# 27                                                NaN                                     heuristic_full  No numeric behavior columns remain for PCA aft...
# 28                                                NaN                                     heuristic_full  No numeric behavior columns remain for PCA aft...
# 29                                                NaN                                     heuristic_full  No numeric behavior columns remain for PCA aft...
# 30                                                NaN                                     heuristic_full  No numeric behavior columns remain for PCA aft...
# 31                                                NaN                                     heuristic_full  No numeric behavior columns remain for PCA aft...
# 32                                                NaN                                     heuristic_full  No numeric behavior columns remain for PCA aft...
# 33                                                NaN                                     heuristic_full  No numeric behavior columns remain for PCA aft...
# 34                                                NaN                                     heuristic_full  No numeric behavior columns remain for PCA aft...
# 35                                                NaN                                     heuristic_full  No numeric behavior columns remain for PCA aft...
# 39  source_faithfulness, claim_status_recognition,...                                     heuristic_full                                                NaN
# 40  claim_status_recognition, correction_accuracy,...                                     heuristic_full                                                NaN
# 41  source_faithfulness, evidence_grounding, claim...                                     heuristic_full                                                NaN
# 24  source_faithfulness, evidence_grounding, claim...                                     heuristic_full                                                NaN
# 25  source_faithfulness, evidence_grounding, claim...                                     heuristic_full                                                NaN
# 26  source_faithfulness, evidence_grounding, claim...                                     heuristic_full                                                NaN
# 36  source_faithfulness, evidence_grounding, claim...                                     heuristic_full                                                NaN
# 37  source_faithfulness, evidence_grounding, claim...                                     heuristic_full                                                NaN
# 38  source_faithfulness, evidence_grounding, claim...                                     heuristic_full                                                NaN
# 12                                                NaN     qwen25_7b_limit1000, qwen25_7b_llama_limit1000  No numeric behavior columns remain for PCA aft...
# 13                                                NaN     qwen25_7b_limit1000, qwen25_7b_llama_limit1000  No numeric behavior columns remain for PCA aft...
# 14                                                NaN     qwen25_7b_limit1000, qwen25_7b_llama_limit1000  No numeric behavior columns remain for PCA aft...
# 15  uncertainty_handling, claim_status_recognition...     qwen25_7b_limit1000, qwen25_7b_llama_limit1000                                                NaN
# 16  uncertainty_handling, claim_status_recognition...     qwen25_7b_limit1000, qwen25_7b_llama_limit1000                                                NaN
# 17  uncertainty_handling, claim_status_recognition...     qwen25_7b_limit1000, qwen25_7b_llama_limit1000                                                NaN
# 18                                                NaN     qwen3_14b_limit1000, qwen3_14b_llama_limit1000  No numeric behavior columns remain for PCA aft...
# 19                                                NaN     qwen3_14b_limit1000, qwen3_14b_llama_limit1000  No numeric behavior columns remain for PCA aft...
# 20                                                NaN     qwen3_14b_limit1000, qwen3_14b_llama_limit1000  No numeric behavior columns remain for PCA aft...
# 21  claim_status_recognition, correction_accuracy,...     qwen3_14b_limit1000, qwen3_14b_llama_limit1000                                                NaN
# 22  claim_status_recognition, framing_resistance, ...     qwen3_14b_limit1000, qwen3_14b_llama_limit1000                                                NaN
# 23  claim_status_recognition, correction_accuracy,...     qwen3_14b_limit1000, qwen3_14b_llama_limit1000                                                NaN
# 6                                                 NaN   gemma3_12b_limit1000, gemma3_12b_llama_limit1000  No numeric behavior columns remain for PCA aft...
# 7                                                 NaN   gemma3_12b_limit1000, gemma3_12b_llama_limit1000  No numeric behavior columns remain for PCA aft...
# 8                                                 NaN   gemma3_12b_limit1000, gemma3_12b_llama_limit1000  No numeric behavior columns remain for PCA aft...
# 9   claim_status_recognition, uncertainty_handling...   gemma3_12b_limit1000, gemma3_12b_llama_limit1000                                                NaN
# 10  claim_status_recognition, framing_resistance, ...   gemma3_12b_limit1000, gemma3_12b_llama_limit1000                                                NaN
# 11  uncertainty_handling, claim_status_recognition...   gemma3_12b_limit1000, gemma3_12b_llama_limit1000                                                NaN
# 0                                                 NaN  deepseek_v4_pro_limit1000, deepseek_v4_pro_lla...  No numeric behavior columns remain for PCA aft...
# 1                                                 NaN  deepseek_v4_pro_limit1000, deepseek_v4_pro_lla...  No numeric behavior columns remain for PCA aft...
# 2                                                 NaN  deepseek_v4_pro_limit1000, deepseek_v4_pro_lla...  No numeric behavior columns remain for PCA aft...
# 3   source_faithfulness, evidence_grounding, claim...  deepseek_v4_pro_limit1000, deepseek_v4_pro_lla...                                                NaN
# 4   source_faithfulness, uncertainty_handling, cla...  deepseek_v4_pro_limit1000, deepseek_v4_pro_lla...                                                NaN
# 5   evidence_grounding, source_faithfulness, claim...  deepseek_v4_pro_limit1000, deepseek_v4_pro_lla...                                                NaN

# %%
def save_protocol_variance_plot(summary, path):
    if summary.empty:
        return
    plot_df = summary[
        summary['target_split'].isin(['pooled_qwen_llama', 'pooled_all_available_targets'])
        & summary.get('pc1_variance', pd.Series(index=summary.index, dtype=float)).notna()
    ].copy()
    if plot_df.empty:
        return
    sort_cols = [c for c in ['backend_order', 'variant_order', 'evaluator_variant'] if c in plot_df.columns]
    plot_df = plot_df.sort_values(sort_cols).reset_index(drop=True) if sort_cols else plot_df.reset_index(drop=True)
    plot_df['audit_label'] = plot_df['backend_short'].map(short_backend_label) + ' | ' + plot_df['evaluator_variant'].map(short_variant_label)
    plot_df['row_label'] = plot_df['audit_label'] + ' (n=' + plot_df['rows'].astype(str) + ')'
    colors = plot_df['evaluator_backend_label'].map(BACKEND_COLORS).fillna('#4c4c4c')
    y = np.arange(len(plot_df))

    fig, axes = plt.subplots(1, 2, figsize=(13, max(4.5, 0.42 * len(plot_df))))
    metrics = [
        ('pc1_variance', 'PC1 explained variance'),
        ('pc1_pc4_cumulative_variance', 'PC1-PC4 cumulative variance'),
    ]
    for ax, (metric, title) in zip(axes, metrics):
        ax.barh(y, plot_df[metric], color=colors)
        ax.set_title(title)
        ax.set_xlim(0, 1)
        ax.set_xlabel('Explained variance ratio')
        ax.set_yticks(y)
        ax.set_yticklabels(plot_df['row_label'] if ax is axes[0] else [''] * len(plot_df), fontsize=8)
        ax.grid(axis='x', alpha=0.25)
        for idx, value in enumerate(plot_df[metric]):
            if pd.notna(value):
                ax.text(min(value + 0.015, 0.98), idx, f'{value:.3f}', va='center', fontsize=8)
    fig.suptitle('Latent-Structure Variance Across Backends and Protocols', y=1.01)
    fig.tight_layout()
    fig.savefig(path, dpi=240, bbox_inches='tight')
    plt.show()


def save_metric_by_target_plot(summary, metric, path, title):
    if summary.empty or metric not in summary.columns:
        return
    plot_df = summary[summary[metric].notna()].copy()
    if plot_df.empty:
        return
    plot_df['backend_target_label'] = plot_df['backend_short'].map(short_backend_label) + ' | ' + plot_df['evaluator_variant'].map(short_variant_label)
    if 'backend_order' in plot_df.columns:
        plot_df = plot_df.sort_values(['backend_order', 'variant_order', 'target_split'])
    pivot = plot_df.pivot_table(
        index=['backend_target_label'],
        columns='target_split',
        values=metric,
        aggfunc='first',
        sort=False,
    )
    ordered_cols = [c for c in ['pooled_qwen_llama', 'target_qwen_only', 'target_llama_only', 'pooled_all_available_targets'] if c in pivot.columns]
    pivot = pivot[ordered_cols]
    pivot.to_csv(path.with_suffix('.csv'))
    save_annotated_heatmap(pivot, path, title, vmin=0, vmax=1)
    display(pivot.round(3))

if not protocol_backend_pca.empty:
    save_protocol_variance_plot(protocol_backend_pca, OUTDIR / 'protocol_backend_pca_variance_pooled.png')
    save_metric_by_target_plot(
        protocol_backend_pca,
        'pc1_variance',
        OUTDIR / 'protocol_backend_pca_pc1_by_target_split.png',
        'PC1 Variance by Backend, Protocol, and Target Split',
    )
    save_metric_by_target_plot(
        protocol_backend_pca,
        'pc1_pc4_cumulative_variance',
        OUTDIR / 'protocol_backend_pca_pc1_pc4_by_target_split.png',
        'PC1-PC4 Cumulative Variance by Backend, Protocol, and Target Split',
    )
# Out:
# target_split                              pooled_qwen_llama  target_qwen_only  target_llama_only
# backend_target_label
# Rule-based heuristic | generic CALE                   0.229             0.271              0.221
# Rule-based heuristic | attack-aware CALE              0.271             0.279              0.265
# Rule-based heuristic | full CALE                      0.252             0.263              0.245
# Qwen2.5-7B judge | full CALE                          0.548             0.488              0.573
# Qwen3-14B judge | full CALE                           0.484             0.481              0.475
# Gemma3-12B judge | full CALE                          0.556             0.556              0.557
# DeepSeek V4-Pro | full CALE                           0.684             0.747              0.619
# target_split                              pooled_qwen_llama  target_qwen_only  target_llama_only
# backend_target_label
# Rule-based heuristic | generic CALE                   0.675             0.687              0.677
# Rule-based heuristic | attack-aware CALE              0.705             0.699              0.710
# Rule-based heuristic | full CALE                      0.650             0.642              0.657
# Qwen2.5-7B judge | full CALE                          0.831             0.798              0.855
# Qwen3-14B judge | full CALE                           0.837             0.857              0.821
# Gemma3-12B judge | full CALE                          0.852             0.860              0.850
# DeepSeek V4-Pro | full CALE                           0.909             0.937              0.882

# %% [markdown]
# ## 12. Goal 1 Measurement Quality Summary
#
# This section writes the main audit table for **Goal 1: evaluator measurement quality**.
#
# 这一节输出 Goal 1 的主表：不是问哪个 evaluator 分数最高，而是问某个 `evaluator_backend × evaluator_variant × target_split` 是否呈现可解释的 measurement behavior。
#
# The table joins four kinds of evidence:
#
# - **Measurement structure**: PCA variance and top-loading construct clusters.
# - **Backend agreement**: whether other backends agree on shared rows for the same protocol/split.
# - **Target-split sensitivity**: whether Qwen-target and Llama-target rows diverge strongly under the same backend/protocol.
# - **Claim readiness**: conservative language for what can be claimed from the current evidence.
#
# Interpretation warning: high PC1 or PC1-PC4 variance means stronger low-dimensional concentration. It is **not** automatically better evaluator quality.
#
# 解释提醒：PC1/PC1-PC4 方差高表示 behavior signals 更集中在少数轴上，不等于 evaluator 更好。

# %%
def _safe_mean(values):
    values = pd.to_numeric(pd.Series(values), errors='coerce')
    return values.mean() if values.notna().any() else np.nan


def _safe_min(values):
    values = pd.to_numeric(pd.Series(values), errors='coerce')
    return values.min() if values.notna().any() else np.nan


def _target_score_sensitivity_table(outcome_df):
    if outcome_df.empty or 'mean_final_score' not in outcome_df.columns or 'target_split' not in outcome_df.columns:
        return pd.DataFrame()
    rows = []
    # outcome_summary is intentionally a lighter table and may not carry
    # evaluator_backend_model. Build the sensitivity table from whatever stable
    # keys exist, then merge back using common keys below.
    group_cols = [c for c in ['evaluator_backend_label', 'evaluator_backend_model', 'evaluator_variant'] if c in outcome_df.columns]
    if not group_cols:
        return pd.DataFrame()
    for keys, group in outcome_df.groupby(group_cols, dropna=False):
        if not isinstance(keys, tuple):
            keys = (keys,)
        row_base = dict(zip(group_cols, keys))
        by_split = group.groupby('target_split', dropna=False)['mean_final_score'].mean()
        if {'target_qwen_only', 'target_llama_only'} <= set(by_split.index):
            delta = by_split.loc['target_qwen_only'] - by_split.loc['target_llama_only']
            row_base.update({
                'qwen_minus_llama_mean_score_delta': delta,
                'abs_qwen_minus_llama_mean_score_delta': abs(delta),
            })
            rows.append(row_base)
    return pd.DataFrame(rows)


def _construct_sensitivity_table(delta_df):
    if delta_df.empty:
        return pd.DataFrame()
    # Keep construct sensitivity focused on core CALE behavior dimensions.
    # Reference-label proxies are useful diagnostics, but mixing them here makes
    # the summary read as if a proxy were a latent construct.
    metric_cols = [c for c in CORE_BEHAVIOR_COLUMNS if c in delta_df.columns]
    if not metric_cols:
        return pd.DataFrame()
    rows = []
    for _, row in delta_df.iterrows():
        values = pd.to_numeric(row[metric_cols], errors='coerce')
        rows.append({
            'evaluator_backend_label': row.get('evaluator_backend_label'),
            'evaluator_backend_model': row.get('evaluator_backend_model'),
            'evaluator_variant': row.get('evaluator_variant'),
            'max_abs_construct_qwen_minus_llama_delta': values.abs().max(),
            'mean_abs_construct_qwen_minus_llama_delta': values.abs().mean(),
            'largest_target_sensitive_construct': values.abs().sort_values(ascending=False).index[0] if values.notna().any() else '',
        })
    return pd.DataFrame(rows)


def _backend_agreement_for_summary(alignment_df):
    if alignment_df.empty:
        return pd.DataFrame()
    rows = []
    for _, row in alignment_df.iterrows():
        for side in ['backend_left', 'backend_right']:
            rows.append({
                'evaluator_backend_label': row.get(side),
                'evaluator_variant': row.get('evaluator_variant'),
                'target_split': row.get('target_split'),
                'agreement_pair': f"{row.get('backend_left')} ↔ {row.get('backend_right')}",
                'n_shared_rows': row.get('n_shared_rows'),
                'pairwise_pearson': row.get('pearson'),
                'pairwise_spearman': row.get('spearman'),
                'pairwise_mae': row.get('mae'),
            })
    agree = pd.DataFrame(rows)
    if agree.empty:
        return agree
    return agree.groupby(['evaluator_backend_label', 'evaluator_variant', 'target_split'], dropna=False).agg(
        backend_agreement_pairs=('agreement_pair', lambda s: '; '.join(sorted(set(map(str, s))))),
        backend_agreement_shared_rows_min=('n_shared_rows', 'min'),
        backend_agreement_pearson_mean=('pairwise_pearson', _safe_mean),
        backend_agreement_spearman_mean=('pairwise_spearman', _safe_mean),
        backend_agreement_mae_mean=('pairwise_mae', _safe_mean),
    ).reset_index()


def _claim_readiness(row):
    variant = str(row.get('evaluator_variant', ''))
    split = str(row.get('target_split', ''))
    rows = row.get('rows', 0)
    pc1_pc4 = row.get('pc1_pc4_cumulative_variance', np.nan)
    if pd.isna(pc1_pc4):
        return 'not_ready: no PCA structure available'
    if rows < 100:
        return 'screening_only: too few rows for stable measurement claim'
    if variant in {'baseline_binary', 'baseline_likert', 'direct_trustllm_heuristic', 'direct_llm_judge'}:
        return 'control_protocol: use for baseline/sensitivity, not CALE construct validity claim'
    if variant == FULL_CALE_VARIANT and split == 'pooled_qwen_llama':
        return 'primary_preliminary_evidence: internal structure plus balanced target split'
    if variant == FULL_CALE_VARIANT and split.startswith('target_'):
        return 'robustness_check: target-specific internal-structure evidence'
    if variant in CALE_VARIANTS:
        return 'protocol_ablation_evidence: compare within backend and matched rows'
    return 'screening_only'


measurement_quality_summary = pd.DataFrame()
if 'protocol_backend_pca' in globals() and not protocol_backend_pca.empty:
    base_cols = [
        'backend_short', 'backend_order', 'evaluator_backend_label', 'evaluator_backend_model', 'evaluator_variant', 'variant_role',
        'target_split', 'split_type', 'rows', 'n_columns_used', 'pc1_variance', 'pc1_pc4_cumulative_variance',
        'pc1_top_variables', 'pc2_top_variables', 'source_run_ids', 'subset_policy', 'error'
    ]
    measurement_quality_summary = protocol_backend_pca[[c for c in base_cols if c in protocol_backend_pca.columns]].copy()

    score_sensitivity = _target_score_sensitivity_table(outcome_summary if 'outcome_summary' in globals() else pd.DataFrame())
    if not score_sensitivity.empty:
        score_merge_keys = [
            c for c in ['evaluator_backend_label', 'evaluator_backend_model', 'evaluator_variant']
            if c in measurement_quality_summary.columns and c in score_sensitivity.columns
        ]
        if score_merge_keys:
            measurement_quality_summary = measurement_quality_summary.merge(
                score_sensitivity,
                on=score_merge_keys,
                how='left',
            )

    construct_sensitivity = _construct_sensitivity_table(full_cale_target_delta if 'full_cale_target_delta' in globals() else pd.DataFrame())
    if not construct_sensitivity.empty:
        construct_merge_keys = [
            c for c in ['evaluator_backend_label', 'evaluator_backend_model', 'evaluator_variant']
            if c in measurement_quality_summary.columns and c in construct_sensitivity.columns
        ]
        if construct_merge_keys:
            measurement_quality_summary = measurement_quality_summary.merge(
                construct_sensitivity,
                on=construct_merge_keys,
                how='left',
            )

    agreement_summary = _backend_agreement_for_summary(backend_alignment if 'backend_alignment' in globals() else pd.DataFrame())
    if not agreement_summary.empty:
        measurement_quality_summary = measurement_quality_summary.merge(
            agreement_summary,
            on=['evaluator_backend_label', 'evaluator_variant', 'target_split'],
            how='left',
        )

    target_sensitivity_summary = measurement_quality_summary[
        measurement_quality_summary['target_split'].eq('pooled_qwen_llama')
    ].copy()
    sensitivity_cols = [
        'qwen_minus_llama_mean_score_delta',
        'abs_qwen_minus_llama_mean_score_delta',
        'max_abs_construct_qwen_minus_llama_delta',
        'mean_abs_construct_qwen_minus_llama_delta',
        'largest_target_sensitive_construct',
    ]
    target_sensitivity_summary = target_sensitivity_summary[
        [c for c in ['backend_short', 'evaluator_backend_label', 'evaluator_backend_model', 'evaluator_variant', 'rows'] + sensitivity_cols if c in target_sensitivity_summary.columns]
    ]
    target_sensitivity_summary.to_csv(OUTDIR / 'target_sensitivity_summary.csv', index=False)

    # Target-sensitivity deltas compare Qwen-target vs Llama-target, so they
    # belong to the pooled comparison row. Blank them on target-specific PCA rows
    # to avoid reading the same delta as a property of only one split.
    non_pooled_mask = ~measurement_quality_summary['target_split'].eq('pooled_qwen_llama')
    for col in sensitivity_cols:
        if col in measurement_quality_summary.columns:
            measurement_quality_summary.loc[non_pooled_mask, col] = np.nan

    measurement_quality_summary['pca_interpretation_warning'] = 'Explained variance indicates structure/concentration, not evaluator quality by itself.'
    measurement_quality_summary['claim_readiness'] = measurement_quality_summary.apply(_claim_readiness, axis=1)
    measurement_quality_summary = measurement_quality_summary.sort_values(
        [c for c in ['backend_order', 'variant_role', 'evaluator_variant', 'target_split'] if c in measurement_quality_summary.columns]
    )

measurement_quality_summary.to_csv(OUTDIR / 'measurement_quality_summary.csv', index=False)
if measurement_quality_summary.empty:
    print('No measurement quality summary available yet.')
else:
    display_cols = [
        'backend_short', 'evaluator_variant', 'target_split', 'rows', 'pc1_variance', 'pc1_pc4_cumulative_variance',
        'backend_agreement_spearman_mean', 'abs_qwen_minus_llama_mean_score_delta',
        'max_abs_construct_qwen_minus_llama_delta', 'claim_readiness'
    ]
    display(measurement_quality_summary[[c for c in display_cols if c in measurement_quality_summary.columns]].round(3))
# Out:
#            backend_short          evaluator_variant       target_split   rows  pc1_variance  pc1_pc4_cumulative_variance  backend_agreement_spearman_mean  abs_qwen_minus_llama_mean_score_delta  \
# 27  Rule-based heuristic            baseline_binary  pooled_qwen_llama  39996           NaN                          NaN                              NaN                                  0.008
# 28  Rule-based heuristic            baseline_binary  target_llama_only  19998           NaN                          NaN                              NaN                                    NaN
# 29  Rule-based heuristic            baseline_binary   target_qwen_only  19998           NaN                          NaN                              NaN                                    NaN
# 30  Rule-based heuristic            baseline_likert  pooled_qwen_llama  39996           NaN                          NaN                              NaN                                  0.004
# 31  Rule-based heuristic            baseline_likert  target_llama_only  19998           NaN                          NaN                              NaN                                    NaN
# 32  Rule-based heuristic            baseline_likert   target_qwen_only  19998           NaN                          NaN                              NaN                                    NaN
# 24  Rule-based heuristic          attack_aware_cale  pooled_qwen_llama  39996         0.271                        0.705                              NaN                                  0.026
# 25  Rule-based heuristic          attack_aware_cale  target_llama_only  19998         0.265                        0.710                              NaN                                    NaN
# 26  Rule-based heuristic          attack_aware_cale   target_qwen_only  19998         0.279                        0.699                              NaN                                    NaN
# 36  Rule-based heuristic     full_attack_aware_cale  pooled_qwen_llama  39996         0.252                        0.650                            0.422                                  0.027
# 37  Rule-based heuristic     full_attack_aware_cale  target_llama_only  19998         0.245                        0.657                            0.378                                    NaN
# 38  Rule-based heuristic     full_attack_aware_cale   target_qwen_only  19998         0.263                        0.642                            0.477                                    NaN
# 39  Rule-based heuristic               generic_cale  pooled_qwen_llama  39996         0.229                        0.675                              NaN                                  0.048
# 40  Rule-based heuristic               generic_cale  target_llama_only  19998         0.221                        0.677                              NaN                                    NaN
# 41  Rule-based heuristic               generic_cale   target_qwen_only  19998         0.271                        0.687                              NaN                                    NaN
# 33  Rule-based heuristic  direct_trustllm_heuristic  pooled_qwen_llama  39996           NaN                          NaN                              NaN                                  0.005
# 34  Rule-based heuristic  direct_trustllm_heuristic  target_llama_only  19998           NaN                          NaN                              NaN                                    NaN
# 35  Rule-based heuristic  direct_trustllm_heuristic   target_qwen_only  19998           NaN                          NaN                              NaN                                    NaN
# 15      Qwen2.5-7B judge     full_attack_aware_cale  pooled_qwen_llama   2000         0.548                        0.831                            0.468                                  0.101
# 16      Qwen2.5-7B judge     full_attack_aware_cale  target_llama_only   1000         0.573                        0.855                            0.428                                    NaN
# 17      Qwen2.5-7B judge     full_attack_aware_cale   target_qwen_only   1000         0.488                        0.798                            0.497                                    NaN
# 12      Qwen2.5-7B judge           direct_llm_judge  pooled_qwen_llama   2000           NaN                          NaN                            0.374                                  0.273
# 13      Qwen2.5-7B judge           direct_llm_judge  target_llama_only   1000           NaN                          NaN                            0.392                                    NaN
# 14      Qwen2.5-7B judge           direct_llm_judge   target_qwen_only   1000           NaN                          NaN                            0.237                                    NaN
# 21       Qwen3-14B judge     full_attack_aware_cale  pooled_qwen_llama   2000         0.484                        0.837                            0.521                                  0.103
# 22       Qwen3-14B judge     full_attack_aware_cale  target_llama_only   1000         0.475                        0.821                            0.471                                    NaN
# 23       Qwen3-14B judge     full_attack_aware_cale   target_qwen_only   1000         0.481                        0.857                            0.570                                    NaN
# 18       Qwen3-14B judge           direct_llm_judge  pooled_qwen_llama   2000           NaN                          NaN                            0.436                                  0.152
# 19       Qwen3-14B judge           direct_llm_judge  target_llama_only   1000           NaN                          NaN                            0.424                                    NaN
# 20       Qwen3-14B judge           direct_llm_judge   target_qwen_only   1000           NaN                          NaN                            0.396                                    NaN
# 9       Gemma3-12B judge     full_attack_aware_cale  pooled_qwen_llama   2000         0.556                        0.852                            0.507                                  0.083
# 10      Gemma3-12B judge     full_attack_aware_cale  target_llama_only   1000         0.557                        0.850                            0.459                                    NaN
# 11      Gemma3-12B judge     full_attack_aware_cale   target_qwen_only   1000         0.556                        0.860                            0.556                                    NaN
# 6       Gemma3-12B judge           direct_llm_judge  pooled_qwen_llama   2000           NaN                          NaN                            0.484                                  0.201
# 7       Gemma3-12B judge           direct_llm_judge  target_llama_only   1000           NaN                          NaN                            0.498                                    NaN
# 8       Gemma3-12B judge           direct_llm_judge   target_qwen_only   1000           NaN                          NaN                            0.385                                    NaN
# 3        DeepSeek V4-Pro     full_attack_aware_cale  pooled_qwen_llama   2000         0.684                        0.909                            0.212                                  0.063
# 4        DeepSeek V4-Pro     full_attack_aware_cale  target_llama_only   1000         0.619                        0.882                            0.178                                    NaN
# 5        DeepSeek V4-Pro     full_attack_aware_cale   target_qwen_only   1000         0.747                        0.937                            0.235                                    NaN
# 0        DeepSeek V4-Pro           direct_llm_judge  pooled_qwen_llama   2000           NaN                          NaN                            0.349                                  0.048
# 1        DeepSeek V4-Pro           direct_llm_judge  target_llama_only   1000           NaN                          NaN                            0.385                                    NaN
# 2        DeepSeek V4-Pro           direct_llm_judge   target_qwen_only   1000           NaN                          NaN                            0.299                                    NaN
#
#     max_abs_construct_qwen_minus_llama_delta                                    claim_readiness
# 27                                       NaN              not_ready: no PCA structure available
# 28                                       NaN              not_ready: no PCA structure available
# 29                                       NaN              not_ready: no PCA structure available
# 30                                       NaN              not_ready: no PCA structure available
# 31                                       NaN              not_ready: no PCA structure available
# 32                                       NaN              not_ready: no PCA structure available
# 24                                       NaN  protocol_ablation_evidence: compare within bac...
# 25                                       NaN  protocol_ablation_evidence: compare within bac...
# 26                                       NaN  protocol_ablation_evidence: compare within bac...
# 36                                     0.477  primary_preliminary_evidence: internal structu...
# 37                                       NaN  robustness_check: target-specific internal-str...
# 38                                       NaN  robustness_check: target-specific internal-str...
# 39                                       NaN  protocol_ablation_evidence: compare within bac...
# 40                                       NaN  protocol_ablation_evidence: compare within bac...
# 41                                       NaN  protocol_ablation_evidence: compare within bac...
# 33                                       NaN              not_ready: no PCA structure available
# 34                                       NaN              not_ready: no PCA structure available
# 35                                       NaN              not_ready: no PCA structure available
# 15                                     0.266  primary_preliminary_evidence: internal structu...
# 16                                       NaN  robustness_check: target-specific internal-str...
# 17                                       NaN  robustness_check: target-specific internal-str...
# 12                                       NaN              not_ready: no PCA structure available
# 13                                       NaN              not_ready: no PCA structure available
# 14                                       NaN              not_ready: no PCA structure available
# 21                                     0.259  primary_preliminary_evidence: internal structu...
# 22                                       NaN  robustness_check: target-specific internal-str...
# 23                                       NaN  robustness_check: target-specific internal-str...
# 18                                       NaN              not_ready: no PCA structure available
# 19                                       NaN              not_ready: no PCA structure available
# 20                                       NaN              not_ready: no PCA structure available
# 9                                      0.210  primary_preliminary_evidence: internal structu...
# 10                                       NaN  robustness_check: target-specific internal-str...
# 11                                       NaN  robustness_check: target-specific internal-str...
# 6                                        NaN              not_ready: no PCA structure available
# 7                                        NaN              not_ready: no PCA structure available
# 8                                        NaN              not_ready: no PCA structure available
# 3                                      0.114  primary_preliminary_evidence: internal structu...
# 4                                        NaN  robustness_check: target-specific internal-str...
# 5                                        NaN  robustness_check: target-specific internal-str...
# 0                                        NaN              not_ready: no PCA structure available
# 1                                        NaN              not_ready: no PCA structure available
# 2                                        NaN              not_ready: no PCA structure available

# %% [markdown]
# ## 13. Goal 2 Compact Target Capability Profile
#
# This section writes the main audit table for **Goal 2: compact LLM capability summaries**.
#
# 这一节输出 Goal 2 的主表：在固定 `full_attack_aware_cale` 后，把 target-model responses 压缩成少数 construct profiles。这里的行仍然保留 evaluator backend 和 target split，因为 target capability summary 不能和 evaluator/backend effects 混在一起。
#
# Interpretation guardrails:
#
# - Use target-specific rows (`target_qwen_only`, `target_llama_only`) for Qwen-vs-Llama target comparisons.
# - Compare target models only within the same evaluator backend and protocol.
# - Treat backend differences as robustness/sensitivity evidence, not as calibrated target-model scores.
#
# 解释边界：这张表不是 evaluator 排行榜，也不是跨 backend 校准后的 target model 排行榜；它是 full CALE 下的 compact construct profile。

# %%
FACTOR_GROUPS = {
    'factual_handling_mean': [
        'source_faithfulness', 'evidence_grounding', 'claim_status_recognition',
        'correction_accuracy', 'misinformation_detection'
    ],
    'resistance_boundary_mean': [
        'framing_resistance', 'error_rejection', 'hallucination_control',
        'uncertainty_handling'
    ],
}


def _row_mean(row, columns):
    existing = [c for c in columns if c in row.index]
    if not existing:
        return np.nan
    return pd.to_numeric(row[existing], errors='coerce').mean()


compact_capability_summary = pd.DataFrame()
if 'full_cale_construct_profile' in globals() and not full_cale_construct_profile.empty:
    capability_cols = [c for c in CORE_BEHAVIOR_COLUMNS if c in full_cale_construct_profile.columns]
    proxy_cols = [c for c in PROXY_COLUMNS if c in full_cale_construct_profile.columns]
    keep_cols = [
        'evaluator_backend_family', 'evaluator_backend_label', 'evaluator_backend_model', 'backend_order',
        'evaluator_variant', 'variant_role', 'target_split', 'split_type', 'target_models',
        'rows', 'source_run_ids'
    ] + capability_cols + proxy_cols
    compact_capability_summary = full_cale_construct_profile[[c for c in keep_cols if c in full_cale_construct_profile.columns]].copy()
    compact_capability_summary['summary_scope'] = np.where(
        compact_capability_summary['target_split'].isin(['target_qwen_only', 'target_llama_only']),
        'target_model_specific',
        np.where(compact_capability_summary['target_split'].eq('pooled_qwen_llama'), 'balanced_pooled_reference', 'available_only_reference')
    )
    for factor_name, cols in FACTOR_GROUPS.items():
        compact_capability_summary[factor_name] = compact_capability_summary.apply(lambda row: _row_mean(row, cols), axis=1)
    ordered = [
        'summary_scope', 'evaluator_backend_label', 'evaluator_backend_model', 'backend_order', 'evaluator_variant',
        'target_split', 'target_models', 'rows', 'source_run_ids',
        'factual_handling_mean', 'resistance_boundary_mean'
    ] + capability_cols + proxy_cols
    compact_capability_summary = compact_capability_summary[[c for c in ordered if c in compact_capability_summary.columns]]
    compact_capability_summary = compact_capability_summary.sort_values(
        [c for c in ['backend_order', 'evaluator_variant', 'target_split'] if c in compact_capability_summary.columns]
    )

compact_capability_summary.to_csv(OUTDIR / 'compact_capability_summary.csv', index=False)
if compact_capability_summary.empty:
    print('No compact capability summary available yet. This requires full_attack_aware_cale construct rows.')
else:
    display_cols = [
        'summary_scope', 'evaluator_backend_label', 'evaluator_variant', 'target_split', 'target_models', 'rows',
        'factual_handling_mean', 'resistance_boundary_mean',
        'source_faithfulness', 'evidence_grounding', 'claim_status_recognition',
        'correction_accuracy', 'framing_resistance', 'error_rejection', 'uncertainty_handling'
    ]
    display(compact_capability_summary[[c for c in display_cols if c in compact_capability_summary.columns]].round(3))
# Out:
#                 summary_scope               evaluator_backend_label       evaluator_variant       target_split                                      target_models   rows  factual_handling_mean  resistance_boundary_mean  \
# 3   balanced_pooled_reference  Rule-based scoring backend (non-LLM)  full_attack_aware_cale  pooled_qwen_llama  Qwen/Qwen2.5-1.5B-Instruct, meta-llama/Llama-3...  39996                  0.664                     0.990
# 4       target_model_specific  Rule-based scoring backend (non-LLM)  full_attack_aware_cale  target_llama_only                   meta-llama/Llama-3.2-1B-Instruct  19998                  0.633                     0.986
# 5       target_model_specific  Rule-based scoring backend (non-LLM)  full_attack_aware_cale   target_qwen_only                         Qwen/Qwen2.5-1.5B-Instruct  19998                  0.696                     0.993
# 9   balanced_pooled_reference             Qwen2.5-7B local HF judge  full_attack_aware_cale  pooled_qwen_llama  Qwen/Qwen2.5-1.5B-Instruct, meta-llama/Llama-3...   2000                  0.795                     0.877
# 10      target_model_specific             Qwen2.5-7B local HF judge  full_attack_aware_cale  target_llama_only                   meta-llama/Llama-3.2-1B-Instruct   1000                  0.727                     0.832
# 11      target_model_specific             Qwen2.5-7B local HF judge  full_attack_aware_cale   target_qwen_only                         Qwen/Qwen2.5-1.5B-Instruct   1000                  0.862                     0.922
# 12  balanced_pooled_reference              Qwen3-14B local HF judge  full_attack_aware_cale  pooled_qwen_llama  Qwen/Qwen2.5-1.5B-Instruct, meta-llama/Llama-3...   2000                  0.653                     0.733
# 13      target_model_specific              Qwen3-14B local HF judge  full_attack_aware_cale  target_llama_only                   meta-llama/Llama-3.2-1B-Instruct   1000                  0.597                     0.669
# 14      target_model_specific              Qwen3-14B local HF judge  full_attack_aware_cale   target_qwen_only                         Qwen/Qwen2.5-1.5B-Instruct   1000                  0.709                     0.798
# 6   balanced_pooled_reference             Gemma3-12B local HF judge  full_attack_aware_cale  pooled_qwen_llama  Qwen/Qwen2.5-1.5B-Instruct, meta-llama/Llama-3...   2000                  0.788                     0.810
# 7       target_model_specific             Gemma3-12B local HF judge  full_attack_aware_cale  target_llama_only                   meta-llama/Llama-3.2-1B-Instruct   1000                  0.748                     0.757
# 8       target_model_specific             Gemma3-12B local HF judge  full_attack_aware_cale   target_qwen_only                         Qwen/Qwen2.5-1.5B-Instruct   1000                  0.828                     0.862
# 0   balanced_pooled_reference             DeepSeek V4-Pro API judge  full_attack_aware_cale  pooled_qwen_llama  Qwen/Qwen2.5-1.5B-Instruct, meta-llama/Llama-3...   2000                  0.493                     0.548
# 1       target_model_specific             DeepSeek V4-Pro API judge  full_attack_aware_cale  target_llama_only                   meta-llama/Llama-3.2-1B-Instruct   1000                  0.454                     0.511
# 2       target_model_specific             DeepSeek V4-Pro API judge  full_attack_aware_cale   target_qwen_only                         Qwen/Qwen2.5-1.5B-Instruct   1000                  0.531                     0.584
#
#     source_faithfulness  evidence_grounding  claim_status_recognition  correction_accuracy  framing_resistance  error_rejection  uncertainty_handling
# 3                 0.899               0.898                     0.588                0.415               0.994            0.981                 0.999
# 4                 0.917               0.917                     0.584                0.462               0.989            0.964                 0.999
# 5                 0.880               0.879                     0.591                0.368               0.999            0.998                 0.999
# 9                 0.882               0.800                     0.843                0.800               0.914            0.720                 0.892
# 10                0.839               0.774                     0.769                0.739               0.878            0.636                 0.843
# 11                0.925               0.826                     0.917                0.860               0.951            0.803                 0.940
# 12                0.842               0.600                     0.718                0.526               0.716            0.530                 0.812
# 13                0.814               0.556                     0.670                0.482               0.634            0.400                 0.788
# 14                0.871               0.644                     0.767                0.570               0.799            0.659                 0.836
# 6                 0.880               0.777                     0.827                0.658               0.754            0.637                 0.874
# 7                 0.865               0.784                     0.763                0.573               0.676            0.532                 0.843
# 8                 0.894               0.770                     0.891                0.744               0.832            0.742                 0.904
# 0                 0.442               0.405                     0.482                0.553               0.737            0.589                 0.452
# 1                 0.406               0.348                     0.451                0.542               0.685            0.557                 0.423
# 2                 0.478               0.462                     0.512                0.564               0.789            0.621                 0.481

# %% [markdown]
# ## 14. CALE Variant Ladder Within The Heuristic Full Run
#
# The heuristic full run is the only current result that contains the full CALE ladder (`generic_cale`, `attack_aware_cale`, `full_attack_aware_cale`) over both target models.
#
# 目前只有 heuristic full run 覆盖完整 CALE ladder，所以 variant ladder 的主分析应该放在这里。

# %%
ladder_rows = []
heuristic = matrices.get('heuristic_full')
if heuristic is not None:
    cols = existing_behavior_columns(heuristic)
    ladder = heuristic[heuristic['evaluator_variant'].isin(CALE_VARIANTS)].copy()
    for keys, group in ladder.groupby(['target_split', 'evaluator_variant'], dropna=False):
        target_split, variant = keys
        row = {'target_split': target_split, 'evaluator_variant': variant, 'rows': len(group)}
        for col in cols:
            row[col] = pd.to_numeric(group[col], errors='coerce').mean()
        ladder_rows.append(row)

variant_ladder = pd.DataFrame(ladder_rows)
variant_ladder.to_csv(OUTDIR / 'heuristic_full_variant_ladder_by_target_split.csv', index=False)
if not variant_ladder.empty:
    display(variant_ladder.round(3))
else:
    print('Heuristic full result not available locally.')
# Out:
#         target_split       evaluator_variant   rows  misinformation_detection  framing_resistance  claim_status_recognition  error_rejection  correction_accuracy  evidence_grounding  source_faithfulness  \
# 0  target_llama_only       attack_aware_cale  19998                     0.283               0.989                     0.567            0.964                0.433               0.910                0.913
# 1  target_llama_only  full_attack_aware_cale  19998                     0.283               0.989                     0.584            0.964                0.462               0.917                0.917
# 2  target_llama_only            generic_cale  19998                     0.283               0.987                     0.567            0.964                0.433               0.681                0.887
# 3   target_qwen_only       attack_aware_cale  19998                     0.760               0.999                     0.572            0.998                0.331               0.878                0.879
# 4   target_qwen_only  full_attack_aware_cale  19998                     0.760               0.999                     0.591            0.998                0.368               0.879                0.880
# 5   target_qwen_only            generic_cale  19998                     0.760               0.999                     0.572            0.998                0.331               0.862                0.875
#
#    hallucination_control  uncertainty_handling  nei_uncertainty_failure_proxy  refutes_correction_credit_proxy  supports_status_failure_proxy
# 0                  0.994                 0.999                          0.000                            0.964                          0.175
# 1                  0.994                 0.999                          0.000                            0.968                          0.145
# 2                  0.994                 0.999                          0.000                            0.964                          0.175
# 3                  0.978                 0.999                          0.001                            0.998                          0.263
# 4                  0.978                 0.999                          0.001                            0.998                          0.209
# 5                  0.978                 0.999                          0.001                            0.998                          0.263

# %% [markdown]
# ### 14.1 Paired CALE Family Ladder Delta
#
# The heuristic full run is currently the only run with the complete CALE family ladder. This paired table asks whether `attack_aware_cale` and `full_attack_aware_cale` improve construct-relevant behavior over `generic_cale` on the same target responses.
#
# 目前只有 heuristic full run 有完整 CALE family ladder。这张 paired table 比较同一条 target response 上 `generic_cale → attack_aware_cale → full_attack_aware_cale` 的变化。

# %%
paired_ladder_rows = []
heuristic = matrices.get('heuristic_full')
if heuristic is not None:
    ladder_variants = ['generic_cale', 'attack_aware_cale', 'full_attack_aware_cale']
    cols = existing_behavior_columns(heuristic)
    key_cols = ['dataset', 'id', 'target_model', 'target_split']
    ladder = heuristic[heuristic['evaluator_variant'].isin(ladder_variants)].copy()
    for metric in ['final_score'] + cols:
        if metric not in ladder.columns:
            continue
        tmp = ladder[key_cols + ['evaluator_variant', metric]].copy()
        tmp[metric] = pd.to_numeric(tmp[metric], errors='coerce')
        wide = tmp.pivot_table(index=key_cols, columns='evaluator_variant', values=metric, aggfunc='mean')
        comparisons = [
            ('attack_minus_generic', 'attack_aware_cale', 'generic_cale'),
            ('full_minus_attack', 'full_attack_aware_cale', 'attack_aware_cale'),
            ('full_minus_generic', 'full_attack_aware_cale', 'generic_cale'),
        ]
        for comparison, left, right in comparisons:
            if left not in wide.columns or right not in wide.columns:
                continue
            delta = (wide[left] - wide[right]).dropna()
            meta = wide.loc[delta.index].reset_index()[key_cols]
            for target_split, values in pd.DataFrame({'delta': delta.values, 'target_split': meta['target_split'].values}).groupby('target_split'):
                paired_ladder_rows.append({
                    'metric': metric,
                    'comparison': comparison,
                    'target_split': target_split,
                    'n_paired': len(values),
                    'mean_delta': values['delta'].mean(),
                    'median_delta': values['delta'].median(),
                    'std_delta': values['delta'].std(),
                })

paired_ladder_delta = pd.DataFrame(paired_ladder_rows)
paired_ladder_delta.to_csv(OUTDIR / 'heuristic_full_paired_cale_family_ladder_delta.csv', index=False)
paired_ladder_delta.head(40)
# Out:
#                       metric            comparison       target_split  n_paired  mean_delta  median_delta  std_delta
# 0                final_score  attack_minus_generic  target_llama_only     19998    0.023696           0.0   0.044087
# 1                final_score  attack_minus_generic   target_qwen_only     19998    0.001751           0.0   0.014069
# 2                final_score     full_minus_attack  target_llama_only     19998    0.006609           0.0   0.019949
# 3                final_score     full_minus_attack   target_qwen_only     19998    0.007097           0.0   0.019872
# 4                final_score    full_minus_generic  target_llama_only     19998    0.030305           0.0   0.050266
# 5                final_score    full_minus_generic   target_qwen_only     19998    0.008848           0.0   0.025409
# 6   misinformation_detection  attack_minus_generic  target_llama_only     19998    0.000000           0.0   0.000000
# 7   misinformation_detection  attack_minus_generic   target_qwen_only     19998    0.000000           0.0   0.000000
# 8   misinformation_detection     full_minus_attack  target_llama_only     19998    0.000000           0.0   0.000000
# 9   misinformation_detection     full_minus_attack   target_qwen_only     19998    0.000000           0.0   0.000000
# 10  misinformation_detection    full_minus_generic  target_llama_only     19998    0.000000           0.0   0.000000
# 11  misinformation_detection    full_minus_generic   target_qwen_only     19998    0.000000           0.0   0.000000
# 12        framing_resistance  attack_minus_generic  target_llama_only     19998    0.001300           0.0   0.036035
# 13        framing_resistance  attack_minus_generic   target_qwen_only     19998    0.000200           0.0   0.014142
# 14        framing_resistance     full_minus_attack  target_llama_only     19998    0.000000           0.0   0.000000
# 15        framing_resistance     full_minus_attack   target_qwen_only     19998    0.000000           0.0   0.000000
# 16        framing_resistance    full_minus_generic  target_llama_only     19998    0.001300           0.0   0.036035
# 17        framing_resistance    full_minus_generic   target_qwen_only     19998    0.000200           0.0   0.014142
# 18  claim_status_recognition  attack_minus_generic  target_llama_only     19998    0.000000           0.0   0.000000
# 19  claim_status_recognition  attack_minus_generic   target_qwen_only     19998    0.000000           0.0   0.000000
# 20  claim_status_recognition     full_minus_attack  target_llama_only     19998    0.017152           0.0   0.091286
# 21  claim_status_recognition     full_minus_attack   target_qwen_only     19998    0.018752           0.0   0.096020
# 22  claim_status_recognition    full_minus_generic  target_llama_only     19998    0.017152           0.0   0.091286
# 23  claim_status_recognition    full_minus_generic   target_qwen_only     19998    0.018752           0.0   0.096020
# 24           error_rejection  attack_minus_generic  target_llama_only     19998    0.000000           0.0   0.000000
# 25           error_rejection  attack_minus_generic   target_qwen_only     19998    0.000000           0.0   0.000000
# 26           error_rejection     full_minus_attack  target_llama_only     19998    0.000000           0.0   0.000000
# 27           error_rejection     full_minus_attack   target_qwen_only     19998    0.000000           0.0   0.000000
# 28           error_rejection    full_minus_generic  target_llama_only     19998    0.000000           0.0   0.000000
# 29           error_rejection    full_minus_generic   target_qwen_only     19998    0.000000           0.0   0.000000
# 30       correction_accuracy  attack_minus_generic  target_llama_only     19998    0.000000           0.0   0.000000
# 31       correction_accuracy  attack_minus_generic   target_qwen_only     19998    0.000000           0.0   0.000000
# 32       correction_accuracy     full_minus_attack  target_llama_only     19998    0.029393           0.0   0.117831
# 33       correction_accuracy     full_minus_attack   target_qwen_only     19998    0.037584           0.0   0.129839
# 34       correction_accuracy    full_minus_generic  target_llama_only     19998    0.029393           0.0   0.117831
# 35       correction_accuracy    full_minus_generic   target_qwen_only     19998    0.037584           0.0   0.129839
# 36        evidence_grounding  attack_minus_generic  target_llama_only     19998    0.229323           0.0   0.420408
# 37        evidence_grounding  attack_minus_generic   target_qwen_only     19998    0.015452           0.0   0.123343
# 38        evidence_grounding     full_minus_attack  target_llama_only     19998    0.006351           0.0   0.056340
# 39        evidence_grounding     full_minus_attack   target_qwen_only     19998    0.001610           0.0   0.029318

# %% [markdown]
# ## 15. Proxy-Specific Diagnostics
#
# Proxy variables are reference-label-specific. They should be interpreted only where the corresponding FEVER label applies, not as general scores across all rows.
#
# Proxy 变量是 reference-label-specific，不能把非对应 label 的缺失当成 0。

# %%
proxy_specs = {
    'NOT ENOUGH INFO': 'nei_uncertainty_failure_proxy',
    'REFUTES': 'refutes_correction_credit_proxy',
    'SUPPORTS': 'supports_status_failure_proxy',
}
proxy_rows = []
if not combined.empty and 'reference_label' in combined.columns:
    group_cols = [
        'run_id', 'evaluator_backend_label', 'evaluator_backend_model', 'subset_policy',
        'target_split', 'target_model', 'evaluator_variant'
    ]
    for label, proxy in proxy_specs.items():
        if proxy not in combined.columns:
            continue
        subset = combined[combined['reference_label'].eq(label)].copy()
        for keys, group in subset.groupby(group_cols, dropna=False):
            run_id, backend_label, backend_model, subset_policy, target_split, target_model, variant = keys
            proxy_rows.append({
                'run_id': run_id,
                'reference_label': label,
                'proxy': proxy,
                'evaluator_backend_label': backend_label,
                'evaluator_backend_model': backend_model,
                'subset_policy': subset_policy,
                'target_split': target_split,
                'target_model': target_model,
                'evaluator_variant': variant,
                'rows': len(group),
                'mean_proxy': pd.to_numeric(group[proxy], errors='coerce').mean(),
                'non_null_share': pd.to_numeric(group[proxy], errors='coerce').notna().mean(),
            })

proxy_diagnostics = pd.DataFrame(proxy_rows)
proxy_diagnostics.to_csv(OUTDIR / 'proxy_specific_diagnostics.csv', index=False)
proxy_diagnostics.to_csv(OUTDIR / 'proxy_specific_diagnostics_by_run_target_split.csv', index=False)
proxy_diagnostics.head(30)
# Out:
#                              run_id  reference_label                            proxy               evaluator_backend_label   evaluator_backend_model                                      subset_policy  \
# 0         deepseek_v4_pro_limit1000  NOT ENOUGH INFO    nei_uncertainty_failure_proxy             DeepSeek V4-Pro API judge           deepseek-v4-pro     limit1000_qwen_target_from_fixed_response_file
# 1         deepseek_v4_pro_limit1000  NOT ENOUGH INFO    nei_uncertainty_failure_proxy             DeepSeek V4-Pro API judge           deepseek-v4-pro     limit1000_qwen_target_from_fixed_response_file
# 2   deepseek_v4_pro_llama_limit1000  NOT ENOUGH INFO    nei_uncertainty_failure_proxy             DeepSeek V4-Pro API judge           deepseek-v4-pro  matched_limit1000_llama_target_from_fixed_resp...
# 3   deepseek_v4_pro_llama_limit1000  NOT ENOUGH INFO    nei_uncertainty_failure_proxy             DeepSeek V4-Pro API judge           deepseek-v4-pro  matched_limit1000_llama_target_from_fixed_resp...
# 4              gemma3_12b_limit1000  NOT ENOUGH INFO    nei_uncertainty_failure_proxy             Gemma3-12B local HF judge     google/gemma-3-12b-it     limit1000_qwen_target_from_fixed_response_file
# 5              gemma3_12b_limit1000  NOT ENOUGH INFO    nei_uncertainty_failure_proxy             Gemma3-12B local HF judge     google/gemma-3-12b-it     limit1000_qwen_target_from_fixed_response_file
# 6        gemma3_12b_llama_limit1000  NOT ENOUGH INFO    nei_uncertainty_failure_proxy             Gemma3-12B local HF judge     google/gemma-3-12b-it  matched_limit1000_llama_target_from_fixed_resp...
# 7        gemma3_12b_llama_limit1000  NOT ENOUGH INFO    nei_uncertainty_failure_proxy             Gemma3-12B local HF judge     google/gemma-3-12b-it  matched_limit1000_llama_target_from_fixed_resp...
# 8                    heuristic_full  NOT ENOUGH INFO    nei_uncertainty_failure_proxy  Rule-based scoring backend (non-LLM)         heuristic/default          full_neutral_fever_qwen_and_llama_targets
# 9                    heuristic_full  NOT ENOUGH INFO    nei_uncertainty_failure_proxy  Rule-based scoring backend (non-LLM)         heuristic/default          full_neutral_fever_qwen_and_llama_targets
# 10                   heuristic_full  NOT ENOUGH INFO    nei_uncertainty_failure_proxy  Rule-based scoring backend (non-LLM)         heuristic/default          full_neutral_fever_qwen_and_llama_targets
# 11                   heuristic_full  NOT ENOUGH INFO    nei_uncertainty_failure_proxy  Rule-based scoring backend (non-LLM)         heuristic/default          full_neutral_fever_qwen_and_llama_targets
# 12                   heuristic_full  NOT ENOUGH INFO    nei_uncertainty_failure_proxy  Rule-based scoring backend (non-LLM)         heuristic/default          full_neutral_fever_qwen_and_llama_targets
# 13                   heuristic_full  NOT ENOUGH INFO    nei_uncertainty_failure_proxy  Rule-based scoring backend (non-LLM)         heuristic/default          full_neutral_fever_qwen_and_llama_targets
# 14                   heuristic_full  NOT ENOUGH INFO    nei_uncertainty_failure_proxy  Rule-based scoring backend (non-LLM)         heuristic/default          full_neutral_fever_qwen_and_llama_targets
# 15                   heuristic_full  NOT ENOUGH INFO    nei_uncertainty_failure_proxy  Rule-based scoring backend (non-LLM)         heuristic/default          full_neutral_fever_qwen_and_llama_targets
# 16                   heuristic_full  NOT ENOUGH INFO    nei_uncertainty_failure_proxy  Rule-based scoring backend (non-LLM)         heuristic/default          full_neutral_fever_qwen_and_llama_targets
# 17                   heuristic_full  NOT ENOUGH INFO    nei_uncertainty_failure_proxy  Rule-based scoring backend (non-LLM)         heuristic/default          full_neutral_fever_qwen_and_llama_targets
# 18                   heuristic_full  NOT ENOUGH INFO    nei_uncertainty_failure_proxy  Rule-based scoring backend (non-LLM)         heuristic/default          full_neutral_fever_qwen_and_llama_targets
# 19                   heuristic_full  NOT ENOUGH INFO    nei_uncertainty_failure_proxy  Rule-based scoring backend (non-LLM)         heuristic/default          full_neutral_fever_qwen_and_llama_targets
# 20              qwen25_7b_limit1000  NOT ENOUGH INFO    nei_uncertainty_failure_proxy             Qwen2.5-7B local HF judge  Qwen/Qwen2.5-7B-Instruct     limit1000_qwen_target_from_fixed_response_file
# 21              qwen25_7b_limit1000  NOT ENOUGH INFO    nei_uncertainty_failure_proxy             Qwen2.5-7B local HF judge  Qwen/Qwen2.5-7B-Instruct     limit1000_qwen_target_from_fixed_response_file
# 22        qwen25_7b_llama_limit1000  NOT ENOUGH INFO    nei_uncertainty_failure_proxy             Qwen2.5-7B local HF judge  Qwen/Qwen2.5-7B-Instruct  matched_limit1000_llama_target_from_fixed_resp...
# 23        qwen25_7b_llama_limit1000  NOT ENOUGH INFO    nei_uncertainty_failure_proxy             Qwen2.5-7B local HF judge  Qwen/Qwen2.5-7B-Instruct  matched_limit1000_llama_target_from_fixed_resp...
# 24              qwen3_14b_limit1000  NOT ENOUGH INFO    nei_uncertainty_failure_proxy              Qwen3-14B local HF judge            Qwen/Qwen3-14B     limit1000_qwen_target_from_fixed_response_file
# 25              qwen3_14b_limit1000  NOT ENOUGH INFO    nei_uncertainty_failure_proxy              Qwen3-14B local HF judge            Qwen/Qwen3-14B     limit1000_qwen_target_from_fixed_response_file
# 26        qwen3_14b_llama_limit1000  NOT ENOUGH INFO    nei_uncertainty_failure_proxy              Qwen3-14B local HF judge            Qwen/Qwen3-14B  matched_limit1000_llama_target_from_fixed_resp...
# 27        qwen3_14b_llama_limit1000  NOT ENOUGH INFO    nei_uncertainty_failure_proxy              Qwen3-14B local HF judge            Qwen/Qwen3-14B  matched_limit1000_llama_target_from_fixed_resp...
# 28        deepseek_v4_pro_limit1000          REFUTES  refutes_correction_credit_proxy             DeepSeek V4-Pro API judge           deepseek-v4-pro     limit1000_qwen_target_from_fixed_response_file
# 29        deepseek_v4_pro_limit1000          REFUTES  refutes_correction_credit_proxy             DeepSeek V4-Pro API judge           deepseek-v4-pro     limit1000_qwen_target_from_fixed_response_file
#
#          target_split                      target_model          evaluator_variant  rows  mean_proxy  non_null_share
# 0    target_qwen_only        Qwen/Qwen2.5-1.5B-Instruct           direct_llm_judge   330         NaN             0.0
# 1    target_qwen_only        Qwen/Qwen2.5-1.5B-Instruct     full_attack_aware_cale   330    0.915152             1.0
# 2   target_llama_only  meta-llama/Llama-3.2-1B-Instruct           direct_llm_judge   330         NaN             0.0
# 3   target_llama_only  meta-llama/Llama-3.2-1B-Instruct     full_attack_aware_cale   330    0.772727             1.0
# 4    target_qwen_only        Qwen/Qwen2.5-1.5B-Instruct           direct_llm_judge   330         NaN             0.0
# 5    target_qwen_only        Qwen/Qwen2.5-1.5B-Instruct     full_attack_aware_cale   330    0.266667             1.0
# 6   target_llama_only  meta-llama/Llama-3.2-1B-Instruct           direct_llm_judge   330         NaN             0.0
# 7   target_llama_only  meta-llama/Llama-3.2-1B-Instruct     full_attack_aware_cale   330    0.439394             1.0
# 8   target_llama_only  meta-llama/Llama-3.2-1B-Instruct          attack_aware_cale  6666    0.000450             1.0
# 9   target_llama_only  meta-llama/Llama-3.2-1B-Instruct            baseline_binary  6666         NaN             0.0
# 10  target_llama_only  meta-llama/Llama-3.2-1B-Instruct            baseline_likert  6666         NaN             0.0
# 11  target_llama_only  meta-llama/Llama-3.2-1B-Instruct  direct_trustllm_heuristic  6666         NaN             0.0
# 12  target_llama_only  meta-llama/Llama-3.2-1B-Instruct     full_attack_aware_cale  6666    0.000450             1.0
# 13  target_llama_only  meta-llama/Llama-3.2-1B-Instruct               generic_cale  6666    0.000450             1.0
# 14   target_qwen_only        Qwen/Qwen2.5-1.5B-Instruct          attack_aware_cale  6666    0.000600             1.0
# 15   target_qwen_only        Qwen/Qwen2.5-1.5B-Instruct            baseline_binary  6666         NaN             0.0
# 16   target_qwen_only        Qwen/Qwen2.5-1.5B-Instruct            baseline_likert  6666         NaN             0.0
# 17   target_qwen_only        Qwen/Qwen2.5-1.5B-Instruct  direct_trustllm_heuristic  6666         NaN             0.0
# 18   target_qwen_only        Qwen/Qwen2.5-1.5B-Instruct     full_attack_aware_cale  6666    0.000600             1.0
# 19   target_qwen_only        Qwen/Qwen2.5-1.5B-Instruct               generic_cale  6666    0.000600             1.0
# 20   target_qwen_only        Qwen/Qwen2.5-1.5B-Instruct           direct_llm_judge   330         NaN             0.0
# 21   target_qwen_only        Qwen/Qwen2.5-1.5B-Instruct     full_attack_aware_cale   330    0.178788             1.0
# 22  target_llama_only  meta-llama/Llama-3.2-1B-Instruct           direct_llm_judge   330         NaN             0.0
# 23  target_llama_only  meta-llama/Llama-3.2-1B-Instruct     full_attack_aware_cale   330    0.430303             1.0
# 24   target_qwen_only        Qwen/Qwen2.5-1.5B-Instruct           direct_llm_judge   330         NaN             0.0
# 25   target_qwen_only        Qwen/Qwen2.5-1.5B-Instruct     full_attack_aware_cale   330    0.478788             1.0
# 26  target_llama_only  meta-llama/Llama-3.2-1B-Instruct           direct_llm_judge   330         NaN             0.0
# 27  target_llama_only  meta-llama/Llama-3.2-1B-Instruct     full_attack_aware_cale   330    0.545455             1.0
# 28   target_qwen_only        Qwen/Qwen2.5-1.5B-Instruct           direct_llm_judge   339         NaN             0.0
# 29   target_qwen_only        Qwen/Qwen2.5-1.5B-Instruct     full_attack_aware_cale   339    0.926254             1.0

# %% [markdown]
# ## 16. Paper-Ready Figures and Tables
#
# This section exports compact, paper-facing artifacts from the audit tables above. These figures are designed to support the two thesis goals without turning the audit into a leaderboard.
#
# 本节把上面的 audit outputs 转成主文更容易使用的图表。这里不做新的评测实验，也不重新生成模型回答；只把已经算好的 global audit / PCA / backend agreement / target split summaries 重新整理成 paper-ready outputs。
#
# Reading rule: higher `final_score`, higher PCA variance, or stronger one-axis concentration does not by itself mean an evaluator is better. These exports are diagnostics for measurement structure, backend agreement, target-split sensitivity, and compact target-response profiles under fixed evaluator scope.
#
# 阅读提醒：这些图不是排行榜。PCA variance 表示结构集中程度，不等于 evaluator 质量；target-model heatmap 只有在固定 backend 和 `full_attack_aware_cale` scope 后才可以解释成 compact capability profile。

# %%
PAPER_OUTDIR = OUTDIR


def _paper_backend_short(label):
    return short_backend_label(label)


def _paper_backend_order(label):
    return backend_sort_key(label)


def _paper_target_label(split):
    split = str(split)
    if split == 'target_qwen_only':
        return 'Qwen target'
    if split == 'target_llama_only':
        return 'Llama target'
    if split == 'pooled_qwen_llama':
        return 'Pooled Qwen+Llama'
    return split


def _metric_label(col):
    labels = {
        'pc1_variance': 'PC1 variance\n(structure concentration)',
        'pc1_pc4_cumulative_variance': 'PC1-PC4 cumulative\n(structure coverage)',
        'backend_agreement_spearman_mean': 'Backend agreement\nSpearman',
        'abs_qwen_minus_llama_mean_score_delta': '|Qwen-Llama|\nfinal-score sensitivity',
        'max_abs_construct_qwen_minus_llama_delta': 'Max |Qwen-Llama|\nconstruct sensitivity',
        'factual_handling_mean': 'Factual handling\nmean',
        'resistance_boundary_mean': 'Resistance/boundary\nmean',
    }
    return labels.get(col, str(col).replace('_', ' '))


def _construct_label(col):
    labels = {
        'misinformation_detection': 'Misinformation\ndetection',
        'framing_resistance': 'Framing\nresistance',
        'claim_status_recognition': 'Claim status\nrecognition',
        'error_rejection': 'Error\nrejection',
        'correction_accuracy': 'Correction\naccuracy',
        'evidence_grounding': 'Evidence\ngrounding',
        'source_faithfulness': 'Source\nfaithfulness',
        'hallucination_control': 'Hallucination\ncontrol',
        'uncertainty_handling': 'Uncertainty\nhandling',
    }
    return labels.get(col, str(col).replace('_', '\n'))


def _annotated_heatmap(table, path, title, *, vmin=None, vmax=None, cmap='viridis', center_zero=False, cbar_label='', figsize=None, fmt='.2f', x_rotation=0):
    if table.empty:
        print(f'Skipped {path.name}: empty table')
        return
    matrix = table.apply(pd.to_numeric, errors='coerce')
    if figsize is None:
        figsize = (max(8.5, 0.8 * len(matrix.columns) + 2.4), max(3.8, 0.46 * len(matrix.index) + 1.4))
    fig, ax = plt.subplots(figsize=figsize)
    if center_zero:
        max_abs = np.nanmax(np.abs(matrix.values)) if np.isfinite(matrix.values).any() else 1.0
        bound = max(max_abs, 0.05)
        if vmin is None:
            vmin = -bound
        if vmax is None:
            vmax = bound
    image = ax.imshow(matrix.values, aspect='auto', vmin=vmin, vmax=vmax, cmap=cmap)
    ax.set_xticks(range(len(matrix.columns)))
    ax.set_xticklabels([_metric_label(c) if c in {'pc1_variance', 'pc1_pc4_cumulative_variance', 'backend_agreement_spearman_mean', 'abs_qwen_minus_llama_mean_score_delta', 'max_abs_construct_qwen_minus_llama_delta', 'factual_handling_mean', 'resistance_boundary_mean'} else _construct_label(c) for c in matrix.columns], rotation=x_rotation, ha='right' if x_rotation else 'center', fontsize=9)
    ax.set_yticks(range(len(matrix.index)))
    ax.set_yticklabels(matrix.index, fontsize=9)
    ax.tick_params(axis='both', length=0)
    for i in range(matrix.shape[0]):
        for j in range(matrix.shape[1]):
            value = matrix.iloc[i, j]
            if pd.notna(value):
                text_color = 'white' if (not center_zero and value >= 0.62) else 'black'
                if center_zero and abs(value) >= 0.55 * max(abs(vmin), abs(vmax)):
                    text_color = 'white'
                ax.text(j, i, format(value, fmt), ha='center', va='center', fontsize=8, color=text_color)
    cbar = fig.colorbar(image, ax=ax, fraction=0.036, pad=0.03)
    if cbar_label:
        cbar.set_label(cbar_label, fontsize=9)
    ax.set_title(title, fontsize=12, pad=12)
    fig.tight_layout()
    fig.savefig(path, dpi=300, bbox_inches='tight')
    plt.close(fig)
    print(f'Wrote {path}')


# Table 1 / Figure 1: Goal 1 measurement-quality core dashboard.
paper_table_measurement_quality_core = pd.DataFrame()
if 'measurement_quality_summary' in globals() and not measurement_quality_summary.empty:
    mq = measurement_quality_summary.copy()
    mq = mq[(mq['evaluator_variant'].eq(FULL_CALE_VARIANT)) & (mq['target_split'].eq('pooled_qwen_llama'))].copy()
    if not mq.empty:
        mq['backend_short_paper'] = mq['evaluator_backend_label'].map(_paper_backend_short)
        mq['backend_order_paper'] = mq['evaluator_backend_label'].map(_paper_backend_order)
        keep_cols = [
            'backend_short_paper', 'backend_order_paper', 'evaluator_backend_label', 'evaluator_backend_model', 'evaluator_variant',
            'target_split', 'rows', 'pc1_variance', 'pc1_pc4_cumulative_variance',
            'backend_agreement_spearman_mean', 'backend_agreement_mae_mean',
            'abs_qwen_minus_llama_mean_score_delta', 'max_abs_construct_qwen_minus_llama_delta',
            'largest_target_sensitive_construct', 'claim_readiness', 'pca_interpretation_warning'
        ]
        paper_table_measurement_quality_core = mq[[c for c in keep_cols if c in mq.columns]].copy()
        paper_table_measurement_quality_core = paper_table_measurement_quality_core.sort_values('backend_order_paper')
        paper_table_measurement_quality_core = paper_table_measurement_quality_core.drop(columns=['backend_order_paper'], errors='ignore')

paper_table_measurement_quality_core.to_csv(PAPER_OUTDIR / 'paper_table_measurement_quality_core.csv', index=False)
if paper_table_measurement_quality_core.empty:
    print('No paper measurement-quality core table available yet.')
else:
    display(paper_table_measurement_quality_core.round(3))
    dashboard_cols = [
        'pc1_variance', 'pc1_pc4_cumulative_variance', 'backend_agreement_spearman_mean',
        'abs_qwen_minus_llama_mean_score_delta', 'max_abs_construct_qwen_minus_llama_delta'
    ]
    dashboard = paper_table_measurement_quality_core.set_index('backend_short_paper')[[c for c in dashboard_cols if c in paper_table_measurement_quality_core.columns]]
    _annotated_heatmap(
        dashboard,
        PAPER_OUTDIR / 'paper_goal1_measurement_quality_dashboard.png',
        'Goal 1: Measurement-Quality Diagnostics Under Full CALE',
        vmin=0,
        vmax=1,
        cmap='YlGnBu',
        cbar_label='diagnostic value (not a leaderboard score)',
        figsize=(10.8, max(3.8, 0.55 * len(dashboard) + 1.8)),
    )


# Table 2 / Figure 2: Goal 2 compact target capability profile under fixed full CALE scope.
paper_table_compact_capability_core = pd.DataFrame()
if 'compact_capability_summary' in globals() and not compact_capability_summary.empty:
    cap = compact_capability_summary.copy()
    cap = cap[
        cap['evaluator_variant'].eq(FULL_CALE_VARIANT)
        & cap['target_split'].isin(['target_qwen_only', 'target_llama_only'])
    ].copy()
    if not cap.empty:
        cap['backend_short_paper'] = cap['evaluator_backend_label'].map(_paper_backend_short)
        cap['backend_order_paper'] = cap['evaluator_backend_label'].map(_paper_backend_order)
        cap['target_model_paper'] = cap['target_split'].map(_paper_target_label)
        construct_cols = [c for c in CORE_BEHAVIOR_COLUMNS if c in cap.columns]
        keep_cols = [
            'backend_short_paper', 'backend_order_paper', 'target_model_paper', 'evaluator_backend_label', 'evaluator_backend_model',
            'evaluator_variant', 'target_split', 'target_models', 'rows', 'source_run_ids',
            'factual_handling_mean', 'resistance_boundary_mean'
        ] + construct_cols
        paper_table_compact_capability_core = cap[[c for c in keep_cols if c in cap.columns]].copy()
        paper_table_compact_capability_core = paper_table_compact_capability_core.sort_values(['backend_order_paper', 'target_model_paper'])
        paper_table_compact_capability_core = paper_table_compact_capability_core.drop(columns=['backend_order_paper'], errors='ignore')

paper_table_compact_capability_core.to_csv(PAPER_OUTDIR / 'paper_table_compact_capability_core.csv', index=False)
if paper_table_compact_capability_core.empty:
    print('No paper compact capability table available yet.')
else:
    display(paper_table_compact_capability_core.round(3))
    capability_cols = [
        c for c in ['factual_handling_mean', 'resistance_boundary_mean'] + list(CORE_BEHAVIOR_COLUMNS)
        if c in paper_table_compact_capability_core.columns
    ]
    cap_heatmap = paper_table_compact_capability_core.copy()
    cap_heatmap['row_label'] = cap_heatmap['backend_short_paper'] + ' | ' + cap_heatmap['target_model_paper']
    cap_heatmap = cap_heatmap.set_index('row_label')[capability_cols]
    _annotated_heatmap(
        cap_heatmap,
        PAPER_OUTDIR / 'paper_goal2_compact_target_capability_heatmap.png',
        'Goal 2: Compact Target-Response Profile Under Full CALE',
        vmin=0,
        vmax=1,
        cmap='viridis',
        cbar_label='mean construct score under fixed evaluator scope',
        figsize=(15.0, max(5.0, 0.50 * len(cap_heatmap) + 2.0)),
        x_rotation=30,
    )


# Figure 3: Backend agreement on shared full-CALE rows. Low agreement is evidence that backend choice matters.
def _plot_backend_agreement_heatmap(alignment_df, path):
    if alignment_df.empty:
        print(f'Skipped {path.name}: empty backend alignment table')
        return
    rows = alignment_df[alignment_df['evaluator_variant'].eq(FULL_CALE_VARIANT)].copy()
    if rows.empty:
        print(f'Skipped {path.name}: no full CALE backend agreement rows')
        return
    rows['backend_left_short'] = rows['backend_left'].map(_paper_backend_short)
    rows['backend_right_short'] = rows['backend_right'].map(_paper_backend_short)
    split_order = [s for s in ['pooled_qwen_llama', 'target_qwen_only', 'target_llama_only'] if s in set(rows['target_split'])]
    backends = sorted(set(rows['backend_left_short']).union(set(rows['backend_right_short'])), key=backend_sort_key)
    if not split_order or len(backends) < 2:
        print(f'Skipped {path.name}: not enough splits/backends')
        return
    fig, axes = plt.subplots(1, len(split_order), figsize=(5.2 * len(split_order) + 0.8, 4.8), squeeze=False)
    for ax, split in zip(axes[0], split_order):
        matrix = pd.DataFrame(np.nan, index=backends, columns=backends, dtype=float)
        np.fill_diagonal(matrix.values, 1.0)
        sub = rows[rows['target_split'].eq(split)]
        for _, row in sub.iterrows():
            left = row['backend_left_short']
            right = row['backend_right_short']
            value = row.get('spearman', np.nan)
            matrix.loc[left, right] = value
            matrix.loc[right, left] = value
        image = ax.imshow(matrix.values, vmin=-1, vmax=1, cmap='RdBu_r')
        ax.set_xticks(range(len(backends)))
        ax.set_xticklabels(backends, rotation=30, ha='right', fontsize=8)
        ax.set_yticks(range(len(backends)))
        ax.set_yticklabels(backends, fontsize=8)
        ax.set_title(_paper_target_label(split), fontsize=10)
        ax.tick_params(axis='both', length=0)
        for i in range(matrix.shape[0]):
            for j in range(matrix.shape[1]):
                value = matrix.iloc[i, j]
                if pd.notna(value):
                    ax.text(j, i, f'{value:.2f}', ha='center', va='center', fontsize=8, color='white' if abs(value) > 0.55 else 'black')
    fig.suptitle('Backend Agreement on Shared Full-CALE Rows (Spearman)', fontsize=12, y=0.98)
    fig.subplots_adjust(left=0.08, right=0.90, bottom=0.25, top=0.82, wspace=0.55)
    cbar_ax = fig.add_axes([0.925, 0.25, 0.015, 0.57])
    cbar = fig.colorbar(image, cax=cbar_ax)
    cbar.set_label('Spearman correlation; not a quality ranking', fontsize=9)
    fig.savefig(path, dpi=300, bbox_inches='tight')
    plt.close(fig)
    print(f'Wrote {path}')

_plot_backend_agreement_heatmap(backend_alignment if 'backend_alignment' in globals() else pd.DataFrame(), PAPER_OUTDIR / 'paper_backend_agreement_heatmap.png')


# Figure 4: Target-split sensitivity as Qwen-target minus Llama-target construct deltas.
def _plot_target_split_sensitivity(delta_df, path):
    if delta_df.empty:
        print(f'Skipped {path.name}: empty target delta table')
        return
    rows = delta_df.copy()
    if 'evaluator_variant' in rows.columns:
        rows = rows[rows['evaluator_variant'].eq(FULL_CALE_VARIANT)].copy()
    construct_cols = [c for c in CORE_BEHAVIOR_COLUMNS if c in rows.columns]
    if rows.empty or not construct_cols:
        print(f'Skipped {path.name}: no full CALE construct deltas')
        return
    rows['backend_short_paper'] = rows['evaluator_backend_label'].map(_paper_backend_short)
    rows['backend_order_paper'] = rows['evaluator_backend_label'].map(_paper_backend_order)
    rows = rows.sort_values('backend_order_paper')
    rows['backend_order_paper'] = rows['evaluator_backend_label'].map(_paper_backend_order)
    rows = rows.sort_values(['backend_order_paper', 'backend_short_paper'])
    matrix = rows.set_index('backend_short_paper')[construct_cols].apply(pd.to_numeric, errors='coerce')
    matrix = matrix.loc[~matrix.index.duplicated(keep='first')]
    max_abs = np.nanmax(np.abs(matrix.values)) if np.isfinite(matrix.values).any() else 0.5
    bound = max(0.15, min(1.0, max_abs))
    _annotated_heatmap(
        matrix,
        path,
        'Target-Split Sensitivity Under Full CALE: Qwen Target Minus Llama Target',
        vmin=-bound,
        vmax=bound,
        cmap='RdBu_r',
        center_zero=True,
        cbar_label='Qwen-target mean minus Llama-target mean',
        figsize=(12.8, max(4.0, 0.52 * len(matrix) + 1.8)),
        x_rotation=25,
    )

_plot_target_split_sensitivity(full_cale_target_delta if 'full_cale_target_delta' in globals() else pd.DataFrame(), PAPER_OUTDIR / 'paper_target_split_sensitivity_heatmap.png')

print('Paper-ready outputs requested by this section:')
for name in [
    'paper_table_measurement_quality_core.csv',
    'paper_goal1_measurement_quality_dashboard.png',
    'paper_table_compact_capability_core.csv',
    'paper_goal2_compact_target_capability_heatmap.png',
    'paper_backend_agreement_heatmap.png',
    'paper_target_split_sensitivity_heatmap.png',
]:
    path = PAPER_OUTDIR / name
    print(f'- {name}: {path.exists()}')
# Out:
#      backend_short_paper               evaluator_backend_label   evaluator_backend_model       evaluator_variant       target_split   rows  pc1_variance  pc1_pc4_cumulative_variance  backend_agreement_spearman_mean  \
# 36  Rule-based heuristic  Rule-based scoring backend (non-LLM)         heuristic/default  full_attack_aware_cale  pooled_qwen_llama  39996         0.252                        0.650                            0.422
# 15      Qwen2.5-7B judge             Qwen2.5-7B local HF judge  Qwen/Qwen2.5-7B-Instruct  full_attack_aware_cale  pooled_qwen_llama   2000         0.548                        0.831                            0.468
# 21       Qwen3-14B judge              Qwen3-14B local HF judge            Qwen/Qwen3-14B  full_attack_aware_cale  pooled_qwen_llama   2000         0.484                        0.837                            0.521
# 9       Gemma3-12B judge             Gemma3-12B local HF judge     google/gemma-3-12b-it  full_attack_aware_cale  pooled_qwen_llama   2000         0.556                        0.852                            0.507
# 3        DeepSeek V4-Pro             DeepSeek V4-Pro API judge           deepseek-v4-pro  full_attack_aware_cale  pooled_qwen_llama   2000         0.684                        0.909                            0.212
#
#     backend_agreement_mae_mean  abs_qwen_minus_llama_mean_score_delta  max_abs_construct_qwen_minus_llama_delta largest_target_sensitive_construct                                    claim_readiness  \
# 36                       0.214                                  0.027                                     0.477           misinformation_detection  primary_preliminary_evidence: internal structu...
# 15                       0.201                                  0.101                                     0.266           misinformation_detection  primary_preliminary_evidence: internal structu...
# 21                       0.204                                  0.103                                     0.259                    error_rejection  primary_preliminary_evidence: internal structu...
# 9                        0.191                                  0.083                                     0.210                    error_rejection  primary_preliminary_evidence: internal structu...
# 3                        0.334                                  0.063                                     0.114                 evidence_grounding  primary_preliminary_evidence: internal structu...
#
#                            pca_interpretation_warning
# 36  Explained variance indicates structure/concent...
# 15  Explained variance indicates structure/concent...
# 21  Explained variance indicates structure/concent...
# 9   Explained variance indicates structure/concent...
# 3   Explained variance indicates structure/concent...
# Wrote figures/global_evaluator_audit/paper_goal1_measurement_quality_dashboard.png
#      backend_short_paper target_model_paper               evaluator_backend_label   evaluator_backend_model       evaluator_variant       target_split                     target_models   rows  \
# 4   Rule-based heuristic       Llama target  Rule-based scoring backend (non-LLM)         heuristic/default  full_attack_aware_cale  target_llama_only  meta-llama/Llama-3.2-1B-Instruct  19998
# 5   Rule-based heuristic        Qwen target  Rule-based scoring backend (non-LLM)         heuristic/default  full_attack_aware_cale   target_qwen_only        Qwen/Qwen2.5-1.5B-Instruct  19998
# 10      Qwen2.5-7B judge       Llama target             Qwen2.5-7B local HF judge  Qwen/Qwen2.5-7B-Instruct  full_attack_aware_cale  target_llama_only  meta-llama/Llama-3.2-1B-Instruct   1000
# 11      Qwen2.5-7B judge        Qwen target             Qwen2.5-7B local HF judge  Qwen/Qwen2.5-7B-Instruct  full_attack_aware_cale   target_qwen_only        Qwen/Qwen2.5-1.5B-Instruct   1000
# 13       Qwen3-14B judge       Llama target              Qwen3-14B local HF judge            Qwen/Qwen3-14B  full_attack_aware_cale  target_llama_only  meta-llama/Llama-3.2-1B-Instruct   1000
# 14       Qwen3-14B judge        Qwen target              Qwen3-14B local HF judge            Qwen/Qwen3-14B  full_attack_aware_cale   target_qwen_only        Qwen/Qwen2.5-1.5B-Instruct   1000
# 7       Gemma3-12B judge       Llama target             Gemma3-12B local HF judge     google/gemma-3-12b-it  full_attack_aware_cale  target_llama_only  meta-llama/Llama-3.2-1B-Instruct   1000
# 8       Gemma3-12B judge        Qwen target             Gemma3-12B local HF judge     google/gemma-3-12b-it  full_attack_aware_cale   target_qwen_only        Qwen/Qwen2.5-1.5B-Instruct   1000
# 1        DeepSeek V4-Pro       Llama target             DeepSeek V4-Pro API judge           deepseek-v4-pro  full_attack_aware_cale  target_llama_only  meta-llama/Llama-3.2-1B-Instruct   1000
# 2        DeepSeek V4-Pro        Qwen target             DeepSeek V4-Pro API judge           deepseek-v4-pro  full_attack_aware_cale   target_qwen_only        Qwen/Qwen2.5-1.5B-Instruct   1000
#
#                      source_run_ids  factual_handling_mean  resistance_boundary_mean  misinformation_detection  framing_resistance  claim_status_recognition  error_rejection  correction_accuracy  evidence_grounding  \
# 4                    heuristic_full                  0.633                     0.986                     0.283               0.989                     0.584            0.964                0.462               0.917
# 5                    heuristic_full                  0.696                     0.993                     0.760               0.999                     0.591            0.998                0.368               0.879
# 10        qwen25_7b_llama_limit1000                  0.727                     0.832                     0.516               0.878                     0.769            0.636                0.739               0.774
# 11              qwen25_7b_limit1000                  0.862                     0.922                     0.782               0.951                     0.917            0.803                0.860               0.826
# 13        qwen3_14b_llama_limit1000                  0.597                     0.669                     0.463               0.634                     0.670            0.400                0.482               0.556
# 14              qwen3_14b_limit1000                  0.709                     0.798                     0.691               0.799                     0.767            0.659                0.570               0.644
# 7        gemma3_12b_llama_limit1000                  0.748                     0.757                     0.757               0.676                     0.763            0.532                0.573               0.784
# 8              gemma3_12b_limit1000                  0.828                     0.862                     0.842               0.832                     0.891            0.742                0.744               0.770
# 1   deepseek_v4_pro_llama_limit1000                  0.454                     0.511                     0.525               0.685                     0.451            0.557                0.542               0.348
# 2         deepseek_v4_pro_limit1000                  0.531                     0.584                     0.638               0.789                     0.512            0.621                0.564               0.462
#
#     source_faithfulness  hallucination_control  uncertainty_handling
# 4                 0.917                  0.994                 0.999
# 5                 0.880                  0.978                 0.999
# 10                0.839                  0.972                 0.843
# 11                0.925                  0.994                 0.940
# 13                0.814                  0.852                 0.788
# 14                0.871                  0.899                 0.836
# 7                 0.865                  0.977                 0.843
# 8                 0.894                  0.972                 0.904
# 1                 0.406                  0.379                 0.423
# 2                 0.478                  0.445                 0.481
# Wrote figures/global_evaluator_audit/paper_goal2_compact_target_capability_heatmap.png
# Wrote figures/global_evaluator_audit/paper_backend_agreement_heatmap.png
# Wrote figures/global_evaluator_audit/paper_target_split_sensitivity_heatmap.png
# Paper-ready outputs requested by this section:
# - paper_table_measurement_quality_core.csv: True
# - paper_goal1_measurement_quality_dashboard.png: True
# - paper_table_compact_capability_core.csv: True
# - paper_goal2_compact_target_capability_heatmap.png: True
# - paper_backend_agreement_heatmap.png: True
# - paper_target_split_sensitivity_heatmap.png: True

# %% [markdown]
# ## 17. Paper-Facing Global Summary

# %%
summary_lines = []
summary_lines.append('# Global Evaluator Audit Summary')
summary_lines.append('')
summary_lines.append('Layer reminder: `target_model` is the response-generating model; `evaluator_backend_label` is the judge backend; `evaluator_variant` is the evaluation protocol.')
summary_lines.append('This is an audit notebook, not a leaderboard. We include weaker or simpler evaluator/protocol settings as robustness and sensitivity controls, not as interchangeable judges in a single calibrated ranking.')
summary_lines.append('Evaluator evidence is organized as backend/protocol/split, not as a flat evaluator-model comparison.')
summary_lines.append('Goal 1 asks whether evaluator/protocol behavior looks like coherent measurement evidence; Goal 2 asks whether full CALE can be summarized into compact target-model capability profiles after backend/protocol scope is fixed.')
summary_lines.append('')

if not audit.empty:
    summary_lines.append('## File Audit')
    for _, row in audit.iterrows():
        summary_lines.append(
            f"- {row['evaluator_backend_label']} / {row['run_id']}: exists={row['exists']}, report_exists={row.get('report_path_exists', False)}, rows={row['rows']}/{row['expected_rows']}, "
            f"coverage={row['target_coverage']}, variants=[{row['evaluator_variants']}]."
        )
    summary_lines.append('')

if 'protocol_backend_pca' in globals() and not protocol_backend_pca.empty:
    summary_lines.append('## Protocol-Level PCA Audit')
    pooled = protocol_backend_pca[protocol_backend_pca['target_split'].isin(['pooled_qwen_llama', 'pooled_all_available_targets'])].copy()
    pooled = pooled[pooled.get('pc1_pc4_cumulative_variance', pd.Series(index=pooled.index, dtype=float)).notna()]
    sort_cols = [c for c in ['backend_order', 'variant_order', 'evaluator_variant'] if c in pooled.columns]
    ordered_pooled = pooled.sort_values(sort_cols) if sort_cols else pooled
    for _, row in ordered_pooled.iterrows():
        summary_lines.append(
            f"- {row['backend_short']} / {row['evaluator_variant']} / {row['target_split']}: "
            f"PC1={row.get('pc1_variance', np.nan):.3f}, PC1-PC4={row.get('pc1_pc4_cumulative_variance', np.nan):.3f}, "
            f"n={int(row['rows'])}, PC1 top={row.get('pc1_top_variables', '')}."
        )
    summary_lines.append('')

if 'target_model_dominance_pca' in globals() and not target_model_dominance_pca.empty:
    summary_lines.append('## Full-CALE PCA / Target Dominance')
    for _, row in target_model_dominance_pca.iterrows():
        if pd.notna(row.get('pc1_pc4_cumulative_variance', np.nan)):
            summary_lines.append(
                f"- {row['evaluator_backend_label']} / {row['target_split']}: "
                f"PC1={row.get('pc1_variance', np.nan):.3f}, PC1-PC4={row['pc1_pc4_cumulative_variance']:.3f}; "
                f"PC1 top variables={row.get('pc1_top_variables', '')}."
            )
    summary_lines.append('')

summary_lines.append('## Final Goal Tables')
summary_lines.append('- `measurement_quality_summary.csv`: Goal 1 measurement-quality audit table. Interpret PCA variance as structure/concentration, not better-by-itself.')
summary_lines.append('- `compact_capability_summary.csv`: Goal 2 compact full-CALE target capability table, scoped by evaluator backend and target split.')
summary_lines.append('- `paper_table_measurement_quality_core.csv`: paper-facing Goal 1 core table.')
summary_lines.append('- `paper_goal1_measurement_quality_dashboard.png`: paper-facing Goal 1 dashboard.')
summary_lines.append('- `paper_table_compact_capability_core.csv`: paper-facing Goal 2 compact capability table.')
summary_lines.append('- `paper_goal2_compact_target_capability_heatmap.png`: paper-facing Goal 2 heatmap.')
summary_lines.append('- `paper_backend_agreement_heatmap.png`: backend agreement heatmap for shared rows.')
summary_lines.append('- `paper_target_split_sensitivity_heatmap.png`: Qwen-minus-Llama construct sensitivity heatmap.')
summary_lines.append('')
summary_lines.append('## Recommended Outputs')
summary_lines.append('- `global_file_audit.csv`')
summary_lines.append('- `cross_product_coverage_compact.csv`')
summary_lines.append('- `outcome_summary_three_layers.csv`')
summary_lines.append('- `direct_vs_full_cale_delta.csv`')
summary_lines.append('- `protocol_backend_pca_summary.csv`')
summary_lines.append('- `protocol_backend_pca_variance_pooled.png`')
summary_lines.append('- `protocol_backend_pca_pc1_by_target_split.png`')
summary_lines.append('- `protocol_backend_pca_pc1_pc4_by_target_split.png`')
summary_lines.append('- `full_cale_construct_profile_by_backend_protocol_target_split.csv`')
summary_lines.append('- `full_cale_construct_profile_compact.csv`')
summary_lines.append('- `backend_pair_score_alignment_by_target_split.csv`')
summary_lines.append('- `schema_missingness_by_run_target_split.csv`')
summary_lines.append('- `proxy_specific_diagnostics_by_run_target_split.csv`')
summary_lines.append('- `target_model_dominance_pca_summary.csv`')
summary_lines.append('- `target_model_dominance_pc1_variance.png`')
summary_lines.append('- `target_model_dominance_variance.png`')
summary_lines.append('- `heuristic_full_variant_ladder_by_target_split.csv`')
summary_lines.append('- `paper_table_measurement_quality_core.csv`')
summary_lines.append('- `paper_goal1_measurement_quality_dashboard.png`')
summary_lines.append('- `paper_table_compact_capability_core.csv`')
summary_lines.append('- `paper_goal2_compact_target_capability_heatmap.png`')
summary_lines.append('- `paper_backend_agreement_heatmap.png`')
summary_lines.append('- `paper_target_split_sensitivity_heatmap.png`')
summary_lines.append('')

summary_lines.append('## Caveats')
summary_lines.append('- Strong evaluator `limit1000` runs are interpreted as balanced backend evidence only when both Qwen-target and Llama-target matched files are present.')
summary_lines.append('- The rule-based heuristic backend is not Qwen, not Llama, and not a Qwen/Llama average.')
summary_lines.append('- Do not interpret cross-backend absolute scores or PCA variance as a calibrated leaderboard.')
summary_lines.append('- High PC1 variance means stronger one-axis concentration, not automatically better measurement quality.')
summary_lines.append('- PCA signs are arbitrary; interpret loading magnitudes and variable clusters.')

summary_text = chr(10).join(summary_lines)
(OUTDIR / 'global_interpretation_notes.md').write_text(summary_text, encoding='utf-8')
print(summary_text)
# Out:
# # Global Evaluator Audit Summary
#
# Layer reminder: `target_model` is the response-generating model; `evaluator_backend_label` is the judge backend; `evaluator_variant` is the evaluation protocol.
# This is an audit notebook, not a leaderboard. We include weaker or simpler evaluator/protocol settings as robustness and sensitivity controls, not as interchangeable judges in a single calibrated ranking.
# Evaluator evidence is organized as backend/protocol/split, not as a flat evaluator-model comparison.
# Goal 1 asks whether evaluator/protocol behavior looks like coherent measurement evidence; Goal 2 asks whether full CALE can be summarized into compact target-model capability profiles after backend/protocol scope is fixed.
#
# ## File Audit
# - Rule-based scoring backend (non-LLM) / heuristic_full: exists=True, report_exists=True, rows=239976/239976, coverage=pooled_qwen_llama, variants=[attack_aware_cale, baseline_binary, baseline_likert, direct_trustllm_heuristic, full_attack_aware_cale, generic_cale].
# - Qwen2.5-7B local HF judge / qwen25_7b_limit1000: exists=True, report_exists=True, rows=2000/2000, coverage=qwen_target_only, variants=[direct_llm_judge, full_attack_aware_cale].
# - Qwen2.5-7B local HF judge / qwen25_7b_llama_limit1000: exists=True, report_exists=True, rows=2000/2000, coverage=llama_target_only, variants=[direct_llm_judge, full_attack_aware_cale].
# - Qwen3-14B local HF judge / qwen3_14b_limit1000: exists=True, report_exists=True, rows=2000/2000, coverage=qwen_target_only, variants=[direct_llm_judge, full_attack_aware_cale].
# - Qwen3-14B local HF judge / qwen3_14b_llama_limit1000: exists=True, report_exists=True, rows=2000/2000, coverage=llama_target_only, variants=[direct_llm_judge, full_attack_aware_cale].
# - Gemma3-12B local HF judge / gemma3_12b_limit1000: exists=True, report_exists=True, rows=2000/2000, coverage=qwen_target_only, variants=[direct_llm_judge, full_attack_aware_cale].
# - Gemma3-12B local HF judge / gemma3_12b_llama_limit1000: exists=True, report_exists=True, rows=2000/2000, coverage=llama_target_only, variants=[direct_llm_judge, full_attack_aware_cale].
# - DeepSeek V4-Pro API judge / deepseek_v4_pro_limit1000: exists=True, report_exists=True, rows=2000/2000, coverage=qwen_target_only, variants=[direct_llm_judge, full_attack_aware_cale].
# - DeepSeek V4-Pro API judge / deepseek_v4_pro_llama_limit1000: exists=True, report_exists=True, rows=2000/2000, coverage=llama_target_only, variants=[direct_llm_judge, full_attack_aware_cale].
#
# ## Protocol-Level PCA Audit
# - Rule-based heuristic / generic_cale / pooled_qwen_llama: PC1=0.229, PC1-PC4=0.675, n=39996, PC1 top=source_faithfulness, claim_status_recognition, correction_accuracy, evidence_grounding.
# - Rule-based heuristic / attack_aware_cale / pooled_qwen_llama: PC1=0.271, PC1-PC4=0.705, n=39996, PC1 top=source_faithfulness, evidence_grounding, claim_status_recognition, correction_accuracy.
# - Rule-based heuristic / full_attack_aware_cale / pooled_qwen_llama: PC1=0.252, PC1-PC4=0.650, n=39996, PC1 top=source_faithfulness, evidence_grounding, claim_status_recognition, correction_accuracy.
# - Qwen2.5-7B judge / full_attack_aware_cale / pooled_qwen_llama: PC1=0.548, PC1-PC4=0.831, n=2000, PC1 top=uncertainty_handling, claim_status_recognition, source_faithfulness, evidence_grounding.
# - Qwen3-14B judge / full_attack_aware_cale / pooled_qwen_llama: PC1=0.484, PC1-PC4=0.837, n=2000, PC1 top=claim_status_recognition, correction_accuracy, framing_resistance, uncertainty_handling.
# - Gemma3-12B judge / full_attack_aware_cale / pooled_qwen_llama: PC1=0.556, PC1-PC4=0.852, n=2000, PC1 top=claim_status_recognition, uncertainty_handling, framing_resistance, misinformation_detection.
# - DeepSeek V4-Pro / full_attack_aware_cale / pooled_qwen_llama: PC1=0.684, PC1-PC4=0.909, n=2000, PC1 top=source_faithfulness, evidence_grounding, claim_status_recognition, uncertainty_handling.
#
# ## Full-CALE PCA / Target Dominance
# - DeepSeek V4-Pro API judge / pooled_qwen_llama: PC1=0.684, PC1-PC4=0.909; PC1 top variables=source_faithfulness, evidence_grounding, claim_status_recognition, uncertainty_handling.
# - DeepSeek V4-Pro API judge / target_llama_only: PC1=0.619, PC1-PC4=0.882; PC1 top variables=source_faithfulness, uncertainty_handling, claim_status_recognition, evidence_grounding.
# - DeepSeek V4-Pro API judge / target_qwen_only: PC1=0.747, PC1-PC4=0.937; PC1 top variables=evidence_grounding, source_faithfulness, claim_status_recognition, uncertainty_handling.
# - Gemma3-12B local HF judge / pooled_qwen_llama: PC1=0.556, PC1-PC4=0.852; PC1 top variables=claim_status_recognition, uncertainty_handling, framing_resistance, misinformation_detection.
# - Gemma3-12B local HF judge / target_llama_only: PC1=0.557, PC1-PC4=0.850; PC1 top variables=claim_status_recognition, framing_resistance, uncertainty_handling, misinformation_detection.
# - Gemma3-12B local HF judge / target_qwen_only: PC1=0.556, PC1-PC4=0.860; PC1 top variables=uncertainty_handling, claim_status_recognition, framing_resistance, source_faithfulness.
# - Qwen2.5-7B local HF judge / pooled_qwen_llama: PC1=0.548, PC1-PC4=0.831; PC1 top variables=uncertainty_handling, claim_status_recognition, source_faithfulness, evidence_grounding.
# - Qwen2.5-7B local HF judge / target_llama_only: PC1=0.573, PC1-PC4=0.855; PC1 top variables=uncertainty_handling, claim_status_recognition, source_faithfulness, evidence_grounding.
# - Qwen2.5-7B local HF judge / target_qwen_only: PC1=0.488, PC1-PC4=0.798; PC1 top variables=uncertainty_handling, claim_status_recognition, source_faithfulness, error_rejection.
# - Qwen3-14B local HF judge / pooled_qwen_llama: PC1=0.484, PC1-PC4=0.837; PC1 top variables=claim_status_recognition, correction_accuracy, framing_resistance, uncertainty_handling.
# - Qwen3-14B local HF judge / target_llama_only: PC1=0.475, PC1-PC4=0.821; PC1 top variables=claim_status_recognition, framing_resistance, correction_accuracy, uncertainty_handling.
# - Qwen3-14B local HF judge / target_qwen_only: PC1=0.481, PC1-PC4=0.857; PC1 top variables=claim_status_recognition, correction_accuracy, framing_resistance, error_rejection.
# - Rule-based scoring backend (non-LLM) / pooled_qwen_llama: PC1=0.252, PC1-PC4=0.650; PC1 top variables=source_faithfulness, evidence_grounding, claim_status_recognition, correction_accuracy.
# - Rule-based scoring backend (non-LLM) / target_llama_only: PC1=0.245, PC1-PC4=0.657; PC1 top variables=source_faithfulness, evidence_grounding, claim_status_recognition, correction_accuracy.
# - Rule-based scoring backend (non-LLM) / target_qwen_only: PC1=0.263, PC1-PC4=0.642; PC1 top variables=source_faithfulness, evidence_grounding, claim_status_recognition, correction_accuracy.
#
# ## Final Goal Tables
# - `measurement_quality_summary.csv`: Goal 1 measurement-quality audit table. Interpret PCA variance as structure/concentration, not better-by-itself.
# - `compact_capability_summary.csv`: Goal 2 compact full-CALE target capability table, scoped by evaluator backend and target split.
# - `paper_table_measurement_quality_core.csv`: paper-facing Goal 1 core table.
# - `paper_goal1_measurement_quality_dashboard.png`: paper-facing Goal 1 dashboard.
# - `paper_table_compact_capability_core.csv`: paper-facing Goal 2 compact capability table.
# - `paper_goal2_compact_target_capability_heatmap.png`: paper-facing Goal 2 heatmap.
# - `paper_backend_agreement_heatmap.png`: backend agreement heatmap for shared rows.
# - `paper_target_split_sensitivity_heatmap.png`: Qwen-minus-Llama construct sensitivity heatmap.
#
# ## Recommended Outputs
# - `global_file_audit.csv`
# - `cross_product_coverage_compact.csv`
# - `outcome_summary_three_layers.csv`
# - `direct_vs_full_cale_delta.csv`
# - `protocol_backend_pca_summary.csv`
# - `protocol_backend_pca_variance_pooled.png`
# - `protocol_backend_pca_pc1_by_target_split.png`
# - `protocol_backend_pca_pc1_pc4_by_target_split.png`
# - `full_cale_construct_profile_by_backend_protocol_target_split.csv`
# - `full_cale_construct_profile_compact.csv`
# - `backend_pair_score_alignment_by_target_split.csv`
# - `schema_missingness_by_run_target_split.csv`
# - `proxy_specific_diagnostics_by_run_target_split.csv`
# - `target_model_dominance_pca_summary.csv`
# - `target_model_dominance_pc1_variance.png`
# - `target_model_dominance_variance.png`
# - `heuristic_full_variant_ladder_by_target_split.csv`
# - `paper_table_measurement_quality_core.csv`
# - `paper_goal1_measurement_quality_dashboard.png`
# - `paper_table_compact_capability_core.csv`
# - `paper_goal2_compact_target_capability_heatmap.png`
# - `paper_backend_agreement_heatmap.png`
# - `paper_target_split_sensitivity_heatmap.png`
#
# ## Caveats
# - Strong evaluator `limit1000` runs are interpreted as balanced backend evidence only when both Qwen-target and Llama-target matched files are present.
# - The rule-based heuristic backend is not Qwen, not Llama, and not a Qwen/Llama average.
# - Do not interpret cross-backend absolute scores or PCA variance as a calibrated leaderboard.
# - High PC1 variance means stronger one-axis concentration, not automatically better measurement quality.
# - PCA signs are arbitrary; interpret loading magnitudes and variable clusters.
